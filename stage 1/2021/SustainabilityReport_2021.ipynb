# %%
# %pip install pdfplumber pandas
# %pip install PyPDF2
# %pip install pymupdf
# %pip install pycryptodome
# %pip install tabulate
# %pip install matplotlib
# Out:
# Requirement already satisfied: pdfplumber in /Users/seyyiduzun/opt/miniconda3/envs/bachelor/lib/python3.12/site-packages (0.10.2)
# Requirement already satisfied: pandas in /Users/seyyiduzun/opt/miniconda3/envs/bachelor/lib/python3.12/site-packages (2.1.2)
# Requirement already satisfied: pdfminer.six==20221105 in /Users/seyyiduzun/opt/miniconda3/envs/bachelor/lib/python3.12/site-packages (from pdfplumber) (20221105)
# Requirement already satisfied: Pillow>=9.1 in /Users/seyyiduzun/opt/miniconda3/envs/bachelor/lib/python3.12/site-packages (from pdfplumber) (10.1.0)
# Requirement already satisfied: pypdfium2>=4.18.0 in /Users/seyyiduzun/opt/miniconda3/envs/bachelor/lib/python3.12/site-packages (from pdfplumber) (4.22.0)
# Requirement already satisfied: charset-normalizer>=2.0.0 in /Users/seyyiduzun/opt/miniconda3/envs/bachelor/lib/python3.12/site-packages (from pdfminer.six==20221105->pdfplumber) (3.3.1)
# Requirement already satisfied: cryptography>=36.0.0 in /Users/seyyiduzun/opt/miniconda3/envs/bachelor/lib/python3.12/site-packages (from pdfminer.six==20221105->pdfplumber) (41.0.5)
# Requirement already satisfied: numpy<2,>=1.26.0 in /Users/seyyiduzun/opt/miniconda3/envs/bachelor/lib/python3.12/site-packages (from pandas) (1.26.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/seyyiduzun/opt/miniconda3/envs/bachelor/lib/python3.12/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/seyyiduzun/opt/miniconda3/envs/bachelor/lib/python3.12/site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /Users/seyyiduzun/opt/miniconda3/envs/bachelor/lib/python3.12/site-packages (from pandas) (2023.3)
# Requirement already satisfied: six>=1.5 in /Users/seyyiduzun/opt/miniconda3/envs/bachelor/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: cffi>=1.12 in /Users/seyyiduzun/opt/miniconda3/envs/bachelor/lib/python3.12/site-packages (from cryptography>=36.0.0->pdfminer.six==20221105->pdfplumber) (1.16.0)
# Requirement already satisfied: pycparser in /Users/seyyiduzun/opt/miniconda3/envs/bachelor/lib/python3.12/site-packages (from cffi>=1.12->cryptography>=36.0.0->pdfminer.six==20221105->pdfplumber) (2.21)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: PyPDF2 in /Users/seyyiduzun/opt/miniconda3/envs/bachelor/lib/python3.12/site-packages (3.0.1)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: pymupdf in /Users/seyyiduzun/opt/miniconda3/envs/bachelor/lib/python3.12/site-packages (1.23.5)
# Requirement already satisfied: PyMuPDFb==1.23.5 in /Users/seyyiduzun/opt/miniconda3/envs/bachelor/lib/python3.12/site-packages (from pymupdf) (1.23.5)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: pycryptodome in /Users/seyyiduzun/opt/miniconda3/envs/bachelor/lib/python3.12/site-packages (3.19.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: tabulate in /Users/seyyiduzun/opt/miniconda3/envs/bachelor/lib/python3.12/site-packages (0.9.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: matplotlib in /Users/seyyiduzun/opt/miniconda3/envs/bachelor/lib/python3.12/site-packages (3.8.1)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/seyyiduzun/opt/miniconda3/envs/bachelor/lib/python3.12/site-packages (from matplotlib) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in /Users/seyyiduzun/opt/miniconda3/envs/bachelor/lib/python3.12/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/seyyiduzun/opt/miniconda3/envs/bachelor/lib/python3.12/site-packages (from matplotlib) (4.44.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/seyyiduzun/opt/miniconda3/envs/bachelor/lib/python3.12/site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: numpy<2,>=1.21 in /Users/seyyiduzun/opt/miniconda3/envs/bachelor/lib/python3.12/site-packages (from matplotlib) (1.26.1)
# Requirement already satisfied: packaging>=20.0 in /Users/seyyiduzun/opt/miniconda3/envs/bachelor/lib/python3.12/site-packages (from matplotlib) (23.2)
# Requirement already satisfied: pillow>=8 in /Users/seyyiduzun/opt/miniconda3/envs/bachelor/lib/python3.12/site-packages (from matplotlib) (10.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/seyyiduzun/opt/miniconda3/envs/bachelor/lib/python3.12/site-packages (from matplotlib) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/seyyiduzun/opt/miniconda3/envs/bachelor/lib/python3.12/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in /Users/seyyiduzun/opt/miniconda3/envs/bachelor/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Import necessary libraries
# %pip install contractions langdetect requests nltk spacy
# %pip install unidecode
# %pip install beautifulsoup4
import numpy as np
import pandas as pd  # library for data manipulation and analysis
import re  # library for regular expressions
import os  # library for operating system dependent functionality
import string  # library for string operations
import nltk  # library for natural language processing
import spacy  # library for advanced natural language processing
import requests  # library for making HTTP requests
import contractions  # library for expanding contractions
from langdetect import detect  # library for language detection
from nltk.corpus import stopwords  # library for stop words
from nltk.stem import WordNetLemmatizer  # library for lemmatizing words
from nltk.tokenize import word_tokenize, sent_tokenize  # libraries for tokenizing text
from unidecode import unidecode  # library for converting accented characters
from bs4 import BeautifulSoup  # library for parsing HTML and XML documents
from nltk.sentiment import SentimentIntensityAnalyzer  # library for sentiment analysis
nltk.download('vader_lexicon')  # download the VADER sentiment analysis lexicon
nltk.download('wordnet')  # download WordNet for lemmatization
nltk.download('stopwords')  # download stopwords for text preprocessing
nltk.download('punkt')  # download the Punkt tokenizer for sentence segmentation
nltk.download('maxent_ne_chunker')  # download the maximum entropy chunker for named entity recognition
nltk.download('averaged_perceptron_tagger')  # download the averaged perceptron tagger for part-of-speech tagging
nltk.download('words')  # download the NLTK corpus of words
# Out:
# Requirement already satisfied: contractions in /Users/seyyiduzun/opt/miniconda3/envs/bachelor/lib/python3.12/site-packages (0.1.73)
# Requirement already satisfied: langdetect in /Users/seyyiduzun/opt/miniconda3/envs/bachelor/lib/python3.12/site-packages (1.0.9)
# Requirement already satisfied: requests in /Users/seyyiduzun/opt/miniconda3/envs/bachelor/lib/python3.12/site-packages (2.31.0)
# Requirement already satisfied: nltk in /Users/seyyiduzun/opt/miniconda3/envs/bachelor/lib/python3.12/site-packages (3.8.1)
# Requirement already satisfied: spacy in /Users/seyyiduzun/opt/miniconda3/envs/bachelor/lib/python3.12/site-packages (3.7.2)
# Requirement already satisfied: textsearch>=0.0.21 in /Users/seyyiduzun/opt/miniconda3/envs/bachelor/lib/python3.12/site-packages (from contractions) (0.0.24)
# Requirement already satisfied: six in /Users/seyyiduzun/opt/miniconda3/envs/bachelor/lib/python3.12/site-packages (from langdetect) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/seyyiduzun/opt/miniconda3/envs/bachelor/lib/python3.12/site-packages (from requests) (3.3.1)
# Requirement already satisfied: idna<4,>=2.5 in /Users/seyyiduzun/opt/miniconda3/envs/bachelor/lib/python3.12/site-packages (from requests) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/seyyiduzun/opt/miniconda3/envs/bachelor/lib/python3.12/site-packages (from requests) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/seyyiduzun/opt/miniconda3/envs/bachelor/lib/python3.12/site-packages (from requests) (2023.7.22)
# Requirement already satisfied: click in /Users/seyyiduzun/opt/miniconda3/envs/bachelor/lib/python3.12/site-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in /Users/seyyiduzun/opt/miniconda3/envs/bachelor/lib/python3.12/site-packages (from nltk) (1.3.2)
# Requirement already satisfied: regex>=2021.8.3 in /Users/seyyiduzun/opt/miniconda3/envs/bachelor/lib/python3.12/site-packages (from nltk) (2023.10.3)
# Requirement already satisfied: tqdm in /Users/seyyiduzun/opt/miniconda3/envs/bachelor/lib/python3.12/site-packages (from nltk) (4.66.1)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /Users/seyyiduzun/opt/miniconda3/envs/bachelor/lib/python3.12/site-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /Users/seyyiduzun/opt/miniconda3/envs/bachelor/lib/python3.12/site-packages (from spacy) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /Users/seyyiduzun/opt/miniconda3/envs/bachelor/lib/python3.12/site-packages (from spacy) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /Users/seyyiduzun/opt/miniconda3/envs/bachelor/lib/python3.12/site-packages (from spacy) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /Users/seyyiduzun/opt/miniconda3/envs/bachelor/lib/python3.12/site-packages (from spacy) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.1.8 in /Users/seyyiduzun/opt/miniconda3/envs/bachelor/lib/python3.12/site-packages (from spacy) (8.2.1)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /Users/seyyiduzun/opt/miniconda3/envs/bachelor/lib/python3.12/site-packages (from spacy) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /Users/seyyiduzun/opt/miniconda3/envs/bachelor/lib/python3.12/site-packages (from spacy) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /Users/seyyiduzun/opt/miniconda3/envs/bachelor/lib/python3.12/site-packages (from spacy) (2.0.10)
# Requirement already satisfied: weasel<0.4.0,>=0.1.0 in /Users/seyyiduzun/opt/miniconda3/envs/bachelor/lib/python3.12/site-packages (from spacy) (0.3.3)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in /Users/seyyiduzun/opt/miniconda3/envs/bachelor/lib/python3.12/site-packages (from spacy) (0.9.0)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /Users/seyyiduzun/opt/miniconda3/envs/bachelor/lib/python3.12/site-packages (from spacy) (6.4.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /Users/seyyiduzun/opt/miniconda3/envs/bachelor/lib/python3.12/site-packages (from spacy) (2.4.2)
# Requirement already satisfied: jinja2 in /Users/seyyiduzun/opt/miniconda3/envs/bachelor/lib/python3.12/site-packages (from spacy) (3.1.2)
# Requirement already satisfied: setuptools in /Users/seyyiduzun/opt/miniconda3/envs/bachelor/lib/python3.12/site-packages (from spacy) (68.2.2)
# Requirement already satisfied: packaging>=20.0 in /Users/seyyiduzun/opt/miniconda3/envs/bachelor/lib/python3.12/site-packages (from spacy) (23.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /Users/seyyiduzun/opt/miniconda3/envs/bachelor/lib/python3.12/site-packages (from spacy) (3.3.0)
# Requirement already satisfied: numpy>=1.19.0 in /Users/seyyiduzun/opt/miniconda3/envs/bachelor/lib/python3.12/site-packages (from spacy) (1.26.1)
# Requirement already satisfied: annotated-types>=0.4.0 in /Users/seyyiduzun/opt/miniconda3/envs/bachelor/lib/python3.12/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (0.6.0)
# Requirement already satisfied: pydantic-core==2.10.1 in /Users/seyyiduzun/opt/miniconda3/envs/bachelor/lib/python3.12/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (2.10.1)
# Requirement already satisfied: typing-extensions>=4.6.1 in /Users/seyyiduzun/opt/miniconda3/envs/bachelor/lib/python3.12/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (4.8.0)
# Requirement already satisfied: anyascii in /Users/seyyiduzun/opt/miniconda3/envs/bachelor/lib/python3.12/site-packages (from textsearch>=0.0.21->contractions) (0.3.2)
# Requirement already satisfied: pyahocorasick in /Users/seyyiduzun/opt/miniconda3/envs/bachelor/lib/python3.12/site-packages (from textsearch>=0.0.21->contractions) (2.0.0)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /Users/seyyiduzun/opt/miniconda3/envs/bachelor/lib/python3.12/site-packages (from thinc<8.3.0,>=8.1.8->spacy) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /Users/seyyiduzun/opt/miniconda3/envs/bachelor/lib/python3.12/site-packages (from thinc<8.3.0,>=8.1.8->spacy) (0.1.3)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in /Users/seyyiduzun/opt/miniconda3/envs/bachelor/lib/python3.12/site-packages (from weasel<0.4.0,>=0.1.0->spacy) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/seyyiduzun/opt/miniconda3/envs/bachelor/lib/python3.12/site-packages (from jinja2->spacy) (2.1.3)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: unidecode in /Users/seyyiduzun/opt/miniconda3/envs/bachelor/lib/python3.12/site-packages (1.3.7)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: beautifulsoup4 in /Users/seyyiduzun/opt/miniconda3/envs/bachelor/lib/python3.12/site-packages (4.12.2)
# Requirement already satisfied: soupsieve>1.2 in /Users/seyyiduzun/opt/miniconda3/envs/bachelor/lib/python3.12/site-packages (from beautifulsoup4) (2.5)
# Note: you may need to restart the kernel to use updated packages.
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/seyyiduzun/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/seyyiduzun/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/seyyiduzun/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/seyyiduzun/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package maxent_ne_chunker to
# [nltk_data]     /Users/seyyiduzun/nltk_data...
# [nltk_data]   Package maxent_ne_chunker is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /Users/seyyiduzun/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package words to
# [nltk_data]     /Users/seyyiduzun/nltk_data...
# [nltk_data]   Package words is already up-to-date!
# True

# %%
import os
import pandas as pd
from pdfminer.high_level import extract_text
from pathlib import Path
from nltk import FreqDist
from nltk.tokenize import word_tokenize

# Definiere den Pfad zum Ordner mit den PDFs
pdf_folder = '/Users/seyyiduzun/Documents/Bachelorarbeit/Bachelorarbeit/stage 0/2021/SustainabilityReports2021'

# Initialisiere ein leeres DataFrame für die Ergebnisse
result_df = pd.DataFrame(columns=['company', 'content', 'datatype', 'date', 'internal', 'title'])

def process_pdf(pdf_path):
    # Extrahiere den Unternehmensnamen und das Jahr aus dem Dateinamen
    match = re.match(r'(.+?)_(\d+)_SR\.pdf', pdf_path.name)
    if match:
        company_name = match.group(1)
        report_year = int(match.group(2))

        # Öffne die PDF-Datei und extrahiere den Text
        text = extract_text(pdf_path)

        # Extrahiere das Jahr aus dem Dateinamen
        date_match = re.match(r'.+?_(\d+)_SR\.pdf', pdf_path.name)
        date = int(date_match.group(1)) if date_match else None

        # Finde das am häufigsten vorkommende Wort (Title)
        words = word_tokenize(text.lower())
        title = FreqDist(words).max() if words else None

        # Füge die extrahierten Informationen zum DataFrame hinzu
        result_df.loc[len(result_df)] = {
            'company': company_name,
            'content': text,
            'datatype': 'Sustainability Report',
            'date': date,
            'internal': 1,
            'title': title
        }

# Iteriere über alle Dateien im PDF-Ordner
for pdf_path in Path(pdf_folder).glob('*.pdf'):
    process_pdf(pdf_path)

# Speichere das DataFrame als CSV-Datei
result_df.to_csv('/Users/seyyiduzun/Documents/Bachelorarbeit/Bachelorarbeit/output/SustainReports2021.csv', index=False)
# Out:
# The PDF <_io.BufferedReader name='/Users/seyyiduzun/Documents/Bachelorarbeit/Bachelorarbeit/stage 0/2021/SustainabilityReports2021/Symrise_2021_SR.pdf'> contains a metadata field indicating that it should not allow text extraction. Ignoring this field and proceeding. Use the check_extractable if you want to raise an error in this case
# The PDF <_io.BufferedReader name='/Users/seyyiduzun/Documents/Bachelorarbeit/Bachelorarbeit/stage 0/2021/SustainabilityReports2021/Beiersdorf_2021_SR.pdf'> contains a metadata field indicating that it should not allow text extraction. Ignoring this field and proceeding. Use the check_extractable if you want to raise an error in this case
# The PDF <_io.BufferedReader name='/Users/seyyiduzun/Documents/Bachelorarbeit/Bachelorarbeit/stage 0/2021/SustainabilityReports2021/Infineon_2021_SR.pdf'> contains a metadata field indicating that it should not allow text extraction. Ignoring this field and proceeding. Use the check_extractable if you want to raise an error in this case
# The PDF <_io.BufferedReader name='/Users/seyyiduzun/Documents/Bachelorarbeit/Bachelorarbeit/stage 0/2021/SustainabilityReports2021/RWE_2021_SR.pdf'> contains a metadata field indicating that it should not allow text extraction. Ignoring this field and proceeding. Use the check_extractable if you want to raise an error in this case
# The PDF <_io.BufferedReader name='/Users/seyyiduzun/Documents/Bachelorarbeit/Bachelorarbeit/stage 0/2021/SustainabilityReports2021/Volkswagen_2021_SR.pdf'> contains a metadata field indicating that it should not allow text extraction. Ignoring this field and proceeding. Use the check_extractable if you want to raise an error in this case

# %%
# Zeige den Inhalt der CSV-Datei an
df = pd.read_csv('/Users/seyyiduzun/Documents/Bachelorarbeit/Bachelorarbeit/output/SustainReports2021.csv')
df.head(37)
# Out:
#                 company                                            content  \
# 0           Rheinmetall  Basic information on the rheinmetall GroupStru...
# 1         SiemensEnergy  Sustainability Report 2021 \n\nCreating transp...
# 2               Symrise  20 \n21 \n\nSustainability Record  \n(GRI) \n\...
# 3           Continetnal  Turn Change Into Opportunity – \nEmbrace Susta...
# 4          DeutscheBank  Deutsche Bank\n\n Non-Financial Report \n2021\...
# 5              Covestro  COMBINED \n MANAGEMENT REPORT\n\nCOMBINED MANA...
# 6                   MTU  Acting for tomorrow, today  \nOUR RESPONSIBILI...
# 7                 Bayer  Sustainability Report\n\n2021\n\n
# Contents \n\...
# 8       MuenchenerRueck  Sustainability \nReport 2021\n\n
# Munich Re  \n...
# 9               Zalando  Sustainability \nProgress Report\n2021\n\n
# Our...
# 10                  BMW  2MANAGEMENT REPORTCOMBINED34 Overview of the B...
# 11       DeutscheBoerse  Combined  \nmanagement report\n\n20\n\nWhat we...
# 12            Fresenius  SEPARATE  \nGROUP NON-FINANCIAL REPORT\n\n 115...
# 13               Adidas  1 \nTO OUR SHAREHOLDERS \n\n2 \nGROUP MANAGEME...
# 14           Beiersdorf  Sustainability Highlight Report\n\nCARE  \nBEY...
# 15        HannoverRueck  Sustainability Report 2021\n\n  \n
# 2\n\nHannov...
# 16              Allianz  Allianz Group Sustainability Report 2021\n\nBu...
# 17          Commerzbank  40 \n\nCommerzbank Annual Report 2021 \n\nComb...
# 18              Porsche  SUSTAINABILITY MANAGEMENT \nSustainability str...
# 19                 BASF  BASF Report 2021\n\nReport\n\n2 Management’s \...
# 20  HeidelbergMaterials  Company \nPortrait\n\nStrategy & \nManagement\...
# 21             Infineon  Sustainability at Infineon\nSupplementing the ...
# 22               Qiagen  1\n\nForeword\n\nOur Company\n\nEnvironment\n\...
# 23                  RWE  Focus \non tomorrow.\n\nSustainability Report ...
# 24               Airbus  Overview  /  Sustainability\n\n13\n\nPrioritis...
# 25           Volkswagen  SUSTAINABILITY REPORT\n\n2021\n\n
# NEW AUTO: VO...
# 26                  EON  #StandWithUkraine\n\nSustainability \nReport 2...
# 27         MercedesBenz  Sustainability Report 2021\n\nmaximum image ar...
# 28               Henkel  SUSTAINABILITY \nREPORT\n\n2021\n\n
# HENKEL SUS...
# 29              Siemens  Sustainability  report2021
# Our Purpose\n\n  Te...
# 30              Telekom  Corporate Responsibility \nBericht 2021\n\n
# 2\...
# 31                  SAP  SAP Integrated Report 2021 \n\nTo Our  \nStake...
# 32            Sartorius  Sartorius Stedim Biotech S.A. \n\nGRI Report 2...
# 33                  DHL  COMBINED MANAGEMENT REPORT NON-FINANCIAL  STAT...
# 34                Merck  Sustainability Report\n\n2021\n\n
# TABLE OF CON...
# 35              Vonovia  VONOVIA SE\nSUSTAINABILITY REPORT 2021\n\n=\n\...
# 36             Brenntag  S U S T A I N A B I L I T Y   R E P O R T\n202...
#
#                  datatype  date  internal title
# 0   Sustainability Report  2021         1   the
# 1   Sustainability Report  2021         1     ,
# 2   Sustainability Report  2021         1   the
# 3   Sustainability Report  2021         1   the
# 4   Sustainability Report  2021         1   and
# 5   Sustainability Report  2021         1   the
# 6   Sustainability Report  2021         1   the
# 7   Sustainability Report  2021         1   the
# 8   Sustainability Report  2021         1     .
# 9   Sustainability Report  2021         1     ,
# 10  Sustainability Report  2021         1   the
# 11  Sustainability Report  2021         1   the
# 12  Sustainability Report  2021         1   the
# 13  Sustainability Report  2021         1     ,
# 14  Sustainability Report  2021         1   our
# 15  Sustainability Report  2021         1   the
# 16  Sustainability Report  2021         1   and
# 17  Sustainability Report  2021         1   the
# 18  Sustainability Report  2021         1   the
# 19  Sustainability Report  2021         1   the
# 20  Sustainability Report  2021         1   the
# 21  Sustainability Report  2021         1   the
# 22  Sustainability Report  2021         1   and
# 23  Sustainability Report  2021         1   the
# 24  Sustainability Report  2021         1   the
# 25  Sustainability Report  2021         1   the
# 26  Sustainability Report  2021         1     ,
# 27  Sustainability Report  2021         1   the
# 28  Sustainability Report  2021         1   the
# 29  Sustainability Report  2021         1   the
# 30  Sustainability Report  2021         1     .
# 31  Sustainability Report  2021         1     ,
# 32  Sustainability Report  2021         1   the
# 33  Sustainability Report  2021         1   the
# 34  Sustainability Report  2021         1     ,
# 35  Sustainability Report  2021         1   the
# 36  Sustainability Report  2021         1   the

# %%
df.shape
# Out:
# (37, 6)

# %%
import pandas as pd

# Read the CSV file into a DataFrame
df = pd.read_csv('/Users/seyyiduzun/Documents/Bachelorarbeit/Bachelorarbeit/output/SustainReports2021.csv')

# Check datatypes
print(df.dtypes)
# Out:
# company     object
# content     object
# datatype    object
# date         int64
# internal     int64
# title       object
# dtype: object

# %%
import pandas as pd
import os

# Define function to save intermediary steps in a file
def csv_checkpoint(df, filename='checkpoint'):
    """
    Saves a DataFrame to a CSV file and loads it back into a DataFrame.

    Args:
        df (pandas.DataFrame): The DataFrame to save and load.
        filename (str): The name of the CSV file to save the DataFrame to (default: 'checkpoint').

    Returns:
        pandas.DataFrame: The loaded DataFrame.
    """
    if not os.path.exists('../data/checkpoints/'):  # Check if the directory exists and create it if it doesn't
        os.makedirs('../data/checkpoints/')

    # Save DataFrame to CSV
    df.to_csv(f'../data/checkpoints/{filename}.csv', index=False, sep='|')  # Save DataFrame to CSV with specified filename
    print(f'Saved DataFrame to {filename}.csv')

    # Load CSV back into DataFrame
    df = pd.read_csv(f'../data/checkpoints/{filename}.csv', delimiter='|')  # Load CSV back into DataFrame
    print(f'Loaded DataFrame from {filename}.csv')

    return df

# %% [markdown]
# **General Data Cleaning**
#
# As initial data cleaning steps, the following is conducted:
#
#
# * Duplicate entries were identified and removed, resulting in a cleaner and more concise dataset. Duplicates can distort the data and lead to biased analysivs.
# * Language checking was conducted and all rows with non-English content were dropped to ensure consistent language. Language inconsistencies can create bias in the data and lead to inaccurate conclusions. Therefore, it is important to ensure that the data is consistent in language to prevent linguistic biases.
# * Remove company name parts like "AG" for clarity
# * The "sample" method was used to check the data for representativeness and potential issues.

# %%
# Check for duplicates and delete them
duplicates = df[df.duplicated()]
print(f'Duplicated rows: {len(duplicates)}')
df = df.drop_duplicates()
# Out:
# Duplicated rows: 0

# %%
general_cleaned_data = df.copy(deep=True)

# %%
from langdetect import detect

# Check for other languages than English
general_cleaned_data['language'] = general_cleaned_data['content'].apply(lambda x: detect(x))
not_english = len(general_cleaned_data.loc[general_cleaned_data['language'] != 'en'])

# Print the number of rows with other languages
print(f'Number of rows with language other than English: {not_english}')

# Drop the 'language' column
general_cleaned_data.drop(['language'], axis=1, inplace=True)
# Out:
# Number of rows with language other than English: 1

# %%
general_cleaned_data.shape
# Out:
# (37, 6)

# %%
general_cleaned_data.head(37)
# Out:
#                 company                                            content  \
# 0           Rheinmetall  Basic information on the rheinmetall GroupStru...
# 1         SiemensEnergy  Sustainability Report 2021 \n\nCreating transp...
# 2               Symrise  20 \n21 \n\nSustainability Record  \n(GRI) \n\...
# 3           Continetnal  Turn Change Into Opportunity – \nEmbrace Susta...
# 4          DeutscheBank  Deutsche Bank\n\n Non-Financial Report \n2021\...
# 5              Covestro  COMBINED \n MANAGEMENT REPORT\n\nCOMBINED MANA...
# 6                   MTU  Acting for tomorrow, today  \nOUR RESPONSIBILI...
# 7                 Bayer  Sustainability Report\n\n2021\n\n
# Contents \n\...
# 8       MuenchenerRueck  Sustainability \nReport 2021\n\n
# Munich Re  \n...
# 9               Zalando  Sustainability \nProgress Report\n2021\n\n
# Our...
# 10                  BMW  2MANAGEMENT REPORTCOMBINED34 Overview of the B...
# 11       DeutscheBoerse  Combined  \nmanagement report\n\n20\n\nWhat we...
# 12            Fresenius  SEPARATE  \nGROUP NON-FINANCIAL REPORT\n\n 115...
# 13               Adidas  1 \nTO OUR SHAREHOLDERS \n\n2 \nGROUP MANAGEME...
# 14           Beiersdorf  Sustainability Highlight Report\n\nCARE  \nBEY...
# 15        HannoverRueck  Sustainability Report 2021\n\n  \n
# 2\n\nHannov...
# 16              Allianz  Allianz Group Sustainability Report 2021\n\nBu...
# 17          Commerzbank  40 \n\nCommerzbank Annual Report 2021 \n\nComb...
# 18              Porsche  SUSTAINABILITY MANAGEMENT \nSustainability str...
# 19                 BASF  BASF Report 2021\n\nReport\n\n2 Management’s \...
# 20  HeidelbergMaterials  Company \nPortrait\n\nStrategy & \nManagement\...
# 21             Infineon  Sustainability at Infineon\nSupplementing the ...
# 22               Qiagen  1\n\nForeword\n\nOur Company\n\nEnvironment\n\...
# 23                  RWE  Focus \non tomorrow.\n\nSustainability Report ...
# 24               Airbus  Overview  /  Sustainability\n\n13\n\nPrioritis...
# 25           Volkswagen  SUSTAINABILITY REPORT\n\n2021\n\n
# NEW AUTO: VO...
# 26                  EON  #StandWithUkraine\n\nSustainability \nReport 2...
# 27         MercedesBenz  Sustainability Report 2021\n\nmaximum image ar...
# 28               Henkel  SUSTAINABILITY \nREPORT\n\n2021\n\n
# HENKEL SUS...
# 29              Siemens  Sustainability  report2021
# Our Purpose\n\n  Te...
# 30              Telekom  Corporate Responsibility \nBericht 2021\n\n
# 2\...
# 31                  SAP  SAP Integrated Report 2021 \n\nTo Our  \nStake...
# 32            Sartorius  Sartorius Stedim Biotech S.A. \n\nGRI Report 2...
# 33                  DHL  COMBINED MANAGEMENT REPORT NON-FINANCIAL  STAT...
# 34                Merck  Sustainability Report\n\n2021\n\n
# TABLE OF CON...
# 35              Vonovia  VONOVIA SE\nSUSTAINABILITY REPORT 2021\n\n=\n\...
# 36             Brenntag  S U S T A I N A B I L I T Y   R E P O R T\n202...
#
#                  datatype  date  internal title
# 0   Sustainability Report  2021         1   the
# 1   Sustainability Report  2021         1     ,
# 2   Sustainability Report  2021         1   the
# 3   Sustainability Report  2021         1   the
# 4   Sustainability Report  2021         1   and
# 5   Sustainability Report  2021         1   the
# 6   Sustainability Report  2021         1   the
# 7   Sustainability Report  2021         1   the
# 8   Sustainability Report  2021         1     .
# 9   Sustainability Report  2021         1     ,
# 10  Sustainability Report  2021         1   the
# 11  Sustainability Report  2021         1   the
# 12  Sustainability Report  2021         1   the
# 13  Sustainability Report  2021         1     ,
# 14  Sustainability Report  2021         1   our
# 15  Sustainability Report  2021         1   the
# 16  Sustainability Report  2021         1   and
# 17  Sustainability Report  2021         1   the
# 18  Sustainability Report  2021         1   the
# 19  Sustainability Report  2021         1   the
# 20  Sustainability Report  2021         1   the
# 21  Sustainability Report  2021         1   the
# 22  Sustainability Report  2021         1   and
# 23  Sustainability Report  2021         1   the
# 24  Sustainability Report  2021         1   the
# 25  Sustainability Report  2021         1   the
# 26  Sustainability Report  2021         1     ,
# 27  Sustainability Report  2021         1   the
# 28  Sustainability Report  2021         1   the
# 29  Sustainability Report  2021         1   the
# 30  Sustainability Report  2021         1     .
# 31  Sustainability Report  2021         1     ,
# 32  Sustainability Report  2021         1   the
# 33  Sustainability Report  2021         1   the
# 34  Sustainability Report  2021         1     ,
# 35  Sustainability Report  2021         1   the
# 36  Sustainability Report  2021         1   the

# %% [markdown]
# **Text Data Cleaning & Preprocessing**
#
# The "content" column, containing the text of the reports, undergoes a series of cleaning, normalization, and preprocessing steps to ensure accurate and efficient analysis. These steps include:
#
# * String conversion: Converting the input to a string format ensures consistency and compatibility during subsequent processing tasks.
# * Lowercase conversion: Transforming all text to lowercase serves as a simple normalization step, reducing the complexity and variability of the input data.
# * Unicode decoding: Removing diacritics (e.g., accented characters) and normalizing the text encoding mitigates potential discrepancies arising from different encoding formats.
# * URL and email address removal: Eliminating URLs and email addresses reduces noise in the dataset, as these elements do not contribute valuable information for the analysis.
# * Extra whitespace removal: Eradicating extra whitespaces improves text analysis and tokenization by ensuring that only meaningful spaces are retained.
# * Contact detail removal: Excluding phone numbers, contact person strings, and social media references further minimizes noise in the dataset, honing the focus on relevant text.
# * Table of contents removal: Discarding the table of contents enhances the data quality by eliminating repetitive and non-essential information.
# * Named entity removal: Employing the spaCy model to remove human names and other named entities optimizes the text for analysis and modeling by concentrating on pertinent content.
# * Abbreviation expansion: Utilizing the contractions library and custom functions with regular expressions, common and uncommon abbreviations are expanded to improve text interpretation.
# * Special character elimination: Excluding all special characters, except punctuation, refines the input data. Retaining punctuation is necessary for accurate sentence tokenization and removed after sentence tokenization..
# * Tokenization and lemmatization: Tokenizing words and sentences, and subsequently lemmatizing words using the WordNetLemmatizer from nltk, streamlines the text and reduces morphological variations.
# * Stopword removal: Customizing the nltk stopwords list by adding or removing specific stopwords enables more precise and tailored text analysis.
# * Part-of-speech (POS) tagging: Assigning POS tags to words and sentences enhances the text representation by providing additional linguistic information, which may be beneficial for subsequent analysis and modeling tasks.
# * Sentiment Analysis: Basic sentiment value calculation on the tokenzued sentences to get first insights im terms of the sentiments in the reports within the EDA.

# %%
cleaned_data= general_cleaned_data.copy(deep=True)

# %%
# !python -m spacy download en_core_web_md
# Since the spacy model shows better results on the "raw" text, the named entity removal is conducted before all normalization and cleaning steps
spacy_model = spacy.load('en_core_web_md')
spacy_model.max_length = 1800000 # Increase max text length

def remove_named_entities(text):
    """
    Removes named entities from text and returns the modified text and the count of named entities removed.

    Args:
        text (str): The text to remove named entities from.

    Returns:
        tuple: A tuple containing the modified text (str) and the count of named entities removed (int).
    """
    doc = spacy_model(text)
    
    named_entities = set()
    for ent in doc.ents:
        if ent.label_ in ["PERSON"]:
            named_entities.add(ent.text)
    
    named_entities_count = len(named_entities)
    
    for named_entity in named_entities:
        text = text.replace(named_entity, '')
    
    return text, named_entities_count

# Assuming cleaned_data is a pandas DataFrame with a 'content' column
cleaned_data['cleaned_content'], name_entity_count = zip(*cleaned_data['content'].apply(remove_named_entities))
print("Name entities removed:", sum(name_entity_count))
# Out:
# Collecting en-core-web-md==3.7.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_md-3.7.0/en_core_web_md-3.7.0-py3-none-any.whl (42.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.8/42.8 MB 15.4 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: spacy<3.8.0,>=3.7.0 in /Users/seyyiduzun/opt/miniconda3/envs/bachelor/lib/python3.12/site-packages (from en-core-web-md==3.7.0) (3.7.2)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /Users/seyyiduzun/opt/miniconda3/envs/bachelor/lib/python3.12/site-packages (from spacy<3.8.0,>=3.7.0->en-core-web-md==3.7.0) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /Users/seyyiduzun/opt/miniconda3/envs/bachelor/lib/python3.12/site-packages (from spacy<3.8.0,>=3.7.0->en-core-web-md==3.7.0) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /Users/seyyiduzun/opt/miniconda3/envs/bachelor/lib/python3.12/site-packages (from spacy<3.8.0,>=3.7.0->en-core-web-md==3.7.0) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /Users/seyyiduzun/opt/miniconda3/envs/bachelor/lib/python3.12/site-packages (from spacy<3.8.0,>=3.7.0->en-core-web-md==3.7.0) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /Users/seyyiduzun/opt/miniconda3/envs/bachelor/lib/python3.12/site-packages (from spacy<3.8.0,>=3.7.0->en-core-web-md==3.7.0) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.1.8 in /Users/seyyiduzun/opt/miniconda3/envs/bachelor/lib/python3.12/site-packages (from spacy<3.8.0,>=3.7.0->en-core-web-md==3.7.0) (8.2.1)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /Users/seyyiduzun/opt/miniconda3/envs/bachelor/lib/python3.12/site-packages (from spacy<3.8.0,>=3.7.0->en-core-web-md==3.7.0) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /Users/seyyiduzun/opt/miniconda3/envs/bachelor/lib/python3.12/site-packages (from spacy<3.8.0,>=3.7.0->en-core-web-md==3.7.0) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /Users/seyyiduzun/opt/miniconda3/envs/bachelor/lib/python3.12/site-packages (from spacy<3.8.0,>=3.7.0->en-core-web-md==3.7.0) (2.0.10)
# Requirement already satisfied: weasel<0.4.0,>=0.1.0 in /Users/seyyiduzun/opt/miniconda3/envs/bachelor/lib/python3.12/site-packages (from spacy<3.8.0,>=3.7.0->en-core-web-md==3.7.0) (0.3.3)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in /Users/seyyiduzun/opt/miniconda3/envs/bachelor/lib/python3.12/site-packages (from spacy<3.8.0,>=3.7.0->en-core-web-md==3.7.0) (0.9.0)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /Users/seyyiduzun/opt/miniconda3/envs/bachelor/lib/python3.12/site-packages (from spacy<3.8.0,>=3.7.0->en-core-web-md==3.7.0) (6.4.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /Users/seyyiduzun/opt/miniconda3/envs/bachelor/lib/python3.12/site-packages (from spacy<3.8.0,>=3.7.0->en-core-web-md==3.7.0) (4.66.1)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /Users/seyyiduzun/opt/miniconda3/envs/bachelor/lib/python3.12/site-packages (from spacy<3.8.0,>=3.7.0->en-core-web-md==3.7.0) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /Users/seyyiduzun/opt/miniconda3/envs/bachelor/lib/python3.12/site-packages (from spacy<3.8.0,>=3.7.0->en-core-web-md==3.7.0) (2.4.2)
# Requirement already satisfied: jinja2 in /Users/seyyiduzun/opt/miniconda3/envs/bachelor/lib/python3.12/site-packages (from spacy<3.8.0,>=3.7.0->en-core-web-md==3.7.0) (3.1.2)
# Requirement already satisfied: setuptools in /Users/seyyiduzun/opt/miniconda3/envs/bachelor/lib/python3.12/site-packages (from spacy<3.8.0,>=3.7.0->en-core-web-md==3.7.0) (68.2.2)
# Requirement already satisfied: packaging>=20.0 in /Users/seyyiduzun/opt/miniconda3/envs/bachelor/lib/python3.12/site-packages (from spacy<3.8.0,>=3.7.0->en-core-web-md==3.7.0) (23.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /Users/seyyiduzun/opt/miniconda3/envs/bachelor/lib/python3.12/site-packages (from spacy<3.8.0,>=3.7.0->en-core-web-md==3.7.0) (3.3.0)
# Requirement already satisfied: numpy>=1.19.0 in /Users/seyyiduzun/opt/miniconda3/envs/bachelor/lib/python3.12/site-packages (from spacy<3.8.0,>=3.7.0->en-core-web-md==3.7.0) (1.26.1)
# Requirement already satisfied: annotated-types>=0.4.0 in /Users/seyyiduzun/opt/miniconda3/envs/bachelor/lib/python3.12/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.0->en-core-web-md==3.7.0) (0.6.0)
# Requirement already satisfied: pydantic-core==2.10.1 in /Users/seyyiduzun/opt/miniconda3/envs/bachelor/lib/python3.12/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.0->en-core-web-md==3.7.0) (2.10.1)
# Requirement already satisfied: typing-extensions>=4.6.1 in /Users/seyyiduzun/opt/miniconda3/envs/bachelor/lib/python3.12/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.0->en-core-web-md==3.7.0) (4.8.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/seyyiduzun/opt/miniconda3/envs/bachelor/lib/python3.12/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->en-core-web-md==3.7.0) (3.3.1)
# Requirement already satisfied: idna<4,>=2.5 in /Users/seyyiduzun/opt/miniconda3/envs/bachelor/lib/python3.12/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->en-core-web-md==3.7.0) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/seyyiduzun/opt/miniconda3/envs/bachelor/lib/python3.12/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->en-core-web-md==3.7.0) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/seyyiduzun/opt/miniconda3/envs/bachelor/lib/python3.12/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->en-core-web-md==3.7.0) (2023.7.22)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /Users/seyyiduzun/opt/miniconda3/envs/bachelor/lib/python3.12/site-packages (from thinc<8.3.0,>=8.1.8->spacy<3.8.0,>=3.7.0->en-core-web-md==3.7.0) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /Users/seyyiduzun/opt/miniconda3/envs/bachelor/lib/python3.12/site-packages (from thinc<8.3.0,>=8.1.8->spacy<3.8.0,>=3.7.0->en-core-web-md==3.7.0) (0.1.3)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /Users/seyyiduzun/opt/miniconda3/envs/bachelor/lib/python3.12/site-packages (from typer<0.10.0,>=0.3.0->spacy<3.8.0,>=3.7.0->en-core-web-md==3.7.0) (8.1.7)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in /Users/seyyiduzun/opt/miniconda3/envs/bachelor/lib/python3.12/site-packages (from weasel<0.4.0,>=0.1.0->spacy<3.8.0,>=3.7.0->en-core-web-md==3.7.0) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/seyyiduzun/opt/miniconda3/envs/bachelor/lib/python3.12/site-packages (from jinja2->spacy<3.8.0,>=3.7.0->en-core-web-md==3.7.0) (2.1.3)
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_md')
# Name entities removed: 8334

# %%
cleaned_data.head(37)
# Out:
#                 company                                            content  \
# 0           Rheinmetall  Basic information on the rheinmetall GroupStru...
# 1         SiemensEnergy  Sustainability Report 2021 \n\nCreating transp...
# 2               Symrise  20 \n21 \n\nSustainability Record  \n(GRI) \n\...
# 3           Continetnal  Turn Change Into Opportunity – \nEmbrace Susta...
# 4          DeutscheBank  Deutsche Bank\n\n Non-Financial Report \n2021\...
# 5              Covestro  COMBINED \n MANAGEMENT REPORT\n\nCOMBINED MANA...
# 6                   MTU  Acting for tomorrow, today  \nOUR RESPONSIBILI...
# 7                 Bayer  Sustainability Report\n\n2021\n\n
# Contents \n\...
# 8       MuenchenerRueck  Sustainability \nReport 2021\n\n
# Munich Re  \n...
# 9               Zalando  Sustainability \nProgress Report\n2021\n\n
# Our...
# 10                  BMW  2MANAGEMENT REPORTCOMBINED34 Overview of the B...
# 11       DeutscheBoerse  Combined  \nmanagement report\n\n20\n\nWhat we...
# 12            Fresenius  SEPARATE  \nGROUP NON-FINANCIAL REPORT\n\n 115...
# 13               Adidas  1 \nTO OUR SHAREHOLDERS \n\n2 \nGROUP MANAGEME...
# 14           Beiersdorf  Sustainability Highlight Report\n\nCARE  \nBEY...
# 15        HannoverRueck  Sustainability Report 2021\n\n  \n
# 2\n\nHannov...
# 16              Allianz  Allianz Group Sustainability Report 2021\n\nBu...
# 17          Commerzbank  40 \n\nCommerzbank Annual Report 2021 \n\nComb...
# 18              Porsche  SUSTAINABILITY MANAGEMENT \nSustainability str...
# 19                 BASF  BASF Report 2021\n\nReport\n\n2 Management’s \...
# 20  HeidelbergMaterials  Company \nPortrait\n\nStrategy & \nManagement\...
# 21             Infineon  Sustainability at Infineon\nSupplementing the ...
# 22               Qiagen  1\n\nForeword\n\nOur Company\n\nEnvironment\n\...
# 23                  RWE  Focus \non tomorrow.\n\nSustainability Report ...
# 24               Airbus  Overview  /  Sustainability\n\n13\n\nPrioritis...
# 25           Volkswagen  SUSTAINABILITY REPORT\n\n2021\n\n
# NEW AUTO: VO...
# 26                  EON  #StandWithUkraine\n\nSustainability \nReport 2...
# 27         MercedesBenz  Sustainability Report 2021\n\nmaximum image ar...
# 28               Henkel  SUSTAINABILITY \nREPORT\n\n2021\n\n
# HENKEL SUS...
# 29              Siemens  Sustainability  report2021
# Our Purpose\n\n  Te...
# 30              Telekom  Corporate Responsibility \nBericht 2021\n\n
# 2\...
# 31                  SAP  SAP Integrated Report 2021 \n\nTo Our  \nStake...
# 32            Sartorius  Sartorius Stedim Biotech S.A. \n\nGRI Report 2...
# 33                  DHL  COMBINED MANAGEMENT REPORT NON-FINANCIAL  STAT...
# 34                Merck  Sustainability Report\n\n2021\n\n
# TABLE OF CON...
# 35              Vonovia  VONOVIA SE\nSUSTAINABILITY REPORT 2021\n\n=\n\...
# 36             Brenntag  S U S T A I N A B I L I T Y   R E P O R T\n202...
#
#                  datatype  date  internal title  \
# 0   Sustainability Report  2021         1   the
# 1   Sustainability Report  2021         1     ,
# 2   Sustainability Report  2021         1   the
# 3   Sustainability Report  2021         1   the
# 4   Sustainability Report  2021         1   and
# 5   Sustainability Report  2021         1   the
# 6   Sustainability Report  2021         1   the
# 7   Sustainability Report  2021         1   the
# 8   Sustainability Report  2021         1     .
# 9   Sustainability Report  2021         1     ,
# 10  Sustainability Report  2021         1   the
# 11  Sustainability Report  2021         1   the
# 12  Sustainability Report  2021         1   the
# 13  Sustainability Report  2021         1     ,
# 14  Sustainability Report  2021         1   our
# 15  Sustainability Report  2021         1   the
# 16  Sustainability Report  2021         1   and
# 17  Sustainability Report  2021         1   the
# 18  Sustainability Report  2021         1   the
# 19  Sustainability Report  2021         1   the
# 20  Sustainability Report  2021         1   the
# 21  Sustainability Report  2021         1   the
# 22  Sustainability Report  2021         1   and
# 23  Sustainability Report  2021         1   the
# 24  Sustainability Report  2021         1   the
# 25  Sustainability Report  2021         1   the
# 26  Sustainability Report  2021         1     ,
# 27  Sustainability Report  2021         1   the
# 28  Sustainability Report  2021         1   the
# 29  Sustainability Report  2021         1   the
# 30  Sustainability Report  2021         1     .
# 31  Sustainability Report  2021         1     ,
# 32  Sustainability Report  2021         1   the
# 33  Sustainability Report  2021         1   the
# 34  Sustainability Report  2021         1     ,
# 35  Sustainability Report  2021         1   the
# 36  Sustainability Report  2021         1   the
#
#                                       cleaned_content
# 0   Basic information on the rheinmetall GroupStru...
# 1   Sustainability Report 2021 \n\nCreating transp...
# 2   20 \n21 \n\nSustainability Record  \n(GRI) \n\...
# 3   Turn Change Into Opportunity – \nEmbrace Susta...
# 4   Deutsche Bank\n\n Non-Financial Report \n2021\...
# 5   COMBINED \n MANAGEMENT REPORT\n\nCOMBINED MANA...
# 6   Acting for tomorrow, today  \nOUR RESPONSIBILI...
# 7   Sustainability Report\n\n2021\n\n
# Contents \n\...
# 8   Sustainability \nReport 2021\n\n
#  Re  \nSustai...
# 9   Sustainability \nProgress Report\n2021\n\n
# Our...
# 10  2MANAGEMENT REPORTCOMBINED34 Overview of the B...
# 11  Combined  \nmanagement report\n\n20\n\nWhat we...
# 12  SEPARATE  \nGROUP NON-FINANCIAL REPORT\n\n 115...
# 13  1 \nTO OUR SHAREHOLDERS \n\n2 \nGROUP MANAGEME...
# 14  Sustainability Highlight Report\n\nCARE  \nBEY...
# 15  Sustainability Report 2021\n\n  \n
# 2\n\nHannov...
# 16  Allianz Group Sustainability Report 2021\n\nBu...
# 17  40 \n\nCommerzbank Annual Report 2021 \n\nComb...
# 18  SUSTAINABILITY MANAGEMENT \nSustainability str...
# 19  BASF Report 2021\n\nReport\n\n2 Management’s \...
# 20  Company \nPortrait\n\nStrategy & \nManagement\...
# 21  Sustainability at \nSupplementing the Annual R...
# 22  1\n\n\n\nOur Company\n\nEnvironment\n\nSocial\...
# 23  Focus \non tomorrow.\n\nSustainability Report ...
# 24  Overview  /  Sustainability\n\n13\n\nPrioritis...
# 25  SUSTAINABILITY REPORT\n\n2021\n\n
# NEW AUTO: VO...
# 26  #StandWithUkraine\n\nSustainability \nReport 2...
# 27  Sustainability Report 2021\n\nmaximum image ar...
# 28  SUSTAINABILITY \nREPORT\n\n2021\n\n
# HENKEL SUS...
# 29  Sustainability
# Our Purpose\n\n  Technology t...
# 30  Corporate Responsibility \n 2021\n\n
# 2\n\nInha...
# 31  SAP Integrated Report 2021 \n\nTo Our  \nStake...
# 32   Stedim Biotech S.A. \n\nGRI Report 2021 \n\n ...
# 33  COMBINED MANAGEMENT REPORT NON-FINANCIAL  STAT...
# 34  Sustainability Report\n\n2021\n\n
# TABLE OF CON...
# 35  VONOVIA SE\nSUSTAINABILITY REPORT 2021\n\n=\n\...
# 36  S U S T A I N A B I L I T Y   R E P O R T\n202...

# %%
def remove_urls(text):
    urls = re.findall(r'http\S+|www\S+|https\S+', text, flags=re.MULTILINE)
    return re.sub(r'http\S+|www\S+|https\S+', '', text, flags=re.MULTILINE), len(urls)

def remove_emails(text):
    mail_addresses = re.findall(r'\S+@\S+\s?', text, flags=re.MULTILINE)
    return re.sub(r'\S+@\S+\s?', '', text, flags=re.MULTILINE), len(mail_addresses)

def remove_extra_whitespace(text):
    extra_spaces = re.findall(r'\s{2,}', text)
    return re.sub(r'\s+', ' ', text).strip(), len(extra_spaces)

cleaned_data['cleaned_content'] = cleaned_data['cleaned_content'].astype(str) # Convert all texts to string
cleaned_data['cleaned_content'] = cleaned_data['cleaned_content'].apply(lambda x: x.lower()) # Convert all texts to lower-case
cleaned_data['cleaned_content'] = cleaned_data['cleaned_content'].apply(lambda x: unidecode(x, errors="preserve")) # Remove diacritics / accented characters and unicode normalization
cleaned_data['cleaned_content'], url_count = zip(*cleaned_data['cleaned_content'].apply(remove_urls)) # Remove URLs from texts
cleaned_data['cleaned_content'], email_count = zip(*cleaned_data['cleaned_content'].apply(remove_emails)) # Remove e-mail addresses from texts
cleaned_data['cleaned_content'], extra_space_count = zip(*cleaned_data['cleaned_content'].apply(remove_extra_whitespace)) # Remove extra whitespaces from texts

print("URLs removed:", sum(url_count))
print("Mail addresses removed:", sum(email_count))
print("Extra whitespaces removed:", sum(extra_space_count))
# Out:
# URLs removed: 332
# Mail addresses removed: 193
# Extra whitespaces removed: 446578

# %%
cleaned_data.head(37)
# Out:
#                 company                                            content  \
# 0           Rheinmetall  Basic information on the rheinmetall GroupStru...
# 1         SiemensEnergy  Sustainability Report 2021 \n\nCreating transp...
# 2               Symrise  20 \n21 \n\nSustainability Record  \n(GRI) \n\...
# 3           Continetnal  Turn Change Into Opportunity – \nEmbrace Susta...
# 4          DeutscheBank  Deutsche Bank\n\n Non-Financial Report \n2021\...
# 5              Covestro  COMBINED \n MANAGEMENT REPORT\n\nCOMBINED MANA...
# 6                   MTU  Acting for tomorrow, today  \nOUR RESPONSIBILI...
# 7                 Bayer  Sustainability Report\n\n2021\n\n
# Contents \n\...
# 8       MuenchenerRueck  Sustainability \nReport 2021\n\n
# Munich Re  \n...
# 9               Zalando  Sustainability \nProgress Report\n2021\n\n
# Our...
# 10                  BMW  2MANAGEMENT REPORTCOMBINED34 Overview of the B...
# 11       DeutscheBoerse  Combined  \nmanagement report\n\n20\n\nWhat we...
# 12            Fresenius  SEPARATE  \nGROUP NON-FINANCIAL REPORT\n\n 115...
# 13               Adidas  1 \nTO OUR SHAREHOLDERS \n\n2 \nGROUP MANAGEME...
# 14           Beiersdorf  Sustainability Highlight Report\n\nCARE  \nBEY...
# 15        HannoverRueck  Sustainability Report 2021\n\n  \n
# 2\n\nHannov...
# 16              Allianz  Allianz Group Sustainability Report 2021\n\nBu...
# 17          Commerzbank  40 \n\nCommerzbank Annual Report 2021 \n\nComb...
# 18              Porsche  SUSTAINABILITY MANAGEMENT \nSustainability str...
# 19                 BASF  BASF Report 2021\n\nReport\n\n2 Management’s \...
# 20  HeidelbergMaterials  Company \nPortrait\n\nStrategy & \nManagement\...
# 21             Infineon  Sustainability at Infineon\nSupplementing the ...
# 22               Qiagen  1\n\nForeword\n\nOur Company\n\nEnvironment\n\...
# 23                  RWE  Focus \non tomorrow.\n\nSustainability Report ...
# 24               Airbus  Overview  /  Sustainability\n\n13\n\nPrioritis...
# 25           Volkswagen  SUSTAINABILITY REPORT\n\n2021\n\n
# NEW AUTO: VO...
# 26                  EON  #StandWithUkraine\n\nSustainability \nReport 2...
# 27         MercedesBenz  Sustainability Report 2021\n\nmaximum image ar...
# 28               Henkel  SUSTAINABILITY \nREPORT\n\n2021\n\n
# HENKEL SUS...
# 29              Siemens  Sustainability  report2021
# Our Purpose\n\n  Te...
# 30              Telekom  Corporate Responsibility \nBericht 2021\n\n
# 2\...
# 31                  SAP  SAP Integrated Report 2021 \n\nTo Our  \nStake...
# 32            Sartorius  Sartorius Stedim Biotech S.A. \n\nGRI Report 2...
# 33                  DHL  COMBINED MANAGEMENT REPORT NON-FINANCIAL  STAT...
# 34                Merck  Sustainability Report\n\n2021\n\n
# TABLE OF CON...
# 35              Vonovia  VONOVIA SE\nSUSTAINABILITY REPORT 2021\n\n=\n\...
# 36             Brenntag  S U S T A I N A B I L I T Y   R E P O R T\n202...
#
#                  datatype  date  internal title  \
# 0   Sustainability Report  2021         1   the
# 1   Sustainability Report  2021         1     ,
# 2   Sustainability Report  2021         1   the
# 3   Sustainability Report  2021         1   the
# 4   Sustainability Report  2021         1   and
# 5   Sustainability Report  2021         1   the
# 6   Sustainability Report  2021         1   the
# 7   Sustainability Report  2021         1   the
# 8   Sustainability Report  2021         1     .
# 9   Sustainability Report  2021         1     ,
# 10  Sustainability Report  2021         1   the
# 11  Sustainability Report  2021         1   the
# 12  Sustainability Report  2021         1   the
# 13  Sustainability Report  2021         1     ,
# 14  Sustainability Report  2021         1   our
# 15  Sustainability Report  2021         1   the
# 16  Sustainability Report  2021         1   and
# 17  Sustainability Report  2021         1   the
# 18  Sustainability Report  2021         1   the
# 19  Sustainability Report  2021         1   the
# 20  Sustainability Report  2021         1   the
# 21  Sustainability Report  2021         1   the
# 22  Sustainability Report  2021         1   and
# 23  Sustainability Report  2021         1   the
# 24  Sustainability Report  2021         1   the
# 25  Sustainability Report  2021         1   the
# 26  Sustainability Report  2021         1     ,
# 27  Sustainability Report  2021         1   the
# 28  Sustainability Report  2021         1   the
# 29  Sustainability Report  2021         1   the
# 30  Sustainability Report  2021         1     .
# 31  Sustainability Report  2021         1     ,
# 32  Sustainability Report  2021         1   the
# 33  Sustainability Report  2021         1   the
# 34  Sustainability Report  2021         1     ,
# 35  Sustainability Report  2021         1   the
# 36  Sustainability Report  2021         1   the
#
#                                       cleaned_content
# 0   basic information on the rheinmetall groupstru...
# 1   sustainability report 2021 creating transparen...
# 2   20 21 sustainability record (gri) sustainabili...
# 3   turn change into opportunity - embrace sustain...
# 4   deutsche bank non-financial report 2021 conten...
# 5   combined management report combined management...
# 6   acting for tomorrow, today our responsibility,...
# 7   sustainability report 2021 contents contents e...
# 8   sustainability report 2021 re sustainability r...
# 9   sustainability progress report 2021 our progre...
# 10  2management reportcombined34 overview of the b...
# 11  combined management report 20 what we achieved...
# 12  separate group non-financial report 115 strate...
# 13  1 to our shareholders 2 group management repor...
# 14  sustainability highlight report care beyond sk...
# 15  sustainability report 2021 2 hannover re | sus...
# 16  allianz group sustainability report 2021 build...
# 17  40 commerzbank annual report 2021 combined sep...
# 18  sustainability management sustainability strat...
# 19  basf report 2021 report 2 management's 52 17 o...
# 20  company portrait strategy & management busines...
# 21  sustainability at supplementing the annual rep...
# 22  1 our company environment social governance an...
# 23  focus on tomorrow. sustainability report 2021 ...
# 24  overview / sustainability 13 prioritising sust...
# 25  sustainability report 2021 new auto: volkswage...
# 26  #standwithukraine sustainability report 2021 c...
# 27  sustainability report 2021 maximum image aream...
# 28  sustainability report 2021 henkel sustainabili...
# 29  sustainability our purpose technology to trans...
# 30  corporate responsibility 2021 2 inhalt dieses ...
# 31  sap integrated report 2021 to our stakeholders...
# 32  stedim biotech s.a. gri report 2021 stedim bio...
# 33  combined management report non-financial state...
# 34  sustainability report 2021 table of contents s...
# 35  vonovia se sustainability report 2021 = for a ...
# 36  s u s t a i n a b i l i t y r e p o r t 2021 b...

# %%
def remove_contact_details(text):
    # Remove phone numbers
    phone_regex = r'(?<!\d)[\+\(]?[1-9][0-9 .\-\(\)]{8,}[0-9](?!\d)'
    phone_count = len(re.findall(phone_regex, text))
    text = re.sub(phone_regex, '', text)

    # Remove common contact-related phrases
    contact_phrases_regex = r'\b(?:Contact Person|Phone|Tel|Fax|Mobile|E?mail|Skype|Twitter|Facebook|LinkedIn|Website):\s*\S+'
    contact_phrases_count = len(re.findall(contact_phrases_regex, text, flags=re.IGNORECASE))
    text = re.sub(contact_phrases_regex, '', text, flags=re.IGNORECASE)

    total_count = phone_count + contact_phrases_count
    return text, total_count

def remove_table_of_contents(text):
    # Remove common table of contents phrases
    toc_phrases_regex = r'\b(?:Table of Contents|Contents)\b'
    toc_phrases_count = len(re.findall(toc_phrases_regex, text, flags=re.IGNORECASE))
    text = re.sub(toc_phrases_regex, '', text, flags=re.IGNORECASE)

    # Remove content with numbering like "1. Introduction", "1.1. Background", "A. Overview", etc.
    toc_entries_regex = r'(^|\n)\s*\d+(\.\d+)*\s+\w+([\w\s]+)?'
    toc_entries_count = len(re.findall(toc_entries_regex, text))
    text = re.sub(toc_entries_regex, '', text)

    total_count = toc_phrases_count + toc_entries_count
    return text, total_count

cleaned_data['cleaned_content'], contact_count = zip(*cleaned_data['cleaned_content'].apply(remove_contact_details))
cleaned_data['cleaned_content'], toc_count = zip(*cleaned_data['cleaned_content'].apply(remove_table_of_contents))
print("Contact information removed:", sum(contact_count))
print("TOCs removed:", sum(toc_count))
# Out:
# Contact information removed: 4151
# TOCs removed: 327

# %%
cleaned_data.shape
# Out:
# (37, 7)

# %%
def expand_contractions(text):
    expanded_text = []
    for word in text.split():
        expanded_text.append(contractions.fix(word))
    expanded_text = ' '.join(expanded_text)
    return contractions.fix(expanded_text)

cleaned_data['cleaned_content'] = cleaned_data['cleaned_content'].apply(expand_contractions)

# %%
cleaned_data.head(37)
# Out:
#                 company                                            content  \
# 0           Rheinmetall  Basic information on the rheinmetall GroupStru...
# 1         SiemensEnergy  Sustainability Report 2021 \n\nCreating transp...
# 2               Symrise  20 \n21 \n\nSustainability Record  \n(GRI) \n\...
# 3           Continetnal  Turn Change Into Opportunity – \nEmbrace Susta...
# 4          DeutscheBank  Deutsche Bank\n\n Non-Financial Report \n2021\...
# 5              Covestro  COMBINED \n MANAGEMENT REPORT\n\nCOMBINED MANA...
# 6                   MTU  Acting for tomorrow, today  \nOUR RESPONSIBILI...
# 7                 Bayer  Sustainability Report\n\n2021\n\n
# Contents \n\...
# 8       MuenchenerRueck  Sustainability \nReport 2021\n\n
# Munich Re  \n...
# 9               Zalando  Sustainability \nProgress Report\n2021\n\n
# Our...
# 10                  BMW  2MANAGEMENT REPORTCOMBINED34 Overview of the B...
# 11       DeutscheBoerse  Combined  \nmanagement report\n\n20\n\nWhat we...
# 12            Fresenius  SEPARATE  \nGROUP NON-FINANCIAL REPORT\n\n 115...
# 13               Adidas  1 \nTO OUR SHAREHOLDERS \n\n2 \nGROUP MANAGEME...
# 14           Beiersdorf  Sustainability Highlight Report\n\nCARE  \nBEY...
# 15        HannoverRueck  Sustainability Report 2021\n\n  \n
# 2\n\nHannov...
# 16              Allianz  Allianz Group Sustainability Report 2021\n\nBu...
# 17          Commerzbank  40 \n\nCommerzbank Annual Report 2021 \n\nComb...
# 18              Porsche  SUSTAINABILITY MANAGEMENT \nSustainability str...
# 19                 BASF  BASF Report 2021\n\nReport\n\n2 Management’s \...
# 20  HeidelbergMaterials  Company \nPortrait\n\nStrategy & \nManagement\...
# 21             Infineon  Sustainability at Infineon\nSupplementing the ...
# 22               Qiagen  1\n\nForeword\n\nOur Company\n\nEnvironment\n\...
# 23                  RWE  Focus \non tomorrow.\n\nSustainability Report ...
# 24               Airbus  Overview  /  Sustainability\n\n13\n\nPrioritis...
# 25           Volkswagen  SUSTAINABILITY REPORT\n\n2021\n\n
# NEW AUTO: VO...
# 26                  EON  #StandWithUkraine\n\nSustainability \nReport 2...
# 27         MercedesBenz  Sustainability Report 2021\n\nmaximum image ar...
# 28               Henkel  SUSTAINABILITY \nREPORT\n\n2021\n\n
# HENKEL SUS...
# 29              Siemens  Sustainability  report2021
# Our Purpose\n\n  Te...
# 30              Telekom  Corporate Responsibility \nBericht 2021\n\n
# 2\...
# 31                  SAP  SAP Integrated Report 2021 \n\nTo Our  \nStake...
# 32            Sartorius  Sartorius Stedim Biotech S.A. \n\nGRI Report 2...
# 33                  DHL  COMBINED MANAGEMENT REPORT NON-FINANCIAL  STAT...
# 34                Merck  Sustainability Report\n\n2021\n\n
# TABLE OF CON...
# 35              Vonovia  VONOVIA SE\nSUSTAINABILITY REPORT 2021\n\n=\n\...
# 36             Brenntag  S U S T A I N A B I L I T Y   R E P O R T\n202...
#
#                  datatype  date  internal title  \
# 0   Sustainability Report  2021         1   the
# 1   Sustainability Report  2021         1     ,
# 2   Sustainability Report  2021         1   the
# 3   Sustainability Report  2021         1   the
# 4   Sustainability Report  2021         1   and
# 5   Sustainability Report  2021         1   the
# 6   Sustainability Report  2021         1   the
# 7   Sustainability Report  2021         1   the
# 8   Sustainability Report  2021         1     .
# 9   Sustainability Report  2021         1     ,
# 10  Sustainability Report  2021         1   the
# 11  Sustainability Report  2021         1   the
# 12  Sustainability Report  2021         1   the
# 13  Sustainability Report  2021         1     ,
# 14  Sustainability Report  2021         1   our
# 15  Sustainability Report  2021         1   the
# 16  Sustainability Report  2021         1   and
# 17  Sustainability Report  2021         1   the
# 18  Sustainability Report  2021         1   the
# 19  Sustainability Report  2021         1   the
# 20  Sustainability Report  2021         1   the
# 21  Sustainability Report  2021         1   the
# 22  Sustainability Report  2021         1   and
# 23  Sustainability Report  2021         1   the
# 24  Sustainability Report  2021         1   the
# 25  Sustainability Report  2021         1   the
# 26  Sustainability Report  2021         1     ,
# 27  Sustainability Report  2021         1   the
# 28  Sustainability Report  2021         1   the
# 29  Sustainability Report  2021         1   the
# 30  Sustainability Report  2021         1     .
# 31  Sustainability Report  2021         1     ,
# 32  Sustainability Report  2021         1   the
# 33  Sustainability Report  2021         1   the
# 34  Sustainability Report  2021         1     ,
# 35  Sustainability Report  2021         1   the
# 36  Sustainability Report  2021         1   the
#
#                                       cleaned_content
# 0   basic information on the rheinmetall groupstru...
# 1   sustainability report 2021 creating transparen...
# 2   (gri) sustainability record 2021 uses the inte...
# 3   turn change into opportunity - embrace sustain...
# 4   deutsche bank non-financial report 2021 letter...
# 5   combined management report combined management...
# 6   acting for tomorrow, today our responsibility,...
# 7   sustainability report 2021 editorial ............
# 8   sustainability report 2021 re sustainability r...
# 9   sustainability progress report 2021 our progre...
# 10  2management reportcombined34 overview of the b...
# 11  combined management report 20 what we achieved...
# 12  separate group non-financial report 115 strate...
# 13  - our company 3 group management report - fina...
# 14  sustainability highlight report care beyond sk...
# 15  sustainability report 2021 2 hannover re | sus...
# 16  allianz group sustainability report 2021 build...
# 17  -financial report the directives stipulated by...
# 18  sustainability management sustainability strat...
# 19  basf report 2021 report 2 management's 52 17 o...
# 20  company portrait strategy & management busines...
# 21  sustainability at supplementing the annual rep...
# 22  .v. sustainy report qiagen sustainability repo...
# 23  focus on tomorrow. sustainability report 2021 ...
# 24  overview / sustainability 13 prioritising sust...
# 25  sustainability report 2021 new auto: volkswage...
# 26  #standwithukraine sustainability report 2021 s...
# 27  sustainability report 2021 maximum image aream...
# 28  sustainability report 2021 henkel sustainabili...
# 29  sustainability our purpose technology to trans...
# 30  corporate responsibility 2021 2 inhalt dieses ...
# 31  sap integrated report 2021 to our stakeholders...
# 32  stedim biotech s.a. gri report 2021 stedim bio...
# 33  combined management report non-financial state...
# 34  sustainability report 2021 strategy & manageme...
# 35  vonovia se sustainability report 2021 = for a ...
# 36  s you s t a i n a b i l i t y r e p o r t 2021...

# %%
# Expand custom abbreviations which are not captured by "contractions"
# Basic idea from: https://stackoverflow.com/questions/19790188/expanding-english-language-contractions-in-python
# Compile the regular expressions only once for efficiency
specific_patterns = [
    (re.compile(r"won['’]t"), "will not"),
    (re.compile(r"can['’]t"), "can not"),
]

def decontracted(phrase):
    """
    Expands contractions in a given phrase and returns the modified phrase and the count of contractions expanded.

    Args:
        phrase (str): The phrase to expand contractions in.

    Returns:
        tuple: A tuple containing the modified phrase (str) and the count of contractions expanded (int).
    """
    count = 0

    # Replace specific patterns
    for pattern, replacement in specific_patterns:
        matches = len(pattern.findall(phrase))
        count += matches
        phrase = pattern.sub(replacement, phrase)

    return phrase, count

# Apply the function to expand abbreviations
cleaned_data['cleaned_content'], abbreviation_counts = zip(*cleaned_data['cleaned_content'].apply(decontracted))
print("Expanded custom abbreviations:", sum(abbreviation_counts))
# Out:
# Expanded custom abbreviations: 0

# %%
cleaned_data.head(37)
# Out:
#                 company                                            content  \
# 0           Rheinmetall  Basic information on the rheinmetall GroupStru...
# 1         SiemensEnergy  Sustainability Report 2021 \n\nCreating transp...
# 2               Symrise  20 \n21 \n\nSustainability Record  \n(GRI) \n\...
# 3           Continetnal  Turn Change Into Opportunity – \nEmbrace Susta...
# 4          DeutscheBank  Deutsche Bank\n\n Non-Financial Report \n2021\...
# 5              Covestro  COMBINED \n MANAGEMENT REPORT\n\nCOMBINED MANA...
# 6                   MTU  Acting for tomorrow, today  \nOUR RESPONSIBILI...
# 7                 Bayer  Sustainability Report\n\n2021\n\n
# Contents \n\...
# 8       MuenchenerRueck  Sustainability \nReport 2021\n\n
# Munich Re  \n...
# 9               Zalando  Sustainability \nProgress Report\n2021\n\n
# Our...
# 10                  BMW  2MANAGEMENT REPORTCOMBINED34 Overview of the B...
# 11       DeutscheBoerse  Combined  \nmanagement report\n\n20\n\nWhat we...
# 12            Fresenius  SEPARATE  \nGROUP NON-FINANCIAL REPORT\n\n 115...
# 13               Adidas  1 \nTO OUR SHAREHOLDERS \n\n2 \nGROUP MANAGEME...
# 14           Beiersdorf  Sustainability Highlight Report\n\nCARE  \nBEY...
# 15        HannoverRueck  Sustainability Report 2021\n\n  \n
# 2\n\nHannov...
# 16              Allianz  Allianz Group Sustainability Report 2021\n\nBu...
# 17          Commerzbank  40 \n\nCommerzbank Annual Report 2021 \n\nComb...
# 18              Porsche  SUSTAINABILITY MANAGEMENT \nSustainability str...
# 19                 BASF  BASF Report 2021\n\nReport\n\n2 Management’s \...
# 20  HeidelbergMaterials  Company \nPortrait\n\nStrategy & \nManagement\...
# 21             Infineon  Sustainability at Infineon\nSupplementing the ...
# 22               Qiagen  1\n\nForeword\n\nOur Company\n\nEnvironment\n\...
# 23                  RWE  Focus \non tomorrow.\n\nSustainability Report ...
# 24               Airbus  Overview  /  Sustainability\n\n13\n\nPrioritis...
# 25           Volkswagen  SUSTAINABILITY REPORT\n\n2021\n\n
# NEW AUTO: VO...
# 26                  EON  #StandWithUkraine\n\nSustainability \nReport 2...
# 27         MercedesBenz  Sustainability Report 2021\n\nmaximum image ar...
# 28               Henkel  SUSTAINABILITY \nREPORT\n\n2021\n\n
# HENKEL SUS...
# 29              Siemens  Sustainability  report2021
# Our Purpose\n\n  Te...
# 30              Telekom  Corporate Responsibility \nBericht 2021\n\n
# 2\...
# 31                  SAP  SAP Integrated Report 2021 \n\nTo Our  \nStake...
# 32            Sartorius  Sartorius Stedim Biotech S.A. \n\nGRI Report 2...
# 33                  DHL  COMBINED MANAGEMENT REPORT NON-FINANCIAL  STAT...
# 34                Merck  Sustainability Report\n\n2021\n\n
# TABLE OF CON...
# 35              Vonovia  VONOVIA SE\nSUSTAINABILITY REPORT 2021\n\n=\n\...
# 36             Brenntag  S U S T A I N A B I L I T Y   R E P O R T\n202...
#
#                  datatype  date  internal title  \
# 0   Sustainability Report  2021         1   the
# 1   Sustainability Report  2021         1     ,
# 2   Sustainability Report  2021         1   the
# 3   Sustainability Report  2021         1   the
# 4   Sustainability Report  2021         1   and
# 5   Sustainability Report  2021         1   the
# 6   Sustainability Report  2021         1   the
# 7   Sustainability Report  2021         1   the
# 8   Sustainability Report  2021         1     .
# 9   Sustainability Report  2021         1     ,
# 10  Sustainability Report  2021         1   the
# 11  Sustainability Report  2021         1   the
# 12  Sustainability Report  2021         1   the
# 13  Sustainability Report  2021         1     ,
# 14  Sustainability Report  2021         1   our
# 15  Sustainability Report  2021         1   the
# 16  Sustainability Report  2021         1   and
# 17  Sustainability Report  2021         1   the
# 18  Sustainability Report  2021         1   the
# 19  Sustainability Report  2021         1   the
# 20  Sustainability Report  2021         1   the
# 21  Sustainability Report  2021         1   the
# 22  Sustainability Report  2021         1   and
# 23  Sustainability Report  2021         1   the
# 24  Sustainability Report  2021         1   the
# 25  Sustainability Report  2021         1   the
# 26  Sustainability Report  2021         1     ,
# 27  Sustainability Report  2021         1   the
# 28  Sustainability Report  2021         1   the
# 29  Sustainability Report  2021         1   the
# 30  Sustainability Report  2021         1     .
# 31  Sustainability Report  2021         1     ,
# 32  Sustainability Report  2021         1   the
# 33  Sustainability Report  2021         1   the
# 34  Sustainability Report  2021         1     ,
# 35  Sustainability Report  2021         1   the
# 36  Sustainability Report  2021         1   the
#
#                                       cleaned_content
# 0   basic information on the rheinmetall groupstru...
# 1   sustainability report 2021 creating transparen...
# 2   (gri) sustainability record 2021 uses the inte...
# 3   turn change into opportunity - embrace sustain...
# 4   deutsche bank non-financial report 2021 letter...
# 5   combined management report combined management...
# 6   acting for tomorrow, today our responsibility,...
# 7   sustainability report 2021 editorial ............
# 8   sustainability report 2021 re sustainability r...
# 9   sustainability progress report 2021 our progre...
# 10  2management reportcombined34 overview of the b...
# 11  combined management report 20 what we achieved...
# 12  separate group non-financial report 115 strate...
# 13  - our company 3 group management report - fina...
# 14  sustainability highlight report care beyond sk...
# 15  sustainability report 2021 2 hannover re | sus...
# 16  allianz group sustainability report 2021 build...
# 17  -financial report the directives stipulated by...
# 18  sustainability management sustainability strat...
# 19  basf report 2021 report 2 management's 52 17 o...
# 20  company portrait strategy & management busines...
# 21  sustainability at supplementing the annual rep...
# 22  .v. sustainy report qiagen sustainability repo...
# 23  focus on tomorrow. sustainability report 2021 ...
# 24  overview / sustainability 13 prioritising sust...
# 25  sustainability report 2021 new auto: volkswage...
# 26  #standwithukraine sustainability report 2021 s...
# 27  sustainability report 2021 maximum image aream...
# 28  sustainability report 2021 henkel sustainabili...
# 29  sustainability our purpose technology to trans...
# 30  corporate responsibility 2021 2 inhalt dieses ...
# 31  sap integrated report 2021 to our stakeholders...
# 32  stedim biotech s.a. gri report 2021 stedim bio...
# 33  combined management report non-financial state...
# 34  sustainability report 2021 strategy & manageme...
# 35  vonovia se sustainability report 2021 = for a ...
# 36  s you s t a i n a b i l i t y r e p o r t 2021...

# %%
# Remove special characters excl. punctuation since this is needed by the sentence tokenization
def remove_non_alphanumeric(text, remove_punctuation=False):
    if remove_punctuation:
        pattern = r'[^a-zA-Z0-9\s]'
    else:
        pattern = r'[^a-zA-Z0-9\s.,!?\'"]'
    
    special_chars = re.findall(pattern, text)
    return re.sub(pattern, '', text), len(special_chars)

cleaned_data['cleaned_content'], special_char_count = zip(*cleaned_data['cleaned_content'].apply(remove_non_alphanumeric, remove_punctuation=False))
print("Special characters excl. punctuation removed:", sum(special_char_count))
# Out:
# Special characters excl. punctuation removed: 139270

# %%
cleaned_data.shape
# Out:
# (37, 7)

# %%
def tokenize_words(text):
    # Remove numbers, digits, and punctuation
    text = re.sub(r'\b\d+\b', '', text)
    text = re.sub(r'[^\w\s]', '', text)

    # Tokenize words
    tokens = word_tokenize(text)

    # Lemmatize words
    lemmatizer = WordNetLemmatizer()
    tokens = [lemmatizer.lemmatize(token) for token in tokens]
    
    return tokens, len(tokens)

cleaned_data['word_tokens'], word_token_count = zip(*cleaned_data['cleaned_content'].apply(tokenize_words))
print("Generated word token amount:", sum(word_token_count))
# Out:
# Generated word token amount: 1915665

# %%
cleaned_data.head(37)
# Out:
#                 company                                            content  \
# 0           Rheinmetall  Basic information on the rheinmetall GroupStru...
# 1         SiemensEnergy  Sustainability Report 2021 \n\nCreating transp...
# 2               Symrise  20 \n21 \n\nSustainability Record  \n(GRI) \n\...
# 3           Continetnal  Turn Change Into Opportunity – \nEmbrace Susta...
# 4          DeutscheBank  Deutsche Bank\n\n Non-Financial Report \n2021\...
# 5              Covestro  COMBINED \n MANAGEMENT REPORT\n\nCOMBINED MANA...
# 6                   MTU  Acting for tomorrow, today  \nOUR RESPONSIBILI...
# 7                 Bayer  Sustainability Report\n\n2021\n\n
# Contents \n\...
# 8       MuenchenerRueck  Sustainability \nReport 2021\n\n
# Munich Re  \n...
# 9               Zalando  Sustainability \nProgress Report\n2021\n\n
# Our...
# 10                  BMW  2MANAGEMENT REPORTCOMBINED34 Overview of the B...
# 11       DeutscheBoerse  Combined  \nmanagement report\n\n20\n\nWhat we...
# 12            Fresenius  SEPARATE  \nGROUP NON-FINANCIAL REPORT\n\n 115...
# 13               Adidas  1 \nTO OUR SHAREHOLDERS \n\n2 \nGROUP MANAGEME...
# 14           Beiersdorf  Sustainability Highlight Report\n\nCARE  \nBEY...
# 15        HannoverRueck  Sustainability Report 2021\n\n  \n
# 2\n\nHannov...
# 16              Allianz  Allianz Group Sustainability Report 2021\n\nBu...
# 17          Commerzbank  40 \n\nCommerzbank Annual Report 2021 \n\nComb...
# 18              Porsche  SUSTAINABILITY MANAGEMENT \nSustainability str...
# 19                 BASF  BASF Report 2021\n\nReport\n\n2 Management’s \...
# 20  HeidelbergMaterials  Company \nPortrait\n\nStrategy & \nManagement\...
# 21             Infineon  Sustainability at Infineon\nSupplementing the ...
# 22               Qiagen  1\n\nForeword\n\nOur Company\n\nEnvironment\n\...
# 23                  RWE  Focus \non tomorrow.\n\nSustainability Report ...
# 24               Airbus  Overview  /  Sustainability\n\n13\n\nPrioritis...
# 25           Volkswagen  SUSTAINABILITY REPORT\n\n2021\n\n
# NEW AUTO: VO...
# 26                  EON  #StandWithUkraine\n\nSustainability \nReport 2...
# 27         MercedesBenz  Sustainability Report 2021\n\nmaximum image ar...
# 28               Henkel  SUSTAINABILITY \nREPORT\n\n2021\n\n
# HENKEL SUS...
# 29              Siemens  Sustainability  report2021
# Our Purpose\n\n  Te...
# 30              Telekom  Corporate Responsibility \nBericht 2021\n\n
# 2\...
# 31                  SAP  SAP Integrated Report 2021 \n\nTo Our  \nStake...
# 32            Sartorius  Sartorius Stedim Biotech S.A. \n\nGRI Report 2...
# 33                  DHL  COMBINED MANAGEMENT REPORT NON-FINANCIAL  STAT...
# 34                Merck  Sustainability Report\n\n2021\n\n
# TABLE OF CON...
# 35              Vonovia  VONOVIA SE\nSUSTAINABILITY REPORT 2021\n\n=\n\...
# 36             Brenntag  S U S T A I N A B I L I T Y   R E P O R T\n202...
#
#                  datatype  date  internal title  \
# 0   Sustainability Report  2021         1   the
# 1   Sustainability Report  2021         1     ,
# 2   Sustainability Report  2021         1   the
# 3   Sustainability Report  2021         1   the
# 4   Sustainability Report  2021         1   and
# 5   Sustainability Report  2021         1   the
# 6   Sustainability Report  2021         1   the
# 7   Sustainability Report  2021         1   the
# 8   Sustainability Report  2021         1     .
# 9   Sustainability Report  2021         1     ,
# 10  Sustainability Report  2021         1   the
# 11  Sustainability Report  2021         1   the
# 12  Sustainability Report  2021         1   the
# 13  Sustainability Report  2021         1     ,
# 14  Sustainability Report  2021         1   our
# 15  Sustainability Report  2021         1   the
# 16  Sustainability Report  2021         1   and
# 17  Sustainability Report  2021         1   the
# 18  Sustainability Report  2021         1   the
# 19  Sustainability Report  2021         1   the
# 20  Sustainability Report  2021         1   the
# 21  Sustainability Report  2021         1   the
# 22  Sustainability Report  2021         1   and
# 23  Sustainability Report  2021         1   the
# 24  Sustainability Report  2021         1   the
# 25  Sustainability Report  2021         1   the
# 26  Sustainability Report  2021         1     ,
# 27  Sustainability Report  2021         1   the
# 28  Sustainability Report  2021         1   the
# 29  Sustainability Report  2021         1   the
# 30  Sustainability Report  2021         1     .
# 31  Sustainability Report  2021         1     ,
# 32  Sustainability Report  2021         1   the
# 33  Sustainability Report  2021         1   the
# 34  Sustainability Report  2021         1     ,
# 35  Sustainability Report  2021         1   the
# 36  Sustainability Report  2021         1   the
#
#                                       cleaned_content  \
# 0   basic information on the rheinmetall groupstru...
# 1   sustainability report 2021 creating transparen...
# 2   gri sustainability record 2021 uses the intern...
# 3   turn change into opportunity  embrace sustaina...
# 4   deutsche bank nonfinancial report 2021 letter ...
# 5   combined management report combined management...
# 6   acting for tomorrow, today our responsibility,...
# 7   sustainability report 2021 editorial ............
# 8   sustainability report 2021 re sustainability r...
# 9   sustainability progress report 2021 our progre...
# 10  2management reportcombined34 overview of the b...
# 11  combined management report 20 what we achieved...
# 12  separate group nonfinancial report 115 strateg...
# 13   our company 3 group management report  financ...
# 14  sustainability highlight report care beyond sk...
# 15  sustainability report 2021 2 hannover re  sust...
# 16  allianz group sustainability report 2021 build...
# 17  financial report the directives stipulated by ...
# 18  sustainability management sustainability strat...
# 19  basf report 2021 report 2 management's 52 17 o...
# 20  company portrait strategy  management business...
# 21  sustainability at supplementing the annual rep...
# 22  .v. sustainy report qiagen sustainability repo...
# 23  focus on tomorrow. sustainability report 2021 ...
# 24  overview  sustainability 13 prioritising susta...
# 25  sustainability report 2021 new auto volkswagen...
# 26  standwithukraine sustainability report 2021 se...
# 27  sustainability report 2021 maximum image aream...
# 28  sustainability report 2021 henkel sustainabili...
# 29  sustainability our purpose technology to trans...
# 30  corporate responsibility 2021 2 inhalt dieses ...
# 31  sap integrated report 2021 to our stakeholders...
# 32  stedim biotech s.a. gri report 2021 stedim bio...
# 33  combined management report nonfinancial statem...
# 34  sustainability report 2021 strategy  managemen...
# 35  vonovia se sustainability report 2021  for a s...
# 36  s you s t a i n a b i l i t y r e p o r t 2021...
#
#                                           word_tokens
# 0   [basic, information, on, the, rheinmetall, gro...
# 1   [sustainability, report, creating, transparenc...
# 2   [gri, sustainability, record, us, the, interna...
# 3   [turn, change, into, opportunity, embrace, sus...
# 4   [deutsche, bank, nonfinancial, report, letter,...
# 5   [combined, management, report, combined, manag...
# 6   [acting, for, tomorrow, today, our, responsibi...
# 7   [sustainability, report, editorial, about, thi...
# 8   [sustainability, report, re, sustainability, r...
# 9   [sustainability, progress, report, our, progre...
# 10  anagement, reportcombined34, overview, of, ...
# 11  [combined, management, report, what, we, achie...
# 12  [separate, group, nonfinancial, report, strate...
# 13  [our, company, group, management, report, fina...
# 14  [sustainability, highlight, report, care, beyo...
# 15  [sustainability, report, hannover, re, sustain...
# 16  [allianz, group, sustainability, report, build...
# 17  [financial, report, the, directive, stipulated...
# 18  [sustainability, management, sustainability, s...
# 19  [basf, report, report, management, overview, n...
# 20  [company, portrait, strategy, management, busi...
# 21  [sustainability, at, supplementing, the, annua...
# 22  [v, sustainy, report, qiagen, sustainability, ...
# 23  [focus, on, tomorrow, sustainability, report, ...
# 24  [overview, sustainability, prioritising, susta...
# 25  [sustainability, report, new, auto, volkswagen...
# 26  [standwithukraine, sustainability, report, sea...
# 27  [sustainability, report, maximum, image, aream...
# 28  [sustainability, report, henkel, sustainabilit...
# 29  [sustainability, our, purpose, technology, to,...
# 30  [corporate, responsibility, inhalt, diesis, pd...
# 31  [sap, integrated, report, to, our, stakeholder...
# 32  [stedim, biotech, sa, gri, report, stedim, bio...
# 33  [combined, management, report, nonfinancial, s...
# 34  [sustainability, report, strategy, management,...
# 35  [vonovia, se, sustainability, report, for, a, ...
# 36  [s, you, s, t, a, i, n, a, b, i, l, i, t, y, r...

# %%
def tokenize_sentences(text):
    # Tokenize sentences
    tokens = sent_tokenize(text)
    
    return tokens, len(tokens)

cleaned_data['sentence_tokens'], sentence_token_count = zip(*cleaned_data['cleaned_content'].apply(tokenize_sentences))
print("Generated sentence token amount:", sum(sentence_token_count))
# Out:
# Generated sentence token amount: 74950

# %%
cleaned_data.head(37)
# Out:
#                 company                                            content  \
# 0           Rheinmetall  Basic information on the rheinmetall GroupStru...
# 1         SiemensEnergy  Sustainability Report 2021 \n\nCreating transp...
# 2               Symrise  20 \n21 \n\nSustainability Record  \n(GRI) \n\...
# 3           Continetnal  Turn Change Into Opportunity – \nEmbrace Susta...
# 4          DeutscheBank  Deutsche Bank\n\n Non-Financial Report \n2021\...
# 5              Covestro  COMBINED \n MANAGEMENT REPORT\n\nCOMBINED MANA...
# 6                   MTU  Acting for tomorrow, today  \nOUR RESPONSIBILI...
# 7                 Bayer  Sustainability Report\n\n2021\n\n
# Contents \n\...
# 8       MuenchenerRueck  Sustainability \nReport 2021\n\n
# Munich Re  \n...
# 9               Zalando  Sustainability \nProgress Report\n2021\n\n
# Our...
# 10                  BMW  2MANAGEMENT REPORTCOMBINED34 Overview of the B...
# 11       DeutscheBoerse  Combined  \nmanagement report\n\n20\n\nWhat we...
# 12            Fresenius  SEPARATE  \nGROUP NON-FINANCIAL REPORT\n\n 115...
# 13               Adidas  1 \nTO OUR SHAREHOLDERS \n\n2 \nGROUP MANAGEME...
# 14           Beiersdorf  Sustainability Highlight Report\n\nCARE  \nBEY...
# 15        HannoverRueck  Sustainability Report 2021\n\n  \n
# 2\n\nHannov...
# 16              Allianz  Allianz Group Sustainability Report 2021\n\nBu...
# 17          Commerzbank  40 \n\nCommerzbank Annual Report 2021 \n\nComb...
# 18              Porsche  SUSTAINABILITY MANAGEMENT \nSustainability str...
# 19                 BASF  BASF Report 2021\n\nReport\n\n2 Management’s \...
# 20  HeidelbergMaterials  Company \nPortrait\n\nStrategy & \nManagement\...
# 21             Infineon  Sustainability at Infineon\nSupplementing the ...
# 22               Qiagen  1\n\nForeword\n\nOur Company\n\nEnvironment\n\...
# 23                  RWE  Focus \non tomorrow.\n\nSustainability Report ...
# 24               Airbus  Overview  /  Sustainability\n\n13\n\nPrioritis...
# 25           Volkswagen  SUSTAINABILITY REPORT\n\n2021\n\n
# NEW AUTO: VO...
# 26                  EON  #StandWithUkraine\n\nSustainability \nReport 2...
# 27         MercedesBenz  Sustainability Report 2021\n\nmaximum image ar...
# 28               Henkel  SUSTAINABILITY \nREPORT\n\n2021\n\n
# HENKEL SUS...
# 29              Siemens  Sustainability  report2021
# Our Purpose\n\n  Te...
# 30              Telekom  Corporate Responsibility \nBericht 2021\n\n
# 2\...
# 31                  SAP  SAP Integrated Report 2021 \n\nTo Our  \nStake...
# 32            Sartorius  Sartorius Stedim Biotech S.A. \n\nGRI Report 2...
# 33                  DHL  COMBINED MANAGEMENT REPORT NON-FINANCIAL  STAT...
# 34                Merck  Sustainability Report\n\n2021\n\n
# TABLE OF CON...
# 35              Vonovia  VONOVIA SE\nSUSTAINABILITY REPORT 2021\n\n=\n\...
# 36             Brenntag  S U S T A I N A B I L I T Y   R E P O R T\n202...
#
#                  datatype  date  internal title  \
# 0   Sustainability Report  2021         1   the
# 1   Sustainability Report  2021         1     ,
# 2   Sustainability Report  2021         1   the
# 3   Sustainability Report  2021         1   the
# 4   Sustainability Report  2021         1   and
# 5   Sustainability Report  2021         1   the
# 6   Sustainability Report  2021         1   the
# 7   Sustainability Report  2021         1   the
# 8   Sustainability Report  2021         1     .
# 9   Sustainability Report  2021         1     ,
# 10  Sustainability Report  2021         1   the
# 11  Sustainability Report  2021         1   the
# 12  Sustainability Report  2021         1   the
# 13  Sustainability Report  2021         1     ,
# 14  Sustainability Report  2021         1   our
# 15  Sustainability Report  2021         1   the
# 16  Sustainability Report  2021         1   and
# 17  Sustainability Report  2021         1   the
# 18  Sustainability Report  2021         1   the
# 19  Sustainability Report  2021         1   the
# 20  Sustainability Report  2021         1   the
# 21  Sustainability Report  2021         1   the
# 22  Sustainability Report  2021         1   and
# 23  Sustainability Report  2021         1   the
# 24  Sustainability Report  2021         1   the
# 25  Sustainability Report  2021         1   the
# 26  Sustainability Report  2021         1     ,
# 27  Sustainability Report  2021         1   the
# 28  Sustainability Report  2021         1   the
# 29  Sustainability Report  2021         1   the
# 30  Sustainability Report  2021         1     .
# 31  Sustainability Report  2021         1     ,
# 32  Sustainability Report  2021         1   the
# 33  Sustainability Report  2021         1   the
# 34  Sustainability Report  2021         1     ,
# 35  Sustainability Report  2021         1   the
# 36  Sustainability Report  2021         1   the
#
#                                       cleaned_content  \
# 0   basic information on the rheinmetall groupstru...
# 1   sustainability report 2021 creating transparen...
# 2   gri sustainability record 2021 uses the intern...
# 3   turn change into opportunity  embrace sustaina...
# 4   deutsche bank nonfinancial report 2021 letter ...
# 5   combined management report combined management...
# 6   acting for tomorrow, today our responsibility,...
# 7   sustainability report 2021 editorial ............
# 8   sustainability report 2021 re sustainability r...
# 9   sustainability progress report 2021 our progre...
# 10  2management reportcombined34 overview of the b...
# 11  combined management report 20 what we achieved...
# 12  separate group nonfinancial report 115 strateg...
# 13   our company 3 group management report  financ...
# 14  sustainability highlight report care beyond sk...
# 15  sustainability report 2021 2 hannover re  sust...
# 16  allianz group sustainability report 2021 build...
# 17  financial report the directives stipulated by ...
# 18  sustainability management sustainability strat...
# 19  basf report 2021 report 2 management's 52 17 o...
# 20  company portrait strategy  management business...
# 21  sustainability at supplementing the annual rep...
# 22  .v. sustainy report qiagen sustainability repo...
# 23  focus on tomorrow. sustainability report 2021 ...
# 24  overview  sustainability 13 prioritising susta...
# 25  sustainability report 2021 new auto volkswagen...
# 26  standwithukraine sustainability report 2021 se...
# 27  sustainability report 2021 maximum image aream...
# 28  sustainability report 2021 henkel sustainabili...
# 29  sustainability our purpose technology to trans...
# 30  corporate responsibility 2021 2 inhalt dieses ...
# 31  sap integrated report 2021 to our stakeholders...
# 32  stedim biotech s.a. gri report 2021 stedim bio...
# 33  combined management report nonfinancial statem...
# 34  sustainability report 2021 strategy  managemen...
# 35  vonovia se sustainability report 2021  for a s...
# 36  s you s t a i n a b i l i t y r e p o r t 2021...
#
#                                           word_tokens  \
# 0   [basic, information, on, the, rheinmetall, gro...
# 1   [sustainability, report, creating, transparenc...
# 2   [gri, sustainability, record, us, the, interna...
# 3   [turn, change, into, opportunity, embrace, sus...
# 4   [deutsche, bank, nonfinancial, report, letter,...
# 5   [combined, management, report, combined, manag...
# 6   [acting, for, tomorrow, today, our, responsibi...
# 7   [sustainability, report, editorial, about, thi...
# 8   [sustainability, report, re, sustainability, r...
# 9   [sustainability, progress, report, our, progre...
# 10  anagement, reportcombined34, overview, of, ...
# 11  [combined, management, report, what, we, achie...
# 12  [separate, group, nonfinancial, report, strate...
# 13  [our, company, group, management, report, fina...
# 14  [sustainability, highlight, report, care, beyo...
# 15  [sustainability, report, hannover, re, sustain...
# 16  [allianz, group, sustainability, report, build...
# 17  [financial, report, the, directive, stipulated...
# 18  [sustainability, management, sustainability, s...
# 19  [basf, report, report, management, overview, n...
# 20  [company, portrait, strategy, management, busi...
# 21  [sustainability, at, supplementing, the, annua...
# 22  [v, sustainy, report, qiagen, sustainability, ...
# 23  [focus, on, tomorrow, sustainability, report, ...
# 24  [overview, sustainability, prioritising, susta...
# 25  [sustainability, report, new, auto, volkswagen...
# 26  [standwithukraine, sustainability, report, sea...
# 27  [sustainability, report, maximum, image, aream...
# 28  [sustainability, report, henkel, sustainabilit...
# 29  [sustainability, our, purpose, technology, to,...
# 30  [corporate, responsibility, inhalt, diesis, pd...
# 31  [sap, integrated, report, to, our, stakeholder...
# 32  [stedim, biotech, sa, gri, report, stedim, bio...
# 33  [combined, management, report, nonfinancial, s...
# 34  [sustainability, report, strategy, management,...
# 35  [vonovia, se, sustainability, report, for, a, ...
# 36  [s, you, s, t, a, i, n, a, b, i, l, i, t, y, r...
#
#                                       sentence_tokens
# 0   [basic information on the rheinmetall groupstr...
# 1   [sustainability report 2021 creating transpare...
# 2   [gri sustainability record 2021 uses the inter...
# 3   [turn change into opportunity  embrace sustain...
# 4   [deutsche bank nonfinancial report 2021 letter...
# 5   [combined management report combined managemen...
# 6   [acting for tomorrow, today our responsibility...
# 7   [sustainability report 2021 editorial ...........
# 8   [sustainability report 2021 re sustainability ...
# 9   [sustainability progress report 2021 our progr...
# 10  anagement reportcombined34 overview of the ...
# 11  [combined management report 20 what we achieve...
# 12  [separate group nonfinancial report 115 strate...
# 13  [ our company 3 group management report  finan...
# 14  [sustainability highlight report care beyond s...
# 15  [sustainability report 2021 2 hannover re  sus...
# 16  [allianz group sustainability report 2021 buil...
# 17  [financial report the directives stipulated by...
# 18  [sustainability management sustainability stra...
# 19  [basf report 2021 report 2 management's 52 17 ...
# 20  [company portrait strategy  management busines...
# 21  [sustainability at supplementing the annual re...
# 22  [.v., sustainy report qiagen sustainability re...
# 23  [focus on tomorrow., sustainability report 202...
# 24  [overview  sustainability 13 prioritising sust...
# 25  [sustainability report 2021 new auto volkswage...
# 26  [standwithukraine sustainability report 2021 s...
# 27  [sustainability report 2021 maximum image area...
# 28  [sustainability report 2021 henkel sustainabil...
# 29  [sustainability our purpose technology to tran...
# 30  [corporate responsibility 2021 2 inhalt dieses...
# 31  [sap integrated report 2021 to our stakeholder...
# 32  [stedim biotech s.a. gri report 2021 stedim bi...
# 33  [combined management report nonfinancial state...
# 34  [sustainability report 2021 strategy  manageme...
# 35  [vonovia se sustainability report 2021  for a ...
# 36  [s you s t a i n a b i l i t y r e p o r t 202...

# %%
def remove_stopwords_from_word_tokens(tokens, custom_stopwords):
    """
    Removes stopwords and one-character tokens from a list of word tokens and returns the modified list and the count of removed items.

    Args:
        tokens (list): The list of word tokens to remove stopwords from.
        custom_stopwords (list): A list of custom stopwords to remove from the word tokens.

    Returns:
        tuple: A tuple containing the modified list of word tokens (list) and the count of removed items (int).
    """
    filtered_tokens = [
        token for token in tokens
        if token.lower() not in custom_stopwords and len(token) > 1
    ]
    
    return filtered_tokens, len(tokens) - len(filtered_tokens)

def remove_stopwords_from_sentence_tokens(sentences_list, custom_stopwords):
    """
    Removes stopwords, one-character tokens, digits, numbers, and special characters (excluding whitespace) from a list of sentence tokens and returns the modified list and the count of removed items.

    Args:
        sentences_list (list): The list of sentence tokens to remove stopwords from.
        custom_stopwords (list): A list of custom stopwords to remove from the sentence tokens.

    Returns:
        tuple: A tuple containing the modified list of sentence tokens (list) and the count of removed items (int).
    """
    filtered_sentences_list = []
    total_removed_items_count = 0

    for sentence in sentences_list:
        # Tokenize the sentence into words
        word_tokens = word_tokenize(sentence)

        # Remove stopwords, one-character tokens, digits, numbers, and special characters (excluding whitespace) from word tokens
        filtered_word_tokens = [
            re.sub(rf"[{re.escape(string.punctuation)}]", '', token) for token in word_tokens
            if token.lower() not in custom_stopwords
            and len(token) > 1
            and not re.search(r'\d', token)
            and not re.search(r'\W', token)
        ]

        # Reconstruct the sentence without the removed words and special characters
        filtered_sentence = ' '.join(filtered_word_tokens)
        removed_items_count = len(word_tokens) - len(filtered_word_tokens)
        filtered_sentences_list.append(filtered_sentence)
        total_removed_items_count += removed_items_count

    return filtered_sentences_list, total_removed_items_count

# Define custom stopwords to add or remove (the extra stopwords were identified by the TFIDF based wordcloud)
custom_stopwords = {
    'add': ['said','company','companies','year','billion','million','siemens','linde','rwe','volkswagen','symrise','porsche','sap','adidas','puma','airbus','bmw','hannover','mtu','heiderbergcement','qiagen','benz','continental','bayer','fresenius','wa', 'ha', 'eur', 'allianz', 'board'],
    'remove': [''] # Currently not needed
}

# Combine stopwords to filter the content of the reports
all_stopwords = set(stopwords.words('english'))
all_stopwords |= set(custom_stopwords['add'])
all_stopwords -= set(custom_stopwords['remove'])

cleaned_data['word_tokens'], stopword_count_words = zip(*cleaned_data['word_tokens'].apply(remove_stopwords_from_word_tokens, custom_stopwords=all_stopwords))
cleaned_data['sentence_tokens'], stopword_count_sentences = zip(*cleaned_data['sentence_tokens'].apply(remove_stopwords_from_sentence_tokens, custom_stopwords=all_stopwords))

print("Removed stopwords in word tokens", sum(stopword_count_words))
print("Removed stopwords in sentence tokens", sum(stopword_count_sentences))
# Out:
# Removed stopwords in word tokens 747313
# Removed stopwords in sentence tokens 1016610

# %%
cleaned_data.head(37)
# Out:
#                 company                                            content  \
# 0           Rheinmetall  Basic information on the rheinmetall GroupStru...
# 1         SiemensEnergy  Sustainability Report 2021 \n\nCreating transp...
# 2               Symrise  20 \n21 \n\nSustainability Record  \n(GRI) \n\...
# 3           Continetnal  Turn Change Into Opportunity – \nEmbrace Susta...
# 4          DeutscheBank  Deutsche Bank\n\n Non-Financial Report \n2021\...
# 5              Covestro  COMBINED \n MANAGEMENT REPORT\n\nCOMBINED MANA...
# 6                   MTU  Acting for tomorrow, today  \nOUR RESPONSIBILI...
# 7                 Bayer  Sustainability Report\n\n2021\n\n
# Contents \n\...
# 8       MuenchenerRueck  Sustainability \nReport 2021\n\n
# Munich Re  \n...
# 9               Zalando  Sustainability \nProgress Report\n2021\n\n
# Our...
# 10                  BMW  2MANAGEMENT REPORTCOMBINED34 Overview of the B...
# 11       DeutscheBoerse  Combined  \nmanagement report\n\n20\n\nWhat we...
# 12            Fresenius  SEPARATE  \nGROUP NON-FINANCIAL REPORT\n\n 115...
# 13               Adidas  1 \nTO OUR SHAREHOLDERS \n\n2 \nGROUP MANAGEME...
# 14           Beiersdorf  Sustainability Highlight Report\n\nCARE  \nBEY...
# 15        HannoverRueck  Sustainability Report 2021\n\n  \n
# 2\n\nHannov...
# 16              Allianz  Allianz Group Sustainability Report 2021\n\nBu...
# 17          Commerzbank  40 \n\nCommerzbank Annual Report 2021 \n\nComb...
# 18              Porsche  SUSTAINABILITY MANAGEMENT \nSustainability str...
# 19                 BASF  BASF Report 2021\n\nReport\n\n2 Management’s \...
# 20  HeidelbergMaterials  Company \nPortrait\n\nStrategy & \nManagement\...
# 21             Infineon  Sustainability at Infineon\nSupplementing the ...
# 22               Qiagen  1\n\nForeword\n\nOur Company\n\nEnvironment\n\...
# 23                  RWE  Focus \non tomorrow.\n\nSustainability Report ...
# 24               Airbus  Overview  /  Sustainability\n\n13\n\nPrioritis...
# 25           Volkswagen  SUSTAINABILITY REPORT\n\n2021\n\n
# NEW AUTO: VO...
# 26                  EON  #StandWithUkraine\n\nSustainability \nReport 2...
# 27         MercedesBenz  Sustainability Report 2021\n\nmaximum image ar...
# 28               Henkel  SUSTAINABILITY \nREPORT\n\n2021\n\n
# HENKEL SUS...
# 29              Siemens  Sustainability  report2021
# Our Purpose\n\n  Te...
# 30              Telekom  Corporate Responsibility \nBericht 2021\n\n
# 2\...
# 31                  SAP  SAP Integrated Report 2021 \n\nTo Our  \nStake...
# 32            Sartorius  Sartorius Stedim Biotech S.A. \n\nGRI Report 2...
# 33                  DHL  COMBINED MANAGEMENT REPORT NON-FINANCIAL  STAT...
# 34                Merck  Sustainability Report\n\n2021\n\n
# TABLE OF CON...
# 35              Vonovia  VONOVIA SE\nSUSTAINABILITY REPORT 2021\n\n=\n\...
# 36             Brenntag  S U S T A I N A B I L I T Y   R E P O R T\n202...
#
#                  datatype  date  internal title  \
# 0   Sustainability Report  2021         1   the
# 1   Sustainability Report  2021         1     ,
# 2   Sustainability Report  2021         1   the
# 3   Sustainability Report  2021         1   the
# 4   Sustainability Report  2021         1   and
# 5   Sustainability Report  2021         1   the
# 6   Sustainability Report  2021         1   the
# 7   Sustainability Report  2021         1   the
# 8   Sustainability Report  2021         1     .
# 9   Sustainability Report  2021         1     ,
# 10  Sustainability Report  2021         1   the
# 11  Sustainability Report  2021         1   the
# 12  Sustainability Report  2021         1   the
# 13  Sustainability Report  2021         1     ,
# 14  Sustainability Report  2021         1   our
# 15  Sustainability Report  2021         1   the
# 16  Sustainability Report  2021         1   and
# 17  Sustainability Report  2021         1   the
# 18  Sustainability Report  2021         1   the
# 19  Sustainability Report  2021         1   the
# 20  Sustainability Report  2021         1   the
# 21  Sustainability Report  2021         1   the
# 22  Sustainability Report  2021         1   and
# 23  Sustainability Report  2021         1   the
# 24  Sustainability Report  2021         1   the
# 25  Sustainability Report  2021         1   the
# 26  Sustainability Report  2021         1     ,
# 27  Sustainability Report  2021         1   the
# 28  Sustainability Report  2021         1   the
# 29  Sustainability Report  2021         1   the
# 30  Sustainability Report  2021         1     .
# 31  Sustainability Report  2021         1     ,
# 32  Sustainability Report  2021         1   the
# 33  Sustainability Report  2021         1   the
# 34  Sustainability Report  2021         1     ,
# 35  Sustainability Report  2021         1   the
# 36  Sustainability Report  2021         1   the
#
#                                       cleaned_content  \
# 0   basic information on the rheinmetall groupstru...
# 1   sustainability report 2021 creating transparen...
# 2   gri sustainability record 2021 uses the intern...
# 3   turn change into opportunity  embrace sustaina...
# 4   deutsche bank nonfinancial report 2021 letter ...
# 5   combined management report combined management...
# 6   acting for tomorrow, today our responsibility,...
# 7   sustainability report 2021 editorial ............
# 8   sustainability report 2021 re sustainability r...
# 9   sustainability progress report 2021 our progre...
# 10  2management reportcombined34 overview of the b...
# 11  combined management report 20 what we achieved...
# 12  separate group nonfinancial report 115 strateg...
# 13   our company 3 group management report  financ...
# 14  sustainability highlight report care beyond sk...
# 15  sustainability report 2021 2 hannover re  sust...
# 16  allianz group sustainability report 2021 build...
# 17  financial report the directives stipulated by ...
# 18  sustainability management sustainability strat...
# 19  basf report 2021 report 2 management's 52 17 o...
# 20  company portrait strategy  management business...
# 21  sustainability at supplementing the annual rep...
# 22  .v. sustainy report qiagen sustainability repo...
# 23  focus on tomorrow. sustainability report 2021 ...
# 24  overview  sustainability 13 prioritising susta...
# 25  sustainability report 2021 new auto volkswagen...
# 26  standwithukraine sustainability report 2021 se...
# 27  sustainability report 2021 maximum image aream...
# 28  sustainability report 2021 henkel sustainabili...
# 29  sustainability our purpose technology to trans...
# 30  corporate responsibility 2021 2 inhalt dieses ...
# 31  sap integrated report 2021 to our stakeholders...
# 32  stedim biotech s.a. gri report 2021 stedim bio...
# 33  combined management report nonfinancial statem...
# 34  sustainability report 2021 strategy  managemen...
# 35  vonovia se sustainability report 2021  for a s...
# 36  s you s t a i n a b i l i t y r e p o r t 2021...
#
#                                           word_tokens  \
# 0   [basic, information, rheinmetall, groupstructu...
# 1   [sustainability, report, creating, transparenc...
# 2   [gri, sustainability, record, us, internationa...
# 3   [turn, change, opportunity, embrace, sustainab...
# 4   [deutsche, bank, nonfinancial, report, letter,...
# 5   [combined, management, report, combined, manag...
# 6   [acting, tomorrow, today, responsibility, plan...
# 7   [sustainability, report, editorial, report, cr...
# 8   [sustainability, report, sustainability, repor...
# 9   [sustainability, progress, report, progress, g...
# 10  anagement, reportcombined34, overview, grou...
# 11  [combined, management, report, achieved, repor...
# 12  [separate, group, nonfinancial, report, strate...
# 13  [group, management, report, financial, review,...
# 14  [sustainability, highlight, report, care, beyo...
# 15  [sustainability, report, sustainability, repor...
# 16  [group, sustainability, report, building, conf...
# 17  [financial, report, directive, stipulated, com...
# 18  [sustainability, management, sustainability, s...
# 19  [basf, report, report, management, overview, n...
# 20  [portrait, strategy, management, business, com...
# 21  [sustainability, supplementing, annual, report...
# 22  [sustainy, report, sustainability, report, gov...
# 23  [focus, tomorrow, sustainability, report, ener...
# 24  [overview, sustainability, prioritising, susta...
# 25  [sustainability, report, new, auto, reinvents,...
# 26  [standwithukraine, sustainability, report, sea...
# 27  [sustainability, report, maximum, image, aream...
# 28  [sustainability, report, henkel, sustainabilit...
# 29  [sustainability, purpose, technology, transfor...
# 30  [corporate, responsibility, inhalt, diesis, pd...
# 31  [integrated, report, stakeholder, combined, gr...
# 32  [stedim, biotech, sa, gri, report, stedim, bio...
# 33  [combined, management, report, nonfinancial, s...
# 34  [sustainability, report, strategy, management,...
# 35  [vonovia, se, sustainability, report, sustaina...
# 36  [brenntag, se, sustainability, report, brennta...
#
#                                       sentence_tokens
# 0   [basic information rheinmetall groupstructure ...
# 1   [sustainability report creating transparency f...
# 2   [gri sustainability record uses international ...
# 3   [turn change opportunity embrace sustainabilit...
# 4   [deutsche bank nonfinancial report letter chie...
# 5   [combined management report combined managemen...
# 6   [acting tomorrow today responsibility plans su...
# 7   [sustainability report editorial report crop p...
# 8   [sustainability report sustainability report a...
# 9   [sustainability progress report progress glanc...
# 10  [overview organisational business model group ...
# 11  [combined management report achieved report de...
# 12  [separate group nonfinancial report strategy m...
# 13  [group management report financial review cons...
# 14  [sustainability highlight report care beyond s...
# 15  [sustainability report sustainability report u...
# 16  [group sustainability report building confiden...
# 17  [financial report directives stipulated commer...
# 18  [sustainability management sustainability stra...
# 19  [basf report report management overview nonfin...
# 20  [portrait strategy management business complia...
# 21  [sustainability supplementing annual report na...
# 22  [, sustainy report sustainability report gover...
# 23  [focus tomorrow, sustainability report energy ...
# 24  [overview sustainability prioritising sustaina...
# 25  [sustainability report new auto reinvents worl...
# 26  [standwithukraine sustainability report search...
# 27  [sustainability report maximum image areaminim...
# 28  [sustainability report henkel sustainability r...
# 29  [sustainability purpose technology transform e...
# 30  [corporate responsibility inhalt dieses pdfdok...
# 31  [integrated report stakeholders combined group...
# 32  [stedim biotech gri report stedim biotech gri ...
# 33  [combined management report nonfinancial state...
# 34  [sustainability report strategy management yee...
# 35  [vonovia se sustainability report sustainable ...
# 36  [brenntag se sustainability report brenntag wo...

# %%
# Update the cleaned content based on the cleaned word tokens
cleaned_data['cleaned_content'] = cleaned_data['word_tokens'].apply(lambda x: ' '.join(x))

# %%
cleaned_data.head(37)
# Out:
#                 company                                            content  \
# 0           Rheinmetall  Basic information on the rheinmetall GroupStru...
# 1         SiemensEnergy  Sustainability Report 2021 \n\nCreating transp...
# 2               Symrise  20 \n21 \n\nSustainability Record  \n(GRI) \n\...
# 3           Continetnal  Turn Change Into Opportunity – \nEmbrace Susta...
# 4          DeutscheBank  Deutsche Bank\n\n Non-Financial Report \n2021\...
# 5              Covestro  COMBINED \n MANAGEMENT REPORT\n\nCOMBINED MANA...
# 6                   MTU  Acting for tomorrow, today  \nOUR RESPONSIBILI...
# 7                 Bayer  Sustainability Report\n\n2021\n\n
# Contents \n\...
# 8       MuenchenerRueck  Sustainability \nReport 2021\n\n
# Munich Re  \n...
# 9               Zalando  Sustainability \nProgress Report\n2021\n\n
# Our...
# 10                  BMW  2MANAGEMENT REPORTCOMBINED34 Overview of the B...
# 11       DeutscheBoerse  Combined  \nmanagement report\n\n20\n\nWhat we...
# 12            Fresenius  SEPARATE  \nGROUP NON-FINANCIAL REPORT\n\n 115...
# 13               Adidas  1 \nTO OUR SHAREHOLDERS \n\n2 \nGROUP MANAGEME...
# 14           Beiersdorf  Sustainability Highlight Report\n\nCARE  \nBEY...
# 15        HannoverRueck  Sustainability Report 2021\n\n  \n
# 2\n\nHannov...
# 16              Allianz  Allianz Group Sustainability Report 2021\n\nBu...
# 17          Commerzbank  40 \n\nCommerzbank Annual Report 2021 \n\nComb...
# 18              Porsche  SUSTAINABILITY MANAGEMENT \nSustainability str...
# 19                 BASF  BASF Report 2021\n\nReport\n\n2 Management’s \...
# 20  HeidelbergMaterials  Company \nPortrait\n\nStrategy & \nManagement\...
# 21             Infineon  Sustainability at Infineon\nSupplementing the ...
# 22               Qiagen  1\n\nForeword\n\nOur Company\n\nEnvironment\n\...
# 23                  RWE  Focus \non tomorrow.\n\nSustainability Report ...
# 24               Airbus  Overview  /  Sustainability\n\n13\n\nPrioritis...
# 25           Volkswagen  SUSTAINABILITY REPORT\n\n2021\n\n
# NEW AUTO: VO...
# 26                  EON  #StandWithUkraine\n\nSustainability \nReport 2...
# 27         MercedesBenz  Sustainability Report 2021\n\nmaximum image ar...
# 28               Henkel  SUSTAINABILITY \nREPORT\n\n2021\n\n
# HENKEL SUS...
# 29              Siemens  Sustainability  report2021
# Our Purpose\n\n  Te...
# 30              Telekom  Corporate Responsibility \nBericht 2021\n\n
# 2\...
# 31                  SAP  SAP Integrated Report 2021 \n\nTo Our  \nStake...
# 32            Sartorius  Sartorius Stedim Biotech S.A. \n\nGRI Report 2...
# 33                  DHL  COMBINED MANAGEMENT REPORT NON-FINANCIAL  STAT...
# 34                Merck  Sustainability Report\n\n2021\n\n
# TABLE OF CON...
# 35              Vonovia  VONOVIA SE\nSUSTAINABILITY REPORT 2021\n\n=\n\...
# 36             Brenntag  S U S T A I N A B I L I T Y   R E P O R T\n202...
#
#                  datatype  date  internal title  \
# 0   Sustainability Report  2021         1   the
# 1   Sustainability Report  2021         1     ,
# 2   Sustainability Report  2021         1   the
# 3   Sustainability Report  2021         1   the
# 4   Sustainability Report  2021         1   and
# 5   Sustainability Report  2021         1   the
# 6   Sustainability Report  2021         1   the
# 7   Sustainability Report  2021         1   the
# 8   Sustainability Report  2021         1     .
# 9   Sustainability Report  2021         1     ,
# 10  Sustainability Report  2021         1   the
# 11  Sustainability Report  2021         1   the
# 12  Sustainability Report  2021         1   the
# 13  Sustainability Report  2021         1     ,
# 14  Sustainability Report  2021         1   our
# 15  Sustainability Report  2021         1   the
# 16  Sustainability Report  2021         1   and
# 17  Sustainability Report  2021         1   the
# 18  Sustainability Report  2021         1   the
# 19  Sustainability Report  2021         1   the
# 20  Sustainability Report  2021         1   the
# 21  Sustainability Report  2021         1   the
# 22  Sustainability Report  2021         1   and
# 23  Sustainability Report  2021         1   the
# 24  Sustainability Report  2021         1   the
# 25  Sustainability Report  2021         1   the
# 26  Sustainability Report  2021         1     ,
# 27  Sustainability Report  2021         1   the
# 28  Sustainability Report  2021         1   the
# 29  Sustainability Report  2021         1   the
# 30  Sustainability Report  2021         1     .
# 31  Sustainability Report  2021         1     ,
# 32  Sustainability Report  2021         1   the
# 33  Sustainability Report  2021         1   the
# 34  Sustainability Report  2021         1     ,
# 35  Sustainability Report  2021         1   the
# 36  Sustainability Report  2021         1   the
#
#                                       cleaned_content  \
# 0   basic information rheinmetall groupstructure r...
# 1   sustainability report creating transparency si...
# 2   gri sustainability record us international sta...
# 3   turn change opportunity embrace sustainability...
# 4   deutsche bank nonfinancial report letter chief...
# 5   combined management report combined management...
# 6   acting tomorrow today responsibility plan sust...
# 7   sustainability report editorial report crop pr...
# 8   sustainability report sustainability report an...
# 9   sustainability progress report progress glance...
# 10  2management reportcombined34 overview group34 ...
# 11  combined management report achieved report deu...
# 12  separate group nonfinancial report strategy ma...
# 13  group management report financial review conso...
# 14  sustainability highlight report care beyond sk...
# 15  sustainability report sustainability report gr...
# 16  group sustainability report building confidenc...
# 17  financial report directive stipulated commerzb...
# 18  sustainability management sustainability strat...
# 19  basf report report management overview nonfina...
# 20  portrait strategy management business complian...
# 21  sustainability supplementing annual report nav...
# 22  sustainy report sustainability report governan...
# 23  focus tomorrow sustainability report energy su...
# 24  overview sustainability prioritising sustainab...
# 25  sustainability report new auto reinvents world...
# 26  standwithukraine sustainability report search ...
# 27  sustainability report maximum image areaminimu...
# 28  sustainability report henkel sustainability re...
# 29  sustainability purpose technology transform ev...
# 30  corporate responsibility inhalt diesis pdfdoku...
# 31  integrated report stakeholder combined group m...
# 32  stedim biotech sa gri report stedim biotech gr...
# 33  combined management report nonfinancial statem...
# 34  sustainability report strategy management yees...
# 35  vonovia se sustainability report sustainable f...
# 36  brenntag se sustainability report brenntag wor...
#
#                                           word_tokens  \
# 0   [basic, information, rheinmetall, groupstructu...
# 1   [sustainability, report, creating, transparenc...
# 2   [gri, sustainability, record, us, internationa...
# 3   [turn, change, opportunity, embrace, sustainab...
# 4   [deutsche, bank, nonfinancial, report, letter,...
# 5   [combined, management, report, combined, manag...
# 6   [acting, tomorrow, today, responsibility, plan...
# 7   [sustainability, report, editorial, report, cr...
# 8   [sustainability, report, sustainability, repor...
# 9   [sustainability, progress, report, progress, g...
# 10  anagement, reportcombined34, overview, grou...
# 11  [combined, management, report, achieved, repor...
# 12  [separate, group, nonfinancial, report, strate...
# 13  [group, management, report, financial, review,...
# 14  [sustainability, highlight, report, care, beyo...
# 15  [sustainability, report, sustainability, repor...
# 16  [group, sustainability, report, building, conf...
# 17  [financial, report, directive, stipulated, com...
# 18  [sustainability, management, sustainability, s...
# 19  [basf, report, report, management, overview, n...
# 20  [portrait, strategy, management, business, com...
# 21  [sustainability, supplementing, annual, report...
# 22  [sustainy, report, sustainability, report, gov...
# 23  [focus, tomorrow, sustainability, report, ener...
# 24  [overview, sustainability, prioritising, susta...
# 25  [sustainability, report, new, auto, reinvents,...
# 26  [standwithukraine, sustainability, report, sea...
# 27  [sustainability, report, maximum, image, aream...
# 28  [sustainability, report, henkel, sustainabilit...
# 29  [sustainability, purpose, technology, transfor...
# 30  [corporate, responsibility, inhalt, diesis, pd...
# 31  [integrated, report, stakeholder, combined, gr...
# 32  [stedim, biotech, sa, gri, report, stedim, bio...
# 33  [combined, management, report, nonfinancial, s...
# 34  [sustainability, report, strategy, management,...
# 35  [vonovia, se, sustainability, report, sustaina...
# 36  [brenntag, se, sustainability, report, brennta...
#
#                                       sentence_tokens
# 0   [basic information rheinmetall groupstructure ...
# 1   [sustainability report creating transparency f...
# 2   [gri sustainability record uses international ...
# 3   [turn change opportunity embrace sustainabilit...
# 4   [deutsche bank nonfinancial report letter chie...
# 5   [combined management report combined managemen...
# 6   [acting tomorrow today responsibility plans su...
# 7   [sustainability report editorial report crop p...
# 8   [sustainability report sustainability report a...
# 9   [sustainability progress report progress glanc...
# 10  [overview organisational business model group ...
# 11  [combined management report achieved report de...
# 12  [separate group nonfinancial report strategy m...
# 13  [group management report financial review cons...
# 14  [sustainability highlight report care beyond s...
# 15  [sustainability report sustainability report u...
# 16  [group sustainability report building confiden...
# 17  [financial report directives stipulated commer...
# 18  [sustainability management sustainability stra...
# 19  [basf report report management overview nonfin...
# 20  [portrait strategy management business complia...
# 21  [sustainability supplementing annual report na...
# 22  [, sustainy report sustainability report gover...
# 23  [focus tomorrow, sustainability report energy ...
# 24  [overview sustainability prioritising sustaina...
# 25  [sustainability report new auto reinvents worl...
# 26  [standwithukraine sustainability report search...
# 27  [sustainability report maximum image areaminim...
# 28  [sustainability report henkel sustainability r...
# 29  [sustainability purpose technology transform e...
# 30  [corporate responsibility inhalt dieses pdfdok...
# 31  [integrated report stakeholders combined group...
# 32  [stedim biotech gri report stedim biotech gri ...
# 33  [combined management report nonfinancial state...
# 34  [sustainability report strategy management yee...
# 35  [vonovia se sustainability report sustainable ...
# 36  [brenntag se sustainability report brenntag wo...

# %%
def pos_tagging_tokens(word_tokens, sentence_list):
    """
    Performs POS tagging on a given list of word tokens and a list of sentence tokens and returns the POS tagged word tokens and POS tagged sentence tokens.

    Args:
        word_tokens (list): The list of word tokens to perform POS tagging on.
        sentence_list (list): The list of sentence tokens to perform POS tagging on.

    Returns:
        tuple: A tuple containing the POS tagged word tokens (list) and the POS tagged sentence tokens (list of lists).
    """
    
    # POS tagging for word tokens
    pos_tagged_word_tokens = nltk.pos_tag(word_tokens)

    # Create a dictionary to map word tokens to their POS tags, this reduces the effort to call nltk.pos_tag twice
    pos_tags_dict = dict(pos_tagged_word_tokens)

    # POS tagging for sentence tokens
    pos_tagged_sentence_list = []
    for sentence in sentence_list:
        tokenized_sentence = nltk.word_tokenize(sentence)
        pos_tagged_sentence = [(token, pos_tags_dict[token]) for token in tokenized_sentence if token in pos_tags_dict]
        pos_tagged_sentence_list.append(pos_tagged_sentence)

    return pos_tagged_word_tokens, pos_tagged_sentence_list

# Apply POS tagging
pos_tags = cleaned_data.apply(lambda row: pos_tagging_tokens(row['word_tokens'], row['sentence_tokens']), axis=1)
cleaned_data['pos_tagged_word_tokens'], cleaned_data['pos_tagged_sentence_tokens'] = zip(*pos_tags)

# %%
cleaned_data.shape
# Out:
# (37, 11)

# %%
cleaned_data.head(37)
# Out:
#                 company                                            content  \
# 0           Rheinmetall  Basic information on the rheinmetall GroupStru...
# 1         SiemensEnergy  Sustainability Report 2021 \n\nCreating transp...
# 2               Symrise  20 \n21 \n\nSustainability Record  \n(GRI) \n\...
# 3           Continetnal  Turn Change Into Opportunity – \nEmbrace Susta...
# 4          DeutscheBank  Deutsche Bank\n\n Non-Financial Report \n2021\...
# 5              Covestro  COMBINED \n MANAGEMENT REPORT\n\nCOMBINED MANA...
# 6                   MTU  Acting for tomorrow, today  \nOUR RESPONSIBILI...
# 7                 Bayer  Sustainability Report\n\n2021\n\n
# Contents \n\...
# 8       MuenchenerRueck  Sustainability \nReport 2021\n\n
# Munich Re  \n...
# 9               Zalando  Sustainability \nProgress Report\n2021\n\n
# Our...
# 10                  BMW  2MANAGEMENT REPORTCOMBINED34 Overview of the B...
# 11       DeutscheBoerse  Combined  \nmanagement report\n\n20\n\nWhat we...
# 12            Fresenius  SEPARATE  \nGROUP NON-FINANCIAL REPORT\n\n 115...
# 13               Adidas  1 \nTO OUR SHAREHOLDERS \n\n2 \nGROUP MANAGEME...
# 14           Beiersdorf  Sustainability Highlight Report\n\nCARE  \nBEY...
# 15        HannoverRueck  Sustainability Report 2021\n\n  \n
# 2\n\nHannov...
# 16              Allianz  Allianz Group Sustainability Report 2021\n\nBu...
# 17          Commerzbank  40 \n\nCommerzbank Annual Report 2021 \n\nComb...
# 18              Porsche  SUSTAINABILITY MANAGEMENT \nSustainability str...
# 19                 BASF  BASF Report 2021\n\nReport\n\n2 Management’s \...
# 20  HeidelbergMaterials  Company \nPortrait\n\nStrategy & \nManagement\...
# 21             Infineon  Sustainability at Infineon\nSupplementing the ...
# 22               Qiagen  1\n\nForeword\n\nOur Company\n\nEnvironment\n\...
# 23                  RWE  Focus \non tomorrow.\n\nSustainability Report ...
# 24               Airbus  Overview  /  Sustainability\n\n13\n\nPrioritis...
# 25           Volkswagen  SUSTAINABILITY REPORT\n\n2021\n\n
# NEW AUTO: VO...
# 26                  EON  #StandWithUkraine\n\nSustainability \nReport 2...
# 27         MercedesBenz  Sustainability Report 2021\n\nmaximum image ar...
# 28               Henkel  SUSTAINABILITY \nREPORT\n\n2021\n\n
# HENKEL SUS...
# 29              Siemens  Sustainability  report2021
# Our Purpose\n\n  Te...
# 30              Telekom  Corporate Responsibility \nBericht 2021\n\n
# 2\...
# 31                  SAP  SAP Integrated Report 2021 \n\nTo Our  \nStake...
# 32            Sartorius  Sartorius Stedim Biotech S.A. \n\nGRI Report 2...
# 33                  DHL  COMBINED MANAGEMENT REPORT NON-FINANCIAL  STAT...
# 34                Merck  Sustainability Report\n\n2021\n\n
# TABLE OF CON...
# 35              Vonovia  VONOVIA SE\nSUSTAINABILITY REPORT 2021\n\n=\n\...
# 36             Brenntag  S U S T A I N A B I L I T Y   R E P O R T\n202...
#
#                  datatype  date  internal title  \
# 0   Sustainability Report  2021         1   the
# 1   Sustainability Report  2021         1     ,
# 2   Sustainability Report  2021         1   the
# 3   Sustainability Report  2021         1   the
# 4   Sustainability Report  2021         1   and
# 5   Sustainability Report  2021         1   the
# 6   Sustainability Report  2021         1   the
# 7   Sustainability Report  2021         1   the
# 8   Sustainability Report  2021         1     .
# 9   Sustainability Report  2021         1     ,
# 10  Sustainability Report  2021         1   the
# 11  Sustainability Report  2021         1   the
# 12  Sustainability Report  2021         1   the
# 13  Sustainability Report  2021         1     ,
# 14  Sustainability Report  2021         1   our
# 15  Sustainability Report  2021         1   the
# 16  Sustainability Report  2021         1   and
# 17  Sustainability Report  2021         1   the
# 18  Sustainability Report  2021         1   the
# 19  Sustainability Report  2021         1   the
# 20  Sustainability Report  2021         1   the
# 21  Sustainability Report  2021         1   the
# 22  Sustainability Report  2021         1   and
# 23  Sustainability Report  2021         1   the
# 24  Sustainability Report  2021         1   the
# 25  Sustainability Report  2021         1   the
# 26  Sustainability Report  2021         1     ,
# 27  Sustainability Report  2021         1   the
# 28  Sustainability Report  2021         1   the
# 29  Sustainability Report  2021         1   the
# 30  Sustainability Report  2021         1     .
# 31  Sustainability Report  2021         1     ,
# 32  Sustainability Report  2021         1   the
# 33  Sustainability Report  2021         1   the
# 34  Sustainability Report  2021         1     ,
# 35  Sustainability Report  2021         1   the
# 36  Sustainability Report  2021         1   the
#
#                                       cleaned_content  \
# 0   basic information rheinmetall groupstructure r...
# 1   sustainability report creating transparency si...
# 2   gri sustainability record us international sta...
# 3   turn change opportunity embrace sustainability...
# 4   deutsche bank nonfinancial report letter chief...
# 5   combined management report combined management...
# 6   acting tomorrow today responsibility plan sust...
# 7   sustainability report editorial report crop pr...
# 8   sustainability report sustainability report an...
# 9   sustainability progress report progress glance...
# 10  2management reportcombined34 overview group34 ...
# 11  combined management report achieved report deu...
# 12  separate group nonfinancial report strategy ma...
# 13  group management report financial review conso...
# 14  sustainability highlight report care beyond sk...
# 15  sustainability report sustainability report gr...
# 16  group sustainability report building confidenc...
# 17  financial report directive stipulated commerzb...
# 18  sustainability management sustainability strat...
# 19  basf report report management overview nonfina...
# 20  portrait strategy management business complian...
# 21  sustainability supplementing annual report nav...
# 22  sustainy report sustainability report governan...
# 23  focus tomorrow sustainability report energy su...
# 24  overview sustainability prioritising sustainab...
# 25  sustainability report new auto reinvents world...
# 26  standwithukraine sustainability report search ...
# 27  sustainability report maximum image areaminimu...
# 28  sustainability report henkel sustainability re...
# 29  sustainability purpose technology transform ev...
# 30  corporate responsibility inhalt diesis pdfdoku...
# 31  integrated report stakeholder combined group m...
# 32  stedim biotech sa gri report stedim biotech gr...
# 33  combined management report nonfinancial statem...
# 34  sustainability report strategy management yees...
# 35  vonovia se sustainability report sustainable f...
# 36  brenntag se sustainability report brenntag wor...
#
#                                           word_tokens  \
# 0   [basic, information, rheinmetall, groupstructu...
# 1   [sustainability, report, creating, transparenc...
# 2   [gri, sustainability, record, us, internationa...
# 3   [turn, change, opportunity, embrace, sustainab...
# 4   [deutsche, bank, nonfinancial, report, letter,...
# 5   [combined, management, report, combined, manag...
# 6   [acting, tomorrow, today, responsibility, plan...
# 7   [sustainability, report, editorial, report, cr...
# 8   [sustainability, report, sustainability, repor...
# 9   [sustainability, progress, report, progress, g...
# 10  anagement, reportcombined34, overview, grou...
# 11  [combined, management, report, achieved, repor...
# 12  [separate, group, nonfinancial, report, strate...
# 13  [group, management, report, financial, review,...
# 14  [sustainability, highlight, report, care, beyo...
# 15  [sustainability, report, sustainability, repor...
# 16  [group, sustainability, report, building, conf...
# 17  [financial, report, directive, stipulated, com...
# 18  [sustainability, management, sustainability, s...
# 19  [basf, report, report, management, overview, n...
# 20  [portrait, strategy, management, business, com...
# 21  [sustainability, supplementing, annual, report...
# 22  [sustainy, report, sustainability, report, gov...
# 23  [focus, tomorrow, sustainability, report, ener...
# 24  [overview, sustainability, prioritising, susta...
# 25  [sustainability, report, new, auto, reinvents,...
# 26  [standwithukraine, sustainability, report, sea...
# 27  [sustainability, report, maximum, image, aream...
# 28  [sustainability, report, henkel, sustainabilit...
# 29  [sustainability, purpose, technology, transfor...
# 30  [corporate, responsibility, inhalt, diesis, pd...
# 31  [integrated, report, stakeholder, combined, gr...
# 32  [stedim, biotech, sa, gri, report, stedim, bio...
# 33  [combined, management, report, nonfinancial, s...
# 34  [sustainability, report, strategy, management,...
# 35  [vonovia, se, sustainability, report, sustaina...
# 36  [brenntag, se, sustainability, report, brennta...
#
#                                       sentence_tokens  \
# 0   [basic information rheinmetall groupstructure ...
# 1   [sustainability report creating transparency f...
# 2   [gri sustainability record uses international ...
# 3   [turn change opportunity embrace sustainabilit...
# 4   [deutsche bank nonfinancial report letter chie...
# 5   [combined management report combined managemen...
# 6   [acting tomorrow today responsibility plans su...
# 7   [sustainability report editorial report crop p...
# 8   [sustainability report sustainability report a...
# 9   [sustainability progress report progress glanc...
# 10  [overview organisational business model group ...
# 11  [combined management report achieved report de...
# 12  [separate group nonfinancial report strategy m...
# 13  [group management report financial review cons...
# 14  [sustainability highlight report care beyond s...
# 15  [sustainability report sustainability report u...
# 16  [group sustainability report building confiden...
# 17  [financial report directives stipulated commer...
# 18  [sustainability management sustainability stra...
# 19  [basf report report management overview nonfin...
# 20  [portrait strategy management business complia...
# 21  [sustainability supplementing annual report na...
# 22  [, sustainy report sustainability report gover...
# 23  [focus tomorrow, sustainability report energy ...
# 24  [overview sustainability prioritising sustaina...
# 25  [sustainability report new auto reinvents worl...
# 26  [standwithukraine sustainability report search...
# 27  [sustainability report maximum image areaminim...
# 28  [sustainability report henkel sustainability r...
# 29  [sustainability purpose technology transform e...
# 30  [corporate responsibility inhalt dieses pdfdok...
# 31  [integrated report stakeholders combined group...
# 32  [stedim biotech gri report stedim biotech gri ...
# 33  [combined management report nonfinancial state...
# 34  [sustainability report strategy management yee...
# 35  [vonovia se sustainability report sustainable ...
# 36  [brenntag se sustainability report brenntag wo...
#
#                                pos_tagged_word_tokens  \
# 0   [(basic, JJ), (information, NN), (rheinmetall,...
# 1   [(sustainability, NN), (report, NN), (creating...
# 2   [(gri, JJ), (sustainability, NN), (record, NN)...
# 3   [(turn, NN), (change, NN), (opportunity, NN), ...
# 4   [(deutsche, NN), (bank, NN), (nonfinancial, JJ...
# 5   [(combined, JJ), (management, NN), (report, NN...
# 6   [(acting, VBG), (tomorrow, NN), (today, NN), (...
# 7   [(sustainability, NN), (report, NN), (editoria...
# 8   [(sustainability, NN), (report, NN), (sustaina...
# 9   [(sustainability, NN), (progress, NN), (report...
# 10  [(2management, CD), (reportcombined34, JJ), (o...
# 11  [(combined, JJ), (management, NN), (report, NN...
# 12  [(separate, JJ), (group, NN), (nonfinancial, J...
# 13  [(group, NN), (management, NN), (report, NN), ...
# 14  [(sustainability, NN), (highlight, VBD), (repo...
# 15  [(sustainability, NN), (report, NN), (sustaina...
# 16  [(group, NN), (sustainability, NN), (report, N...
# 17  [(financial, JJ), (report, NN), (directive, NN...
# 18  [(sustainability, NN), (management, NN), (sust...
# 19  [(basf, JJ), (report, NN), (report, NN), (mana...
# 20  [(portrait, NN), (strategy, NN), (management, ...
# 21  [(sustainability, NN), (supplementing, VBG), (...
# 22  [(sustainy, JJ), (report, NN), (sustainability...
# 23  [(focus, NN), (tomorrow, NN), (sustainability,...
# 24  [(overview, NN), (sustainability, NN), (priori...
# 25  [(sustainability, NN), (report, NN), (new, JJ)...
# 26  [(standwithukraine, JJ), (sustainability, NN),...
# 27  [(sustainability, NN), (report, NN), (maximum,...
# 28  [(sustainability, NN), (report, NN), (henkel, ...
# 29  [(sustainability, NN), (purpose, NN), (technol...
# 30  [(corporate, JJ), (responsibility, NN), (inhal...
# 31  [(integrated, JJ), (report, NN), (stakeholder,...
# 32  [(stedim, NN), (biotech, NN), (sa, NN), (gri, ...
# 33  [(combined, JJ), (management, NN), (report, NN...
# 34  [(sustainability, NN), (report, NN), (strategy...
# 35  [(vonovia, NN), (se, JJ), (sustainability, NN)...
# 36  [(brenntag, NN), (se, JJ), (sustainability, NN...
#
#                            pos_tagged_sentence_tokens
# 0   [[(basic, JJ), (information, NN), (rheinmetall...
# 1   [[(sustainability, NN), (report, NN), (creatin...
# 2   [[(gri, NN), (sustainability, JJ), (record, JJ...
# 3   [[(turn, NN), (change, NN), (opportunity, NN),...
# 4   [[(deutsche, NN), (bank, NN), (nonfinancial, J...
# 5   [[(combined, VBD), (management, NN), (report, ...
# 6   [[(acting, VBG), (tomorrow, NN), (today, NN), ...
# 7   [[(sustainability, NN), (report, NN), (editori...
# 8   [[(sustainability, NN), (report, NN), (sustain...
# 9   [[(sustainability, NN), (progress, NN), (repor...
# 10  [[(overview, NN), (organisational, JJ), (busin...
# 11  [[(combined, VBD), (management, NN), (report, ...
# 12  [[(separate, JJ), (group, NN), (nonfinancial, ...
# 13  [[(group, NN), (management, NN), (report, NN),...
# 14  [[(sustainability, NN), (highlight, VBD), (rep...
# 15  [[(sustainability, NN), (report, NN), (sustain...
# 16  [[(group, NN), (sustainability, NN), (report, ...
# 17  [[(financial, JJ), (report, NN), (stipulated, ...
# 18  [[(sustainability, NN), (management, NN), (sus...
# 19  [[(basf, VBD), (report, NN), (report, NN), (ma...
# 20  [[(portrait, NN), (strategy, NN), (management,...
# 21  [[(sustainability, NN), (supplementing, VBG), ...
# 22  [[], [(sustainy, JJ), (report, NN), (sustainab...
# 23  [[(focus, NN), (tomorrow, NN)], [(sustainabili...
# 24  [[(overview, JJ), (sustainability, NN), (prior...
# 25  [[(sustainability, NN), (report, VBP), (new, J...
# 26  [[(standwithukraine, JJ), (sustainability, NN)...
# 27  [[(sustainability, NN), (report, NN), (maximum...
# 28  [[(sustainability, NN), (report, NN), (henkel,...
# 29  [[(sustainability, NN), (purpose, JJ), (techno...
# 30  [[(corporate, JJ), (responsibility, NN), (inha...
# 31  [[(integrated, VBN), (report, NN), (combined, ...
# 32  [[(stedim, NN), (biotech, NN), (gri, NN), (rep...
# 33  [[(combined, VBN), (management, NN), (report, ...
# 34  [[(sustainability, NN), (report, NN), (strateg...
# 35  [[(vonovia, NN), (se, JJ), (sustainability, NN...
# 36  [[(brenntag, NN), (se, NN), (sustainability, N...

# %%
# Create checkpoint file
cleaned_data = csv_checkpoint(cleaned_data, 'cleaned_data_2021')
# Out:
# Saved DataFrame to cleaned_data_2021.csv
# Loaded DataFrame from cleaned_data_2021.csv

# %%
cleaned_data_new = cleaned_data.copy(deep=True)

# %% [markdown]
# **Data Enrichment**
#
# Several additional information will be incorporated that are not currently present in the dataset. This includes sector, industry, market capitilazation and the ESG scores of the DAX companies, which will serve to enhance the dataset for further analysis.

# %%
url = 'https://disfold.com/stock-index/dax/companies/'
response = requests.get(url)

soup = BeautifulSoup(response.content, 'html.parser')

table = soup.find('table')
scraped_data = []
for row in table.find_all('tr'):
    cols = row.find_all('td')
    cols = [col.text.strip() for col in cols]
    scraped_data.append(cols)

def clean_scraped_data_new(data):
    cleaned_data_new = []
    
    for row in data:
        # Remove empty rows
        if len(row) > 0:
            # Remove the '$' and ',' signs from the market cap and convert it to float
            market_cap = float(row[3].replace('$', '').replace(',', '').replace('B', ''))
            cleaned_data_new.append([row[1], row[2], market_cap, row[4], row[5], row[6]])
    
    df = pd.DataFrame(cleaned_data_new, columns=['company_name', 'symbol', 'market_cap_in_usd_b', 'country', 'sector', 'industry'])
    
    return df

company_enrichments = clean_scraped_data_new(scraped_data)
company_enrichments.head()
# Out:
#           company_name symbol  market_cap_in_usd_b      country  \
# 0               SAP SE    SAP               161.41      Germany
# 1           Siemens AG    SIE               131.00      Germany
# 2            Airbus SE    AIR               113.90  Netherlands
# 3  Deutsche Telekom AG    DTE               106.00      Germany
# 4           Allianz SE    ALV                91.36      Germany
#
#                    sector                        industry
# 0              Technology            Software—Application
# 1             Industrials  Specialty Industrial Machinery
# 2             Industrials             Aerospace & Defense
# 3  Communication Services                Telecom Services
# 4              Financials           Insurance—Diversified

# %%
# Define a dictionary with the old company names as keys and new company names as values
company_name_mapping = {
    "SAP": "SAP SE",
    "Infineon": "Infineon Technologies AG",
    "BASF": "BASF SE",
    "Porsche": "Porsche Automobil Holding SE",
    "Commerzbank": "Commerzbank AG",
    "Qiagen": "Qiagen N.V.",
    "Henkel": "Henkel AG & Co KGaA",
    "MercedesBenz": "Mercedes-Benz Group AG",
    "Airbus": "Airbus SE",
    "RWE": "RWE AG",
    "EON": "E.ON SE",
    "Volkswagen": "Volkswagen AG",
    "Brenntag": "Brenntag AG",
    "Vonovia": "Vonovia SE",
    "Sartorius": "Sartorius AG",
    "Telekom": "Deutsche Telekom AG",
    "Merck": "MERCK Kommanditgesellschaft auf Aktien",
    "DHL": "Deutsche Post AG",
    "Siemens": "Siemens AG",
    "SiemensEnergy": "Siemens Energy AG",
    "Symrise": "Symrise AG",
    "Rheinmetall": "Rheinmetall AG",
    "MTU": "MTU Aero Engines AG",
    "DeutscheBank": "Deutsche Bank AG",
    "DeutscheBoerse": "Deutsche Börse AG",
    "Zalando": "Zalando SE",
    "MuenchenerRueck": "Münchener Rückversicherungs-Gesellschaft Aktiengesellschaft in München",
    "Bayer": "Bayer AG",
    "Continetnal": "Continental AG",
    "Allianz": "Allianz SE",
    "Beiersdorf": "Beiersdorf AG",
    "HannoverRueck": "Hannover Rück SE",
    "Fresenius": "Fresenius SE & Co KGaA",
    "Adidas": "adidas AG",
    "Covestro": "Covestro AG",
    "BMW": "Bayerische Motoren Werke AG",
    "HeidelbergMaterials": "Heidelberg Materials AG",

    # Add more mappings as needed
}

# Replace the company names in the 'Company' column
cleaned_data_new['company'] = cleaned_data_new['company'].replace(company_name_mapping)

# %%
# Fix the ticker symbols to prevent NaN and ensure correct join conditions
company_enrichments['symbol'] = company_enrichments['symbol'].replace('SRT3', 'SRT')
company_enrichments['symbol'] = company_enrichments['symbol'].replace('HEN3', 'HNK')
company_enrichments.loc[company_enrichments['company_name'] == 'Mercedes-Benz Group AG', 'symbol'] = 'DAI'

# %%
merged_data = pd.merge(cleaned_data_new, company_enrichments, left_on='company', right_on='company_name')

# %%
merged_data.head(37)
# Out:
#                                               company  \
# 0                                      Rheinmetall AG
# 1                                   Siemens Energy AG
# 2                                          Symrise AG
# 3                                      Continental AG
# 4                                    Deutsche Bank AG
# 5                                         Covestro AG
# 6                                 MTU Aero Engines AG
# 7                                            Bayer AG
# 8   Münchener Rückversicherungs-Gesellschaft Aktie...
# 9                                          Zalando SE
# 10                        Bayerische Motoren Werke AG
# 11                                  Deutsche Börse AG
# 12                             Fresenius SE & Co KGaA
# 13                                          adidas AG
# 14                                      Beiersdorf AG
# 15                                   Hannover Rück SE
# 16                                         Allianz SE
# 17                                     Commerzbank AG
# 18                       Porsche Automobil Holding SE
# 19                                            BASF SE
# 20                            Heidelberg Materials AG
# 21                           Infineon Technologies AG
# 22                                        Qiagen N.V.
# 23                                             RWE AG
# 24                                          Airbus SE
# 25                                      Volkswagen AG
# 26                                            E.ON SE
# 27                             Mercedes-Benz Group AG
# 28                                Henkel AG & Co KGaA
# 29                                         Siemens AG
# 30                                Deutsche Telekom AG
# 31                                             SAP SE
# 32                                       Sartorius AG
# 33                                   Deutsche Post AG
# 34             MERCK Kommanditgesellschaft auf Aktien
# 35                                         Vonovia SE
# 36                                        Brenntag AG
#
#                                               content               datatype  \
# 0   Basic information on the rheinmetall GroupStru...  Sustainability Report
# 1   Sustainability Report 2021 \n\nCreating transp...  Sustainability Report
# 2   20 \n21 \n\nSustainability Record  \n(GRI) \n\...  Sustainability Report
# 3   Turn Change Into Opportunity – \nEmbrace Susta...  Sustainability Report
# 4   Deutsche Bank\n\n Non-Financial Report \n2021\...  Sustainability Report
# 5   COMBINED \n MANAGEMENT REPORT\n\nCOMBINED MANA...  Sustainability Report
# 6   Acting for tomorrow, today  \nOUR RESPONSIBILI...  Sustainability Report
# 7   Sustainability Report\n\n2021\n\n
# Contents \n\...  Sustainability Report
# 8   Sustainability \nReport 2021\n\n
# Munich Re  \n...  Sustainability Report
# 9   Sustainability \nProgress Report\n2021\n\n
# Our...  Sustainability Report
# 10  2MANAGEMENT REPORTCOMBINED34 Overview of the B...  Sustainability Report
# 11  Combined  \nmanagement report\n\n20\n\nWhat we...  Sustainability Report
# 12  SEPARATE  \nGROUP NON-FINANCIAL REPORT\n\n 115...  Sustainability Report
# 13  1 \nTO OUR SHAREHOLDERS \n\n2 \nGROUP MANAGEME...  Sustainability Report
# 14  Sustainability Highlight Report\n\nCARE  \nBEY...  Sustainability Report
# 15  Sustainability Report 2021\n\n  \n
# 2\n\nHannov...  Sustainability Report
# 16  Allianz Group Sustainability Report 2021\n\nBu...  Sustainability Report
# 17  40 \n\nCommerzbank Annual Report 2021 \n\nComb...  Sustainability Report
# 18  SUSTAINABILITY MANAGEMENT \nSustainability str...  Sustainability Report
# 19  BASF Report 2021\n\nReport\n\n2 Management’s \...  Sustainability Report
# 20  Company \nPortrait\n\nStrategy & \nManagement\...  Sustainability Report
# 21  Sustainability at Infineon\nSupplementing the ...  Sustainability Report
# 22  1\n\nForeword\n\nOur Company\n\nEnvironment\n\...  Sustainability Report
# 23  Focus \non tomorrow.\n\nSustainability Report ...  Sustainability Report
# 24  Overview  /  Sustainability\n\n13\n\nPrioritis...  Sustainability Report
# 25  SUSTAINABILITY REPORT\n\n2021\n\n
# NEW AUTO: VO...  Sustainability Report
# 26  #StandWithUkraine\n\nSustainability \nReport 2...  Sustainability Report
# 27  Sustainability Report 2021\n\nmaximum image ar...  Sustainability Report
# 28  SUSTAINABILITY \nREPORT\n\n2021\n\n
# HENKEL SUS...  Sustainability Report
# 29  Sustainability  report2021
# Our Purpose\n\n  Te...  Sustainability Report
# 30  Corporate Responsibility \nBericht 2021\n\n
# 2\...  Sustainability Report
# 31  SAP Integrated Report 2021 \n\nTo Our  \nStake...  Sustainability Report
# 32  Sartorius Stedim Biotech S.A. \n\nGRI Report 2...  Sustainability Report
# 33  COMBINED MANAGEMENT REPORT NON-FINANCIAL  STAT...  Sustainability Report
# 34  Sustainability Report\n\n2021\n\n
# TABLE OF CON...  Sustainability Report
# 35  VONOVIA SE\nSUSTAINABILITY REPORT 2021\n\n=\n\...  Sustainability Report
# 36  S U S T A I N A B I L I T Y   R E P O R T\n202...  Sustainability Report
#
#     date  internal title                                    cleaned_content  \
# 0   2021         1   the  basic information rheinmetall groupstructure r...
# 1   2021         1     ,  sustainability report creating transparency si...
# 2   2021         1   the  gri sustainability record us international sta...
# 3   2021         1   the  turn change opportunity embrace sustainability...
# 4   2021         1   and  deutsche bank nonfinancial report letter chief...
# 5   2021         1   the  combined management report combined management...
# 6   2021         1   the  acting tomorrow today responsibility plan sust...
# 7   2021         1   the  sustainability report editorial report crop pr...
# 8   2021         1     .  sustainability report sustainability report an...
# 9   2021         1     ,  sustainability progress report progress glance...
# 10  2021         1   the  2management reportcombined34 overview group34 ...
# 11  2021         1   the  combined management report achieved report deu...
# 12  2021         1   the  separate group nonfinancial report strategy ma...
# 13  2021         1     ,  group management report financial review conso...
# 14  2021         1   our  sustainability highlight report care beyond sk...
# 15  2021         1   the  sustainability report sustainability report gr...
# 16  2021         1   and  group sustainability report building confidenc...
# 17  2021         1   the  financial report directive stipulated commerzb...
# 18  2021         1   the  sustainability management sustainability strat...
# 19  2021         1   the  basf report report management overview nonfina...
# 20  2021         1   the  portrait strategy management business complian...
# 21  2021         1   the  sustainability supplementing annual report nav...
# 22  2021         1   and  sustainy report sustainability report governan...
# 23  2021         1   the  focus tomorrow sustainability report energy su...
# 24  2021         1   the  overview sustainability prioritising sustainab...
# 25  2021         1   the  sustainability report new auto reinvents world...
# 26  2021         1     ,  standwithukraine sustainability report search ...
# 27  2021         1   the  sustainability report maximum image areaminimu...
# 28  2021         1   the  sustainability report henkel sustainability re...
# 29  2021         1   the  sustainability purpose technology transform ev...
# 30  2021         1     .  corporate responsibility inhalt diesis pdfdoku...
# 31  2021         1     ,  integrated report stakeholder combined group m...
# 32  2021         1   the  stedim biotech sa gri report stedim biotech gr...
# 33  2021         1   the  combined management report nonfinancial statem...
# 34  2021         1     ,  sustainability report strategy management yees...
# 35  2021         1   the  vonovia se sustainability report sustainable f...
# 36  2021         1   the  brenntag se sustainability report brenntag wor...
#
#                                           word_tokens  \
# 0   ['basic', 'information', 'rheinmetall', 'group...
# 1   ['sustainability', 'report', 'creating', 'tran...
# 2   ['gri', 'sustainability', 'record', 'us', 'int...
# 3   ['turn', 'change', 'opportunity', 'embrace', '...
# 4   ['deutsche', 'bank', 'nonfinancial', 'report',...
# 5   ['combined', 'management', 'report', 'combined...
# 6   ['acting', 'tomorrow', 'today', 'responsibilit...
# 7   ['sustainability', 'report', 'editorial', 'rep...
# 8   ['sustainability', 'report', 'sustainability',...
# 9   ['sustainability', 'progress', 'report', 'prog...
# 10  ['2management', 'reportcombined34', 'overview'...
# 11  ['combined', 'management', 'report', 'achieved...
# 12  ['separate', 'group', 'nonfinancial', 'report'...
# 13  ['group', 'management', 'report', 'financial',...
# 14  ['sustainability', 'highlight', 'report', 'car...
# 15  ['sustainability', 'report', 'sustainability',...
# 16  ['group', 'sustainability', 'report', 'buildin...
# 17  ['financial', 'report', 'directive', 'stipulat...
# 18  ['sustainability', 'management', 'sustainabili...
# 19  ['basf', 'report', 'report', 'management', 'ov...
# 20  ['portrait', 'strategy', 'management', 'busine...
# 21  ['sustainability', 'supplementing', 'annual', ...
# 22  ['sustainy', 'report', 'sustainability', 'repo...
# 23  ['focus', 'tomorrow', 'sustainability', 'repor...
# 24  ['overview', 'sustainability', 'prioritising',...
# 25  ['sustainability', 'report', 'new', 'auto', 'r...
# 26  ['standwithukraine', 'sustainability', 'report...
# 27  ['sustainability', 'report', 'maximum', 'image...
# 28  ['sustainability', 'report', 'henkel', 'sustai...
# 29  ['sustainability', 'purpose', 'technology', 't...
# 30  ['corporate', 'responsibility', 'inhalt', 'die...
# 31  ['integrated', 'report', 'stakeholder', 'combi...
# 32  ['stedim', 'biotech', 'sa', 'gri', 'report', '...
# 33  ['combined', 'management', 'report', 'nonfinan...
# 34  ['sustainability', 'report', 'strategy', 'mana...
# 35  ['vonovia', 'se', 'sustainability', 'report', ...
# 36  ['brenntag', 'se', 'sustainability', 'report',...
#
#                                       sentence_tokens  \
# 0   ['basic information rheinmetall groupstructure...
# 1   ['sustainability report creating transparency ...
# 2   ['gri sustainability record uses international...
# 3   ['turn change opportunity embrace sustainabili...
# 4   ['deutsche bank nonfinancial report letter chi...
# 5   ['combined management report combined manageme...
# 6   ['acting tomorrow today responsibility plans s...
# 7   ['sustainability report editorial report crop ...
# 8   ['sustainability report sustainability report ...
# 9   ['sustainability progress report progress glan...
# 10  ['overview organisational business model group...
# 11  ['combined management report achieved report d...
# 12  ['separate group nonfinancial report strategy ...
# 13  ['group management report financial review con...
# 14  ['sustainability highlight report care beyond ...
# 15  ['sustainability report sustainability report ...
# 16  ['group sustainability report building confide...
# 17  ['financial report directives stipulated comme...
# 18  ['sustainability management sustainability str...
# 19  ['basf report report management overview nonfi...
# 20  ['portrait strategy management business compli...
# 21  ['sustainability supplementing annual report n...
# 22  ['', 'sustainy report sustainability report go...
# 23  ['focus tomorrow', 'sustainability report ener...
# 24  ['overview sustainability prioritising sustain...
# 25  ['sustainability report new auto reinvents wor...
# 26  ['standwithukraine sustainability report searc...
# 27  ['sustainability report maximum image areamini...
# 28  ['sustainability report henkel sustainability ...
# 29  ['sustainability purpose technology transform ...
# 30  ['corporate responsibility inhalt dieses pdfdo...
# 31  ['integrated report stakeholders combined grou...
# 32  ['stedim biotech gri report stedim biotech gri...
# 33  ['combined management report nonfinancial stat...
# 34  ['sustainability report strategy management ye...
# 35  ['vonovia se sustainability report sustainable...
# 36  ['brenntag se sustainability report brenntag w...
#
#                                pos_tagged_word_tokens  \
# 0   [('basic', 'JJ'), ('information', 'NN'), ('rhe...
# 1   [('sustainability', 'NN'), ('report', 'NN'), (...
# 2   [('gri', 'JJ'), ('sustainability', 'NN'), ('re...
# 3   [('turn', 'NN'), ('change', 'NN'), ('opportuni...
# 4   [('deutsche', 'NN'), ('bank', 'NN'), ('nonfina...
# 5   [('combined', 'JJ'), ('management', 'NN'), ('r...
# 6   [('acting', 'VBG'), ('tomorrow', 'NN'), ('toda...
# 7   [('sustainability', 'NN'), ('report', 'NN'), (...
# 8   [('sustainability', 'NN'), ('report', 'NN'), (...
# 9   [('sustainability', 'NN'), ('progress', 'NN'),...
# 10  [('2management', 'CD'), ('reportcombined34', '...
# 11  [('combined', 'JJ'), ('management', 'NN'), ('r...
# 12  [('separate', 'JJ'), ('group', 'NN'), ('nonfin...
# 13  [('group', 'NN'), ('management', 'NN'), ('repo...
# 14  [('sustainability', 'NN'), ('highlight', 'VBD'...
# 15  [('sustainability', 'NN'), ('report', 'NN'), (...
# 16  [('group', 'NN'), ('sustainability', 'NN'), ('...
# 17  [('financial', 'JJ'), ('report', 'NN'), ('dire...
# 18  [('sustainability', 'NN'), ('management', 'NN'...
# 19  [('basf', 'JJ'), ('report', 'NN'), ('report', ...
# 20  [('portrait', 'NN'), ('strategy', 'NN'), ('man...
# 21  [('sustainability', 'NN'), ('supplementing', '...
# 22  [('sustainy', 'JJ'), ('report', 'NN'), ('susta...
# 23  [('focus', 'NN'), ('tomorrow', 'NN'), ('sustai...
# 24  [('overview', 'NN'), ('sustainability', 'NN'),...
# 25  [('sustainability', 'NN'), ('report', 'NN'), (...
# 26  [('standwithukraine', 'JJ'), ('sustainability'...
# 27  [('sustainability', 'NN'), ('report', 'NN'), (...
# 28  [('sustainability', 'NN'), ('report', 'NN'), (...
# 29  [('sustainability', 'NN'), ('purpose', 'NN'), ...
# 30  [('corporate', 'JJ'), ('responsibility', 'NN')...
# 31  [('integrated', 'JJ'), ('report', 'NN'), ('sta...
# 32  [('stedim', 'NN'), ('biotech', 'NN'), ('sa', '...
# 33  [('combined', 'JJ'), ('management', 'NN'), ('r...
# 34  [('sustainability', 'NN'), ('report', 'NN'), (...
# 35  [('vonovia', 'NN'), ('se', 'JJ'), ('sustainabi...
# 36  [('brenntag', 'NN'), ('se', 'JJ'), ('sustainab...
#
#                            pos_tagged_sentence_tokens  \
# 0   [[('basic', 'JJ'), ('information', 'NN'), ('rh...
# 1   [[('sustainability', 'NN'), ('report', 'NN'), ...
# 2   [[('gri', 'NN'), ('sustainability', 'JJ'), ('r...
# 3   [[('turn', 'NN'), ('change', 'NN'), ('opportun...
# 4   [[('deutsche', 'NN'), ('bank', 'NN'), ('nonfin...
# 5   [[('combined', 'VBD'), ('management', 'NN'), (...
# 6   [[('acting', 'VBG'), ('tomorrow', 'NN'), ('tod...
# 7   [[('sustainability', 'NN'), ('report', 'NN'), ...
# 8   [[('sustainability', 'NN'), ('report', 'NN'), ...
# 9   [[('sustainability', 'NN'), ('progress', 'NN')...
# 10  [[('overview', 'NN'), ('organisational', 'JJ')...
# 11  [[('combined', 'VBD'), ('management', 'NN'), (...
# 12  [[('separate', 'JJ'), ('group', 'NN'), ('nonfi...
# 13  [[('group', 'NN'), ('management', 'NN'), ('rep...
# 14  [[('sustainability', 'NN'), ('highlight', 'VBD...
# 15  [[('sustainability', 'NN'), ('report', 'NN'), ...
# 16  [[('group', 'NN'), ('sustainability', 'NN'), (...
# 17  [[('financial', 'JJ'), ('report', 'NN'), ('sti...
# 18  [[('sustainability', 'NN'), ('management', 'NN...
# 19  [[('basf', 'VBD'), ('report', 'NN'), ('report'...
# 20  [[('portrait', 'NN'), ('strategy', 'NN'), ('ma...
# 21  [[('sustainability', 'NN'), ('supplementing', ...
# 22  [[], [('sustainy', 'JJ'), ('report', 'NN'), ('...
# 23  [[('focus', 'NN'), ('tomorrow', 'NN')], [('sus...
# 24  [[('overview', 'JJ'), ('sustainability', 'NN')...
# 25  [[('sustainability', 'NN'), ('report', 'VBP'),...
# 26  [[('standwithukraine', 'JJ'), ('sustainability...
# 27  [[('sustainability', 'NN'), ('report', 'NN'), ...
# 28  [[('sustainability', 'NN'), ('report', 'NN'), ...
# 29  [[('sustainability', 'NN'), ('purpose', 'JJ'),...
# 30  [[('corporate', 'JJ'), ('responsibility', 'NN'...
# 31  [[('integrated', 'VBN'), ('report', 'NN'), ('c...
# 32  [[('stedim', 'NN'), ('biotech', 'NN'), ('gri',...
# 33  [[('combined', 'VBN'), ('management', 'NN'), (...
# 34  [[('sustainability', 'NN'), ('report', 'NN'), ...
# 35  [[('vonovia', 'NN'), ('se', 'JJ'), ('sustainab...
# 36  [[('brenntag', 'NN'), ('se', 'NN'), ('sustaina...
#
#                                          company_name symbol  \
# 0                                      Rheinmetall AG    RHM
# 1                                   Siemens Energy AG    ENR
# 2                                          Symrise AG    SY1
# 3                                      Continental AG    CON
# 4                                    Deutsche Bank AG    DBK
# 5                                         Covestro AG   1COV
# 6                                 MTU Aero Engines AG    MTX
# 7                                            Bayer AG   BAYN
# 8   Münchener Rückversicherungs-Gesellschaft Aktie...   MUV2
# 9                                          Zalando SE    ZAL
# 10                        Bayerische Motoren Werke AG    BMW
# 11                                  Deutsche Börse AG    DB1
# 12                             Fresenius SE & Co KGaA    FRE
# 13                                          adidas AG    ADS
# 14                                      Beiersdorf AG    BEI
# 15                                   Hannover Rück SE   HNRB
# 16                                         Allianz SE    ALV
# 17                                     Commerzbank AG    CBK
# 18                       Porsche Automobil Holding SE   PAH3
# 19                                            BASF SE    BAS
# 20                            Heidelberg Materials AG    HEI
# 21                           Infineon Technologies AG    IFX
# 22                                        Qiagen N.V.    QIA
# 23                                             RWE AG    RWE
# 24                                          Airbus SE    AIR
# 25                                      Volkswagen AG    VOW
# 26                                            E.ON SE   EOAN
# 27                             Mercedes-Benz Group AG    DAI
# 28                                Henkel AG & Co KGaA    HEN
# 29                                         Siemens AG    SIE
# 30                                Deutsche Telekom AG    DTE
# 31                                             SAP SE    SAP
# 32                                       Sartorius AG    SRT
# 33                                   Deutsche Post AG    DHL
# 34             MERCK Kommanditgesellschaft auf Aktien    MRK
# 35                                         Vonovia SE    VNA
# 36                                        Brenntag AG    BNR
#
#     market_cap_in_usd_b      country                  sector  \
# 0                 11.96      Germany             Industrials
# 1                 13.82      Germany               Utilities
# 2                 14.81      Germany         Basic Materials
# 3                 15.16      Germany  Consumer Discretionary
# 4                 21.13      Germany              Financials
# 5                  9.87      Germany         Basic Materials
# 6                 13.21      Germany             Industrials
# 7                 53.38      Germany              Healthcare
# 8                 49.87      Germany              Financials
# 9                  6.92      Germany  Consumer Discretionary
# 10                77.25      Germany  Consumer Discretionary
# 11                32.32      Germany              Financials
# 12                15.90      Germany              Healthcare
# 13                33.41      Germany  Consumer Discretionary
# 14                28.61      Germany        Consumer Staples
# 15                24.66      Germany              Financials
# 16                91.36      Germany              Financials
# 17                14.96      Germany              Financials
# 18                17.87      Germany  Consumer Discretionary
# 19                44.37      Germany         Basic Materials
# 20                14.65      Germany         Basic Materials
# 21                50.42      Germany              Technology
# 22                10.49  Netherlands              Healthcare
# 23                32.35      Germany               Utilities
# 24               113.90  Netherlands             Industrials
# 25                77.55      Germany  Consumer Discretionary
# 26                32.95      Germany               Utilities
# 27                84.94      Germany  Consumer Discretionary
# 28                30.65      Germany        Consumer Staples
# 29               131.00      Germany             Industrials
# 30               106.00      Germany  Communication Services
# 31               161.41      Germany              Technology
# 32                21.43      Germany              Healthcare
# 33                57.95      Germany             Industrials
# 34                70.69      Germany              Healthcare
# 35                15.69      Germany             Real Estate
# 36                11.76      Germany         Basic Materials
#
#                                   industry
# 0                  Industrial Distribution
# 1    Utilities—Independent Power Producers
# 2                      Specialty Chemicals
# 3                               Auto Parts
# 4                           Banks—Regional
# 5                      Specialty Chemicals
# 6                      Aerospace & Defense
# 7               Drug Manufacturers—General
# 8                    Insurance—Reinsurance
# 9                          Internet Retail
# 10                      Auto Manufacturers
# 11        Financial Data & Stock Exchanges
# 12                 Medical Care Facilities
# 13                  Footwear & Accessories
# 14           Household & Personal Products
# 15                   Insurance—Reinsurance
# 16                   Insurance—Diversified
# 17                          Banks—Regional
# 18                      Auto Manufacturers
# 19                               Chemicals
# 20                      Building Materials
# 21                          Semiconductors
# 22                  Diagnostics & Research
# 23                   Utilities—Diversified
# 24                     Aerospace & Defense
# 25                      Auto Manufacturers
# 26                   Utilities—Diversified
# 27                      Auto Manufacturers
# 28           Household & Personal Products
# 29          Specialty Industrial Machinery
# 30                        Telecom Services
# 31                    Software—Application
# 32          Medical Instruments & Supplies
# 33          Integrated Freight & Logistics
# 34  Drug Manufacturers—Specialty & Generic
# 35                    Real Estate Services
# 36                     Specialty Chemicals

# %%
merged_data.shape
# Out:
# (37, 17)

# %% [markdown]
# **Calculate Sentiment Value with Polarity Score**
#
# As a last preprocessing step, the sentiment is calculated with the (quite basic) SentimentIntensityAnalyzer.

# %%
enriched_cleaned_data = merged_data.copy(deep=True)

# %%
# %pip install vaderSentiment
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

sia = SentimentIntensityAnalyzer()

def get_sentiment_score(sentences):
    """
    Computes the sentiment score for a given list of sentences.

    Args:
        sentences (list): The sentences to compute the sentiment score for.

    Returns:
        float: The sentiment score of the text as a float between -1 and 1.
    """
    # Compute sentiment scores for each sentence and store them in a list
    sentiment_scores = [sia.polarity_scores(sentence)['compound'] for sentence in sentences]

    # Compute the average sentiment score
    avg_sentiment_score = np.mean(sentiment_scores) if sentiment_scores else 0

    return avg_sentiment_score

# Sentiment score calculation provided most "balanced" results with averaged sentence tokens. Therefore the sentiment is calculated on these texts.
enriched_cleaned_data['st1_sentiment_continuous'] = enriched_cleaned_data['sentence_tokens'].apply(get_sentiment_score)
# Out:
# Requirement already satisfied: vaderSentiment in /Users/seyyiduzun/opt/miniconda3/envs/bachelor/lib/python3.12/site-packages (3.3.2)
# Requirement already satisfied: requests in /Users/seyyiduzun/opt/miniconda3/envs/bachelor/lib/python3.12/site-packages (from vaderSentiment) (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/seyyiduzun/opt/miniconda3/envs/bachelor/lib/python3.12/site-packages (from requests->vaderSentiment) (3.3.1)
# Requirement already satisfied: idna<4,>=2.5 in /Users/seyyiduzun/opt/miniconda3/envs/bachelor/lib/python3.12/site-packages (from requests->vaderSentiment) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/seyyiduzun/opt/miniconda3/envs/bachelor/lib/python3.12/site-packages (from requests->vaderSentiment) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/seyyiduzun/opt/miniconda3/envs/bachelor/lib/python3.12/site-packages (from requests->vaderSentiment) (2023.7.22)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Save the dataframe as output
if not os.path.exists('./output/'):
    os.makedirs('./output/')

filename = 'stage1_output_2021'

# Save DataFrame to CSV
enriched_cleaned_data.to_csv(f'./output/{filename}.csv', index=False, sep='|')
print(f'Saved DataFrame to {filename}.csv')
# Out:
# Saved DataFrame to stage1_output_2021.csv

# %%
enriched_cleaned_data.head(49)
# Out:
#                                               company  \
# 0                                      Rheinmetall AG
# 1                                   Siemens Energy AG
# 2                                          Symrise AG
# 3                                      Continental AG
# 4                                    Deutsche Bank AG
# 5                                         Covestro AG
# 6                                 MTU Aero Engines AG
# 7                                            Bayer AG
# 8   Münchener Rückversicherungs-Gesellschaft Aktie...
# 9                                          Zalando SE
# 10                        Bayerische Motoren Werke AG
# 11                                  Deutsche Börse AG
# 12                             Fresenius SE & Co KGaA
# 13                                          adidas AG
# 14                                      Beiersdorf AG
# 15                                   Hannover Rück SE
# 16                                         Allianz SE
# 17                                     Commerzbank AG
# 18                       Porsche Automobil Holding SE
# 19                                            BASF SE
# 20                            Heidelberg Materials AG
# 21                           Infineon Technologies AG
# 22                                        Qiagen N.V.
# 23                                             RWE AG
# 24                                          Airbus SE
# 25                                      Volkswagen AG
# 26                                            E.ON SE
# 27                             Mercedes-Benz Group AG
# 28                                Henkel AG & Co KGaA
# 29                                         Siemens AG
# 30                                Deutsche Telekom AG
# 31                                             SAP SE
# 32                                       Sartorius AG
# 33                                   Deutsche Post AG
# 34             MERCK Kommanditgesellschaft auf Aktien
# 35                                         Vonovia SE
# 36                                        Brenntag AG
#
#                                               content               datatype  \
# 0   Basic information on the rheinmetall GroupStru...  Sustainability Report
# 1   Sustainability Report 2021 \n\nCreating transp...  Sustainability Report
# 2   20 \n21 \n\nSustainability Record  \n(GRI) \n\...  Sustainability Report
# 3   Turn Change Into Opportunity – \nEmbrace Susta...  Sustainability Report
# 4   Deutsche Bank\n\n Non-Financial Report \n2021\...  Sustainability Report
# 5   COMBINED \n MANAGEMENT REPORT\n\nCOMBINED MANA...  Sustainability Report
# 6   Acting for tomorrow, today  \nOUR RESPONSIBILI...  Sustainability Report
# 7   Sustainability Report\n\n2021\n\n
# Contents \n\...  Sustainability Report
# 8   Sustainability \nReport 2021\n\n
# Munich Re  \n...  Sustainability Report
# 9   Sustainability \nProgress Report\n2021\n\n
# Our...  Sustainability Report
# 10  2MANAGEMENT REPORTCOMBINED34 Overview of the B...  Sustainability Report
# 11  Combined  \nmanagement report\n\n20\n\nWhat we...  Sustainability Report
# 12  SEPARATE  \nGROUP NON-FINANCIAL REPORT\n\n 115...  Sustainability Report
# 13  1 \nTO OUR SHAREHOLDERS \n\n2 \nGROUP MANAGEME...  Sustainability Report
# 14  Sustainability Highlight Report\n\nCARE  \nBEY...  Sustainability Report
# 15  Sustainability Report 2021\n\n  \n
# 2\n\nHannov...  Sustainability Report
# 16  Allianz Group Sustainability Report 2021\n\nBu...  Sustainability Report
# 17  40 \n\nCommerzbank Annual Report 2021 \n\nComb...  Sustainability Report
# 18  SUSTAINABILITY MANAGEMENT \nSustainability str...  Sustainability Report
# 19  BASF Report 2021\n\nReport\n\n2 Management’s \...  Sustainability Report
# 20  Company \nPortrait\n\nStrategy & \nManagement\...  Sustainability Report
# 21  Sustainability at Infineon\nSupplementing the ...  Sustainability Report
# 22  1\n\nForeword\n\nOur Company\n\nEnvironment\n\...  Sustainability Report
# 23  Focus \non tomorrow.\n\nSustainability Report ...  Sustainability Report
# 24  Overview  /  Sustainability\n\n13\n\nPrioritis...  Sustainability Report
# 25  SUSTAINABILITY REPORT\n\n2021\n\n
# NEW AUTO: VO...  Sustainability Report
# 26  #StandWithUkraine\n\nSustainability \nReport 2...  Sustainability Report
# 27  Sustainability Report 2021\n\nmaximum image ar...  Sustainability Report
# 28  SUSTAINABILITY \nREPORT\n\n2021\n\n
# HENKEL SUS...  Sustainability Report
# 29  Sustainability  report2021
# Our Purpose\n\n  Te...  Sustainability Report
# 30  Corporate Responsibility \nBericht 2021\n\n
# 2\...  Sustainability Report
# 31  SAP Integrated Report 2021 \n\nTo Our  \nStake...  Sustainability Report
# 32  Sartorius Stedim Biotech S.A. \n\nGRI Report 2...  Sustainability Report
# 33  COMBINED MANAGEMENT REPORT NON-FINANCIAL  STAT...  Sustainability Report
# 34  Sustainability Report\n\n2021\n\n
# TABLE OF CON...  Sustainability Report
# 35  VONOVIA SE\nSUSTAINABILITY REPORT 2021\n\n=\n\...  Sustainability Report
# 36  S U S T A I N A B I L I T Y   R E P O R T\n202...  Sustainability Report
#
#     date  internal title                                    cleaned_content  \
# 0   2021         1   the  basic information rheinmetall groupstructure r...
# 1   2021         1     ,  sustainability report creating transparency si...
# 2   2021         1   the  gri sustainability record us international sta...
# 3   2021         1   the  turn change opportunity embrace sustainability...
# 4   2021         1   and  deutsche bank nonfinancial report letter chief...
# 5   2021         1   the  combined management report combined management...
# 6   2021         1   the  acting tomorrow today responsibility plan sust...
# 7   2021         1   the  sustainability report editorial report crop pr...
# 8   2021         1     .  sustainability report sustainability report an...
# 9   2021         1     ,  sustainability progress report progress glance...
# 10  2021         1   the  2management reportcombined34 overview group34 ...
# 11  2021         1   the  combined management report achieved report deu...
# 12  2021         1   the  separate group nonfinancial report strategy ma...
# 13  2021         1     ,  group management report financial review conso...
# 14  2021         1   our  sustainability highlight report care beyond sk...
# 15  2021         1   the  sustainability report sustainability report gr...
# 16  2021         1   and  group sustainability report building confidenc...
# 17  2021         1   the  financial report directive stipulated commerzb...
# 18  2021         1   the  sustainability management sustainability strat...
# 19  2021         1   the  basf report report management overview nonfina...
# 20  2021         1   the  portrait strategy management business complian...
# 21  2021         1   the  sustainability supplementing annual report nav...
# 22  2021         1   and  sustainy report sustainability report governan...
# 23  2021         1   the  focus tomorrow sustainability report energy su...
# 24  2021         1   the  overview sustainability prioritising sustainab...
# 25  2021         1   the  sustainability report new auto reinvents world...
# 26  2021         1     ,  standwithukraine sustainability report search ...
# 27  2021         1   the  sustainability report maximum image areaminimu...
# 28  2021         1   the  sustainability report henkel sustainability re...
# 29  2021         1   the  sustainability purpose technology transform ev...
# 30  2021         1     .  corporate responsibility inhalt diesis pdfdoku...
# 31  2021         1     ,  integrated report stakeholder combined group m...
# 32  2021         1   the  stedim biotech sa gri report stedim biotech gr...
# 33  2021         1   the  combined management report nonfinancial statem...
# 34  2021         1     ,  sustainability report strategy management yees...
# 35  2021         1   the  vonovia se sustainability report sustainable f...
# 36  2021         1   the  brenntag se sustainability report brenntag wor...
#
#                                           word_tokens  \
# 0   ['basic', 'information', 'rheinmetall', 'group...
# 1   ['sustainability', 'report', 'creating', 'tran...
# 2   ['gri', 'sustainability', 'record', 'us', 'int...
# 3   ['turn', 'change', 'opportunity', 'embrace', '...
# 4   ['deutsche', 'bank', 'nonfinancial', 'report',...
# 5   ['combined', 'management', 'report', 'combined...
# 6   ['acting', 'tomorrow', 'today', 'responsibilit...
# 7   ['sustainability', 'report', 'editorial', 'rep...
# 8   ['sustainability', 'report', 'sustainability',...
# 9   ['sustainability', 'progress', 'report', 'prog...
# 10  ['2management', 'reportcombined34', 'overview'...
# 11  ['combined', 'management', 'report', 'achieved...
# 12  ['separate', 'group', 'nonfinancial', 'report'...
# 13  ['group', 'management', 'report', 'financial',...
# 14  ['sustainability', 'highlight', 'report', 'car...
# 15  ['sustainability', 'report', 'sustainability',...
# 16  ['group', 'sustainability', 'report', 'buildin...
# 17  ['financial', 'report', 'directive', 'stipulat...
# 18  ['sustainability', 'management', 'sustainabili...
# 19  ['basf', 'report', 'report', 'management', 'ov...
# 20  ['portrait', 'strategy', 'management', 'busine...
# 21  ['sustainability', 'supplementing', 'annual', ...
# 22  ['sustainy', 'report', 'sustainability', 'repo...
# 23  ['focus', 'tomorrow', 'sustainability', 'repor...
# 24  ['overview', 'sustainability', 'prioritising',...
# 25  ['sustainability', 'report', 'new', 'auto', 'r...
# 26  ['standwithukraine', 'sustainability', 'report...
# 27  ['sustainability', 'report', 'maximum', 'image...
# 28  ['sustainability', 'report', 'henkel', 'sustai...
# 29  ['sustainability', 'purpose', 'technology', 't...
# 30  ['corporate', 'responsibility', 'inhalt', 'die...
# 31  ['integrated', 'report', 'stakeholder', 'combi...
# 32  ['stedim', 'biotech', 'sa', 'gri', 'report', '...
# 33  ['combined', 'management', 'report', 'nonfinan...
# 34  ['sustainability', 'report', 'strategy', 'mana...
# 35  ['vonovia', 'se', 'sustainability', 'report', ...
# 36  ['brenntag', 'se', 'sustainability', 'report',...
#
#                                       sentence_tokens  \
# 0   ['basic information rheinmetall groupstructure...
# 1   ['sustainability report creating transparency ...
# 2   ['gri sustainability record uses international...
# 3   ['turn change opportunity embrace sustainabili...
# 4   ['deutsche bank nonfinancial report letter chi...
# 5   ['combined management report combined manageme...
# 6   ['acting tomorrow today responsibility plans s...
# 7   ['sustainability report editorial report crop ...
# 8   ['sustainability report sustainability report ...
# 9   ['sustainability progress report progress glan...
# 10  ['overview organisational business model group...
# 11  ['combined management report achieved report d...
# 12  ['separate group nonfinancial report strategy ...
# 13  ['group management report financial review con...
# 14  ['sustainability highlight report care beyond ...
# 15  ['sustainability report sustainability report ...
# 16  ['group sustainability report building confide...
# 17  ['financial report directives stipulated comme...
# 18  ['sustainability management sustainability str...
# 19  ['basf report report management overview nonfi...
# 20  ['portrait strategy management business compli...
# 21  ['sustainability supplementing annual report n...
# 22  ['', 'sustainy report sustainability report go...
# 23  ['focus tomorrow', 'sustainability report ener...
# 24  ['overview sustainability prioritising sustain...
# 25  ['sustainability report new auto reinvents wor...
# 26  ['standwithukraine sustainability report searc...
# 27  ['sustainability report maximum image areamini...
# 28  ['sustainability report henkel sustainability ...
# 29  ['sustainability purpose technology transform ...
# 30  ['corporate responsibility inhalt dieses pdfdo...
# 31  ['integrated report stakeholders combined grou...
# 32  ['stedim biotech gri report stedim biotech gri...
# 33  ['combined management report nonfinancial stat...
# 34  ['sustainability report strategy management ye...
# 35  ['vonovia se sustainability report sustainable...
# 36  ['brenntag se sustainability report brenntag w...
#
#                                pos_tagged_word_tokens  \
# 0   [('basic', 'JJ'), ('information', 'NN'), ('rhe...
# 1   [('sustainability', 'NN'), ('report', 'NN'), (...
# 2   [('gri', 'JJ'), ('sustainability', 'NN'), ('re...
# 3   [('turn', 'NN'), ('change', 'NN'), ('opportuni...
# 4   [('deutsche', 'NN'), ('bank', 'NN'), ('nonfina...
# 5   [('combined', 'JJ'), ('management', 'NN'), ('r...
# 6   [('acting', 'VBG'), ('tomorrow', 'NN'), ('toda...
# 7   [('sustainability', 'NN'), ('report', 'NN'), (...
# 8   [('sustainability', 'NN'), ('report', 'NN'), (...
# 9   [('sustainability', 'NN'), ('progress', 'NN'),...
# 10  [('2management', 'CD'), ('reportcombined34', '...
# 11  [('combined', 'JJ'), ('management', 'NN'), ('r...
# 12  [('separate', 'JJ'), ('group', 'NN'), ('nonfin...
# 13  [('group', 'NN'), ('management', 'NN'), ('repo...
# 14  [('sustainability', 'NN'), ('highlight', 'VBD'...
# 15  [('sustainability', 'NN'), ('report', 'NN'), (...
# 16  [('group', 'NN'), ('sustainability', 'NN'), ('...
# 17  [('financial', 'JJ'), ('report', 'NN'), ('dire...
# 18  [('sustainability', 'NN'), ('management', 'NN'...
# 19  [('basf', 'JJ'), ('report', 'NN'), ('report', ...
# 20  [('portrait', 'NN'), ('strategy', 'NN'), ('man...
# 21  [('sustainability', 'NN'), ('supplementing', '...
# 22  [('sustainy', 'JJ'), ('report', 'NN'), ('susta...
# 23  [('focus', 'NN'), ('tomorrow', 'NN'), ('sustai...
# 24  [('overview', 'NN'), ('sustainability', 'NN'),...
# 25  [('sustainability', 'NN'), ('report', 'NN'), (...
# 26  [('standwithukraine', 'JJ'), ('sustainability'...
# 27  [('sustainability', 'NN'), ('report', 'NN'), (...
# 28  [('sustainability', 'NN'), ('report', 'NN'), (...
# 29  [('sustainability', 'NN'), ('purpose', 'NN'), ...
# 30  [('corporate', 'JJ'), ('responsibility', 'NN')...
# 31  [('integrated', 'JJ'), ('report', 'NN'), ('sta...
# 32  [('stedim', 'NN'), ('biotech', 'NN'), ('sa', '...
# 33  [('combined', 'JJ'), ('management', 'NN'), ('r...
# 34  [('sustainability', 'NN'), ('report', 'NN'), (...
# 35  [('vonovia', 'NN'), ('se', 'JJ'), ('sustainabi...
# 36  [('brenntag', 'NN'), ('se', 'JJ'), ('sustainab...
#
#                            pos_tagged_sentence_tokens  \
# 0   [[('basic', 'JJ'), ('information', 'NN'), ('rh...
# 1   [[('sustainability', 'NN'), ('report', 'NN'), ...
# 2   [[('gri', 'NN'), ('sustainability', 'JJ'), ('r...
# 3   [[('turn', 'NN'), ('change', 'NN'), ('opportun...
# 4   [[('deutsche', 'NN'), ('bank', 'NN'), ('nonfin...
# 5   [[('combined', 'VBD'), ('management', 'NN'), (...
# 6   [[('acting', 'VBG'), ('tomorrow', 'NN'), ('tod...
# 7   [[('sustainability', 'NN'), ('report', 'NN'), ...
# 8   [[('sustainability', 'NN'), ('report', 'NN'), ...
# 9   [[('sustainability', 'NN'), ('progress', 'NN')...
# 10  [[('overview', 'NN'), ('organisational', 'JJ')...
# 11  [[('combined', 'VBD'), ('management', 'NN'), (...
# 12  [[('separate', 'JJ'), ('group', 'NN'), ('nonfi...
# 13  [[('group', 'NN'), ('management', 'NN'), ('rep...
# 14  [[('sustainability', 'NN'), ('highlight', 'VBD...
# 15  [[('sustainability', 'NN'), ('report', 'NN'), ...
# 16  [[('group', 'NN'), ('sustainability', 'NN'), (...
# 17  [[('financial', 'JJ'), ('report', 'NN'), ('sti...
# 18  [[('sustainability', 'NN'), ('management', 'NN...
# 19  [[('basf', 'VBD'), ('report', 'NN'), ('report'...
# 20  [[('portrait', 'NN'), ('strategy', 'NN'), ('ma...
# 21  [[('sustainability', 'NN'), ('supplementing', ...
# 22  [[], [('sustainy', 'JJ'), ('report', 'NN'), ('...
# 23  [[('focus', 'NN'), ('tomorrow', 'NN')], [('sus...
# 24  [[('overview', 'JJ'), ('sustainability', 'NN')...
# 25  [[('sustainability', 'NN'), ('report', 'VBP'),...
# 26  [[('standwithukraine', 'JJ'), ('sustainability...
# 27  [[('sustainability', 'NN'), ('report', 'NN'), ...
# 28  [[('sustainability', 'NN'), ('report', 'NN'), ...
# 29  [[('sustainability', 'NN'), ('purpose', 'JJ'),...
# 30  [[('corporate', 'JJ'), ('responsibility', 'NN'...
# 31  [[('integrated', 'VBN'), ('report', 'NN'), ('c...
# 32  [[('stedim', 'NN'), ('biotech', 'NN'), ('gri',...
# 33  [[('combined', 'VBN'), ('management', 'NN'), (...
# 34  [[('sustainability', 'NN'), ('report', 'NN'), ...
# 35  [[('vonovia', 'NN'), ('se', 'JJ'), ('sustainab...
# 36  [[('brenntag', 'NN'), ('se', 'NN'), ('sustaina...
#
#                                          company_name symbol  \
# 0                                      Rheinmetall AG    RHM
# 1                                   Siemens Energy AG    ENR
# 2                                          Symrise AG    SY1
# 3                                      Continental AG    CON
# 4                                    Deutsche Bank AG    DBK
# 5                                         Covestro AG   1COV
# 6                                 MTU Aero Engines AG    MTX
# 7                                            Bayer AG   BAYN
# 8   Münchener Rückversicherungs-Gesellschaft Aktie...   MUV2
# 9                                          Zalando SE    ZAL
# 10                        Bayerische Motoren Werke AG    BMW
# 11                                  Deutsche Börse AG    DB1
# 12                             Fresenius SE & Co KGaA    FRE
# 13                                          adidas AG    ADS
# 14                                      Beiersdorf AG    BEI
# 15                                   Hannover Rück SE   HNRB
# 16                                         Allianz SE    ALV
# 17                                     Commerzbank AG    CBK
# 18                       Porsche Automobil Holding SE   PAH3
# 19                                            BASF SE    BAS
# 20                            Heidelberg Materials AG    HEI
# 21                           Infineon Technologies AG    IFX
# 22                                        Qiagen N.V.    QIA
# 23                                             RWE AG    RWE
# 24                                          Airbus SE    AIR
# 25                                      Volkswagen AG    VOW
# 26                                            E.ON SE   EOAN
# 27                             Mercedes-Benz Group AG    DAI
# 28                                Henkel AG & Co KGaA    HEN
# 29                                         Siemens AG    SIE
# 30                                Deutsche Telekom AG    DTE
# 31                                             SAP SE    SAP
# 32                                       Sartorius AG    SRT
# 33                                   Deutsche Post AG    DHL
# 34             MERCK Kommanditgesellschaft auf Aktien    MRK
# 35                                         Vonovia SE    VNA
# 36                                        Brenntag AG    BNR
#
#     market_cap_in_usd_b      country                  sector  \
# 0                 11.96      Germany             Industrials
# 1                 13.82      Germany               Utilities
# 2                 14.81      Germany         Basic Materials
# 3                 15.16      Germany  Consumer Discretionary
# 4                 21.13      Germany              Financials
# 5                  9.87      Germany         Basic Materials
# 6                 13.21      Germany             Industrials
# 7                 53.38      Germany              Healthcare
# 8                 49.87      Germany              Financials
# 9                  6.92      Germany  Consumer Discretionary
# 10                77.25      Germany  Consumer Discretionary
# 11                32.32      Germany              Financials
# 12                15.90      Germany              Healthcare
# 13                33.41      Germany  Consumer Discretionary
# 14                28.61      Germany        Consumer Staples
# 15                24.66      Germany              Financials
# 16                91.36      Germany              Financials
# 17                14.96      Germany              Financials
# 18                17.87      Germany  Consumer Discretionary
# 19                44.37      Germany         Basic Materials
# 20                14.65      Germany         Basic Materials
# 21                50.42      Germany              Technology
# 22                10.49  Netherlands              Healthcare
# 23                32.35      Germany               Utilities
# 24               113.90  Netherlands             Industrials
# 25                77.55      Germany  Consumer Discretionary
# 26                32.95      Germany               Utilities
# 27                84.94      Germany  Consumer Discretionary
# 28                30.65      Germany        Consumer Staples
# 29               131.00      Germany             Industrials
# 30               106.00      Germany  Communication Services
# 31               161.41      Germany              Technology
# 32                21.43      Germany              Healthcare
# 33                57.95      Germany             Industrials
# 34                70.69      Germany              Healthcare
# 35                15.69      Germany             Real Estate
# 36                11.76      Germany         Basic Materials
#
#                                   industry  st1_sentiment_continuous
# 0                  Industrial Distribution                  0.019156
# 1    Utilities—Independent Power Producers                  0.018045
# 2                      Specialty Chemicals                  0.018819
# 3                               Auto Parts                  0.017767
# 4                           Banks—Regional                  0.017723
# 5                      Specialty Chemicals                  0.018556
# 6                      Aerospace & Defense                  0.018378
# 7               Drug Manufacturers—General                  0.018680
# 8                    Insurance—Reinsurance                  0.018395
# 9                          Internet Retail                  0.015273
# 10                      Auto Manufacturers                  0.017979
# 11        Financial Data & Stock Exchanges                  0.015751
# 12                 Medical Care Facilities                  0.018011
# 13                  Footwear & Accessories                  0.018259
# 14           Household & Personal Products                  0.019817
# 15                   Insurance—Reinsurance                  0.018542
# 16                   Insurance—Diversified                  0.018116
# 17                          Banks—Regional                  0.017837
# 18                      Auto Manufacturers                  0.018476
# 19                               Chemicals                  0.018786
# 20                      Building Materials                  0.018709
# 21                          Semiconductors                  0.018381
# 22                  Diagnostics & Research                  0.019487
# 23                   Utilities—Diversified                  0.013654
# 24                     Aerospace & Defense                  0.017821
# 25                      Auto Manufacturers                  0.017304
# 26                   Utilities—Diversified                  0.017514
# 27                      Auto Manufacturers                  0.018746
# 28           Household & Personal Products                  0.018979
# 29          Specialty Industrial Machinery                  0.019526
# 30                        Telecom Services                  0.014531
# 31                    Software—Application                  0.018051
# 32          Medical Instruments & Supplies                  0.017118
# 33          Integrated Freight & Logistics                  0.018219
# 34  Drug Manufacturers—Specialty & Generic                  0.018736
# 35                    Real Estate Services                  0.017565
# 36                     Specialty Chemicals                  0.018195

# %%
enriched_cleaned_data.shape
# Out:
# (37, 18)

# %%
enriched_cleaned_data_new = enriched_cleaned_data.copy(deep=True)

# %%
# Define a dictionary with the old company names as keys and new company names as values
company_name_mapping = {
"SAP SE": "SAP",
"Infineon Technologies AG": "Infineon",
"BASF SE": "BASF",
"Porsche Automobil Holding SE": "Porsche",
"Commerzbank AG": "Commerzbank",
"Qiagen N.V.": "Qiagen",
"Henkel AG & Co KGaA": "Henkel",
"Mercedes-Benz Group AG": "MercedesBenz",
"Airbus SE": "Airbus",
"RWE AG": "RWE",
"E.ON SE": "EON",
"Volkswagen AG": "Volkswagen",
"Brenntag AG": "Brenntag",
"Vonovia SE": "Vonovia",
"Sartorius AG": "Sartorius",
"Deutsche Telekom AG": "Telekom",
"MERCK Kommanditgesellschaft auf Aktien": "Merck",
"Deutsche Post AG": "DHL",
"Siemens AG": "Siemens",
"Siemens Energy AG": "SiemensEnergy",
"Symrise AG": "Symrise",
"Rheinmetall AG": "Rheinmetall",
"MTU Aero Engines AG": "MTU",
"Deutsche Bank AG": "DeutscheBank",
"Deutsche Börse AG": "DeutscheBoerse",
"Zalando SE": "Zalando",
"Münchener Rückversicherungs-Gesellschaft Aktiengesellschaft in München": "MuenchenerRueck",
"Bayer AG": "Bayer",
"Continental AG": "Continental",
"Allianz SE": "Allianz",
"Beiersdorf AG": "Beiersdorf",
"Hannover Rück SE": "HannoverRueck",
"Fresenius SE & Co KGaA": "Fresenius",
"adidas AG": "Adidas",
"Covestro AG": "Covestro",
"Bayerische Motoren Werke AG": "BMW",
"Heidelberg Materials AG": "HeidelbergMaterials"  

  # Add more mappings as needed
}

# Replace the company names in the 'Company' column
enriched_cleaned_data_new['company'] = enriched_cleaned_data_new['company'].replace(company_name_mapping)

# %%
enriched_cleaned_data_new.head(37)
# Out:
#                 company                                            content  \
# 0           Rheinmetall  Basic information on the rheinmetall GroupStru...
# 1         SiemensEnergy  Sustainability Report 2021 \n\nCreating transp...
# 2               Symrise  20 \n21 \n\nSustainability Record  \n(GRI) \n\...
# 3           Continental  Turn Change Into Opportunity – \nEmbrace Susta...
# 4          DeutscheBank  Deutsche Bank\n\n Non-Financial Report \n2021\...
# 5              Covestro  COMBINED \n MANAGEMENT REPORT\n\nCOMBINED MANA...
# 6                   MTU  Acting for tomorrow, today  \nOUR RESPONSIBILI...
# 7                 Bayer  Sustainability Report\n\n2021\n\n
# Contents \n\...
# 8       MuenchenerRueck  Sustainability \nReport 2021\n\n
# Munich Re  \n...
# 9               Zalando  Sustainability \nProgress Report\n2021\n\n
# Our...
# 10                  BMW  2MANAGEMENT REPORTCOMBINED34 Overview of the B...
# 11       DeutscheBoerse  Combined  \nmanagement report\n\n20\n\nWhat we...
# 12            Fresenius  SEPARATE  \nGROUP NON-FINANCIAL REPORT\n\n 115...
# 13               Adidas  1 \nTO OUR SHAREHOLDERS \n\n2 \nGROUP MANAGEME...
# 14           Beiersdorf  Sustainability Highlight Report\n\nCARE  \nBEY...
# 15        HannoverRueck  Sustainability Report 2021\n\n  \n
# 2\n\nHannov...
# 16              Allianz  Allianz Group Sustainability Report 2021\n\nBu...
# 17          Commerzbank  40 \n\nCommerzbank Annual Report 2021 \n\nComb...
# 18              Porsche  SUSTAINABILITY MANAGEMENT \nSustainability str...
# 19                 BASF  BASF Report 2021\n\nReport\n\n2 Management’s \...
# 20  HeidelbergMaterials  Company \nPortrait\n\nStrategy & \nManagement\...
# 21             Infineon  Sustainability at Infineon\nSupplementing the ...
# 22               Qiagen  1\n\nForeword\n\nOur Company\n\nEnvironment\n\...
# 23                  RWE  Focus \non tomorrow.\n\nSustainability Report ...
# 24               Airbus  Overview  /  Sustainability\n\n13\n\nPrioritis...
# 25           Volkswagen  SUSTAINABILITY REPORT\n\n2021\n\n
# NEW AUTO: VO...
# 26                  EON  #StandWithUkraine\n\nSustainability \nReport 2...
# 27         MercedesBenz  Sustainability Report 2021\n\nmaximum image ar...
# 28               Henkel  SUSTAINABILITY \nREPORT\n\n2021\n\n
# HENKEL SUS...
# 29              Siemens  Sustainability  report2021
# Our Purpose\n\n  Te...
# 30              Telekom  Corporate Responsibility \nBericht 2021\n\n
# 2\...
# 31                  SAP  SAP Integrated Report 2021 \n\nTo Our  \nStake...
# 32            Sartorius  Sartorius Stedim Biotech S.A. \n\nGRI Report 2...
# 33                  DHL  COMBINED MANAGEMENT REPORT NON-FINANCIAL  STAT...
# 34                Merck  Sustainability Report\n\n2021\n\n
# TABLE OF CON...
# 35              Vonovia  VONOVIA SE\nSUSTAINABILITY REPORT 2021\n\n=\n\...
# 36             Brenntag  S U S T A I N A B I L I T Y   R E P O R T\n202...
#
#                  datatype  date  internal title  \
# 0   Sustainability Report  2021         1   the
# 1   Sustainability Report  2021         1     ,
# 2   Sustainability Report  2021         1   the
# 3   Sustainability Report  2021         1   the
# 4   Sustainability Report  2021         1   and
# 5   Sustainability Report  2021         1   the
# 6   Sustainability Report  2021         1   the
# 7   Sustainability Report  2021         1   the
# 8   Sustainability Report  2021         1     .
# 9   Sustainability Report  2021         1     ,
# 10  Sustainability Report  2021         1   the
# 11  Sustainability Report  2021         1   the
# 12  Sustainability Report  2021         1   the
# 13  Sustainability Report  2021         1     ,
# 14  Sustainability Report  2021         1   our
# 15  Sustainability Report  2021         1   the
# 16  Sustainability Report  2021         1   and
# 17  Sustainability Report  2021         1   the
# 18  Sustainability Report  2021         1   the
# 19  Sustainability Report  2021         1   the
# 20  Sustainability Report  2021         1   the
# 21  Sustainability Report  2021         1   the
# 22  Sustainability Report  2021         1   and
# 23  Sustainability Report  2021         1   the
# 24  Sustainability Report  2021         1   the
# 25  Sustainability Report  2021         1   the
# 26  Sustainability Report  2021         1     ,
# 27  Sustainability Report  2021         1   the
# 28  Sustainability Report  2021         1   the
# 29  Sustainability Report  2021         1   the
# 30  Sustainability Report  2021         1     .
# 31  Sustainability Report  2021         1     ,
# 32  Sustainability Report  2021         1   the
# 33  Sustainability Report  2021         1   the
# 34  Sustainability Report  2021         1     ,
# 35  Sustainability Report  2021         1   the
# 36  Sustainability Report  2021         1   the
#
#                                       cleaned_content  \
# 0   basic information rheinmetall groupstructure r...
# 1   sustainability report creating transparency si...
# 2   gri sustainability record us international sta...
# 3   turn change opportunity embrace sustainability...
# 4   deutsche bank nonfinancial report letter chief...
# 5   combined management report combined management...
# 6   acting tomorrow today responsibility plan sust...
# 7   sustainability report editorial report crop pr...
# 8   sustainability report sustainability report an...
# 9   sustainability progress report progress glance...
# 10  2management reportcombined34 overview group34 ...
# 11  combined management report achieved report deu...
# 12  separate group nonfinancial report strategy ma...
# 13  group management report financial review conso...
# 14  sustainability highlight report care beyond sk...
# 15  sustainability report sustainability report gr...
# 16  group sustainability report building confidenc...
# 17  financial report directive stipulated commerzb...
# 18  sustainability management sustainability strat...
# 19  basf report report management overview nonfina...
# 20  portrait strategy management business complian...
# 21  sustainability supplementing annual report nav...
# 22  sustainy report sustainability report governan...
# 23  focus tomorrow sustainability report energy su...
# 24  overview sustainability prioritising sustainab...
# 25  sustainability report new auto reinvents world...
# 26  standwithukraine sustainability report search ...
# 27  sustainability report maximum image areaminimu...
# 28  sustainability report henkel sustainability re...
# 29  sustainability purpose technology transform ev...
# 30  corporate responsibility inhalt diesis pdfdoku...
# 31  integrated report stakeholder combined group m...
# 32  stedim biotech sa gri report stedim biotech gr...
# 33  combined management report nonfinancial statem...
# 34  sustainability report strategy management yees...
# 35  vonovia se sustainability report sustainable f...
# 36  brenntag se sustainability report brenntag wor...
#
#                                           word_tokens  \
# 0   ['basic', 'information', 'rheinmetall', 'group...
# 1   ['sustainability', 'report', 'creating', 'tran...
# 2   ['gri', 'sustainability', 'record', 'us', 'int...
# 3   ['turn', 'change', 'opportunity', 'embrace', '...
# 4   ['deutsche', 'bank', 'nonfinancial', 'report',...
# 5   ['combined', 'management', 'report', 'combined...
# 6   ['acting', 'tomorrow', 'today', 'responsibilit...
# 7   ['sustainability', 'report', 'editorial', 'rep...
# 8   ['sustainability', 'report', 'sustainability',...
# 9   ['sustainability', 'progress', 'report', 'prog...
# 10  ['2management', 'reportcombined34', 'overview'...
# 11  ['combined', 'management', 'report', 'achieved...
# 12  ['separate', 'group', 'nonfinancial', 'report'...
# 13  ['group', 'management', 'report', 'financial',...
# 14  ['sustainability', 'highlight', 'report', 'car...
# 15  ['sustainability', 'report', 'sustainability',...
# 16  ['group', 'sustainability', 'report', 'buildin...
# 17  ['financial', 'report', 'directive', 'stipulat...
# 18  ['sustainability', 'management', 'sustainabili...
# 19  ['basf', 'report', 'report', 'management', 'ov...
# 20  ['portrait', 'strategy', 'management', 'busine...
# 21  ['sustainability', 'supplementing', 'annual', ...
# 22  ['sustainy', 'report', 'sustainability', 'repo...
# 23  ['focus', 'tomorrow', 'sustainability', 'repor...
# 24  ['overview', 'sustainability', 'prioritising',...
# 25  ['sustainability', 'report', 'new', 'auto', 'r...
# 26  ['standwithukraine', 'sustainability', 'report...
# 27  ['sustainability', 'report', 'maximum', 'image...
# 28  ['sustainability', 'report', 'henkel', 'sustai...
# 29  ['sustainability', 'purpose', 'technology', 't...
# 30  ['corporate', 'responsibility', 'inhalt', 'die...
# 31  ['integrated', 'report', 'stakeholder', 'combi...
# 32  ['stedim', 'biotech', 'sa', 'gri', 'report', '...
# 33  ['combined', 'management', 'report', 'nonfinan...
# 34  ['sustainability', 'report', 'strategy', 'mana...
# 35  ['vonovia', 'se', 'sustainability', 'report', ...
# 36  ['brenntag', 'se', 'sustainability', 'report',...
#
#                                       sentence_tokens  \
# 0   ['basic information rheinmetall groupstructure...
# 1   ['sustainability report creating transparency ...
# 2   ['gri sustainability record uses international...
# 3   ['turn change opportunity embrace sustainabili...
# 4   ['deutsche bank nonfinancial report letter chi...
# 5   ['combined management report combined manageme...
# 6   ['acting tomorrow today responsibility plans s...
# 7   ['sustainability report editorial report crop ...
# 8   ['sustainability report sustainability report ...
# 9   ['sustainability progress report progress glan...
# 10  ['overview organisational business model group...
# 11  ['combined management report achieved report d...
# 12  ['separate group nonfinancial report strategy ...
# 13  ['group management report financial review con...
# 14  ['sustainability highlight report care beyond ...
# 15  ['sustainability report sustainability report ...
# 16  ['group sustainability report building confide...
# 17  ['financial report directives stipulated comme...
# 18  ['sustainability management sustainability str...
# 19  ['basf report report management overview nonfi...
# 20  ['portrait strategy management business compli...
# 21  ['sustainability supplementing annual report n...
# 22  ['', 'sustainy report sustainability report go...
# 23  ['focus tomorrow', 'sustainability report ener...
# 24  ['overview sustainability prioritising sustain...
# 25  ['sustainability report new auto reinvents wor...
# 26  ['standwithukraine sustainability report searc...
# 27  ['sustainability report maximum image areamini...
# 28  ['sustainability report henkel sustainability ...
# 29  ['sustainability purpose technology transform ...
# 30  ['corporate responsibility inhalt dieses pdfdo...
# 31  ['integrated report stakeholders combined grou...
# 32  ['stedim biotech gri report stedim biotech gri...
# 33  ['combined management report nonfinancial stat...
# 34  ['sustainability report strategy management ye...
# 35  ['vonovia se sustainability report sustainable...
# 36  ['brenntag se sustainability report brenntag w...
#
#                                pos_tagged_word_tokens  \
# 0   [('basic', 'JJ'), ('information', 'NN'), ('rhe...
# 1   [('sustainability', 'NN'), ('report', 'NN'), (...
# 2   [('gri', 'JJ'), ('sustainability', 'NN'), ('re...
# 3   [('turn', 'NN'), ('change', 'NN'), ('opportuni...
# 4   [('deutsche', 'NN'), ('bank', 'NN'), ('nonfina...
# 5   [('combined', 'JJ'), ('management', 'NN'), ('r...
# 6   [('acting', 'VBG'), ('tomorrow', 'NN'), ('toda...
# 7   [('sustainability', 'NN'), ('report', 'NN'), (...
# 8   [('sustainability', 'NN'), ('report', 'NN'), (...
# 9   [('sustainability', 'NN'), ('progress', 'NN'),...
# 10  [('2management', 'CD'), ('reportcombined34', '...
# 11  [('combined', 'JJ'), ('management', 'NN'), ('r...
# 12  [('separate', 'JJ'), ('group', 'NN'), ('nonfin...
# 13  [('group', 'NN'), ('management', 'NN'), ('repo...
# 14  [('sustainability', 'NN'), ('highlight', 'VBD'...
# 15  [('sustainability', 'NN'), ('report', 'NN'), (...
# 16  [('group', 'NN'), ('sustainability', 'NN'), ('...
# 17  [('financial', 'JJ'), ('report', 'NN'), ('dire...
# 18  [('sustainability', 'NN'), ('management', 'NN'...
# 19  [('basf', 'JJ'), ('report', 'NN'), ('report', ...
# 20  [('portrait', 'NN'), ('strategy', 'NN'), ('man...
# 21  [('sustainability', 'NN'), ('supplementing', '...
# 22  [('sustainy', 'JJ'), ('report', 'NN'), ('susta...
# 23  [('focus', 'NN'), ('tomorrow', 'NN'), ('sustai...
# 24  [('overview', 'NN'), ('sustainability', 'NN'),...
# 25  [('sustainability', 'NN'), ('report', 'NN'), (...
# 26  [('standwithukraine', 'JJ'), ('sustainability'...
# 27  [('sustainability', 'NN'), ('report', 'NN'), (...
# 28  [('sustainability', 'NN'), ('report', 'NN'), (...
# 29  [('sustainability', 'NN'), ('purpose', 'NN'), ...
# 30  [('corporate', 'JJ'), ('responsibility', 'NN')...
# 31  [('integrated', 'JJ'), ('report', 'NN'), ('sta...
# 32  [('stedim', 'NN'), ('biotech', 'NN'), ('sa', '...
# 33  [('combined', 'JJ'), ('management', 'NN'), ('r...
# 34  [('sustainability', 'NN'), ('report', 'NN'), (...
# 35  [('vonovia', 'NN'), ('se', 'JJ'), ('sustainabi...
# 36  [('brenntag', 'NN'), ('se', 'JJ'), ('sustainab...
#
#                            pos_tagged_sentence_tokens  \
# 0   [[('basic', 'JJ'), ('information', 'NN'), ('rh...
# 1   [[('sustainability', 'NN'), ('report', 'NN'), ...
# 2   [[('gri', 'NN'), ('sustainability', 'JJ'), ('r...
# 3   [[('turn', 'NN'), ('change', 'NN'), ('opportun...
# 4   [[('deutsche', 'NN'), ('bank', 'NN'), ('nonfin...
# 5   [[('combined', 'VBD'), ('management', 'NN'), (...
# 6   [[('acting', 'VBG'), ('tomorrow', 'NN'), ('tod...
# 7   [[('sustainability', 'NN'), ('report', 'NN'), ...
# 8   [[('sustainability', 'NN'), ('report', 'NN'), ...
# 9   [[('sustainability', 'NN'), ('progress', 'NN')...
# 10  [[('overview', 'NN'), ('organisational', 'JJ')...
# 11  [[('combined', 'VBD'), ('management', 'NN'), (...
# 12  [[('separate', 'JJ'), ('group', 'NN'), ('nonfi...
# 13  [[('group', 'NN'), ('management', 'NN'), ('rep...
# 14  [[('sustainability', 'NN'), ('highlight', 'VBD...
# 15  [[('sustainability', 'NN'), ('report', 'NN'), ...
# 16  [[('group', 'NN'), ('sustainability', 'NN'), (...
# 17  [[('financial', 'JJ'), ('report', 'NN'), ('sti...
# 18  [[('sustainability', 'NN'), ('management', 'NN...
# 19  [[('basf', 'VBD'), ('report', 'NN'), ('report'...
# 20  [[('portrait', 'NN'), ('strategy', 'NN'), ('ma...
# 21  [[('sustainability', 'NN'), ('supplementing', ...
# 22  [[], [('sustainy', 'JJ'), ('report', 'NN'), ('...
# 23  [[('focus', 'NN'), ('tomorrow', 'NN')], [('sus...
# 24  [[('overview', 'JJ'), ('sustainability', 'NN')...
# 25  [[('sustainability', 'NN'), ('report', 'VBP'),...
# 26  [[('standwithukraine', 'JJ'), ('sustainability...
# 27  [[('sustainability', 'NN'), ('report', 'NN'), ...
# 28  [[('sustainability', 'NN'), ('report', 'NN'), ...
# 29  [[('sustainability', 'NN'), ('purpose', 'JJ'),...
# 30  [[('corporate', 'JJ'), ('responsibility', 'NN'...
# 31  [[('integrated', 'VBN'), ('report', 'NN'), ('c...
# 32  [[('stedim', 'NN'), ('biotech', 'NN'), ('gri',...
# 33  [[('combined', 'VBN'), ('management', 'NN'), (...
# 34  [[('sustainability', 'NN'), ('report', 'NN'), ...
# 35  [[('vonovia', 'NN'), ('se', 'JJ'), ('sustainab...
# 36  [[('brenntag', 'NN'), ('se', 'NN'), ('sustaina...
#
#                                          company_name symbol  \
# 0                                      Rheinmetall AG    RHM
# 1                                   Siemens Energy AG    ENR
# 2                                          Symrise AG    SY1
# 3                                      Continental AG    CON
# 4                                    Deutsche Bank AG    DBK
# 5                                         Covestro AG   1COV
# 6                                 MTU Aero Engines AG    MTX
# 7                                            Bayer AG   BAYN
# 8   Münchener Rückversicherungs-Gesellschaft Aktie...   MUV2
# 9                                          Zalando SE    ZAL
# 10                        Bayerische Motoren Werke AG    BMW
# 11                                  Deutsche Börse AG    DB1
# 12                             Fresenius SE & Co KGaA    FRE
# 13                                          adidas AG    ADS
# 14                                      Beiersdorf AG    BEI
# 15                                   Hannover Rück SE   HNRB
# 16                                         Allianz SE    ALV
# 17                                     Commerzbank AG    CBK
# 18                       Porsche Automobil Holding SE   PAH3
# 19                                            BASF SE    BAS
# 20                            Heidelberg Materials AG    HEI
# 21                           Infineon Technologies AG    IFX
# 22                                        Qiagen N.V.    QIA
# 23                                             RWE AG    RWE
# 24                                          Airbus SE    AIR
# 25                                      Volkswagen AG    VOW
# 26                                            E.ON SE   EOAN
# 27                             Mercedes-Benz Group AG    DAI
# 28                                Henkel AG & Co KGaA    HEN
# 29                                         Siemens AG    SIE
# 30                                Deutsche Telekom AG    DTE
# 31                                             SAP SE    SAP
# 32                                       Sartorius AG    SRT
# 33                                   Deutsche Post AG    DHL
# 34             MERCK Kommanditgesellschaft auf Aktien    MRK
# 35                                         Vonovia SE    VNA
# 36                                        Brenntag AG    BNR
#
#     market_cap_in_usd_b      country                  sector  \
# 0                 11.96      Germany             Industrials
# 1                 13.82      Germany               Utilities
# 2                 14.81      Germany         Basic Materials
# 3                 15.16      Germany  Consumer Discretionary
# 4                 21.13      Germany              Financials
# 5                  9.87      Germany         Basic Materials
# 6                 13.21      Germany             Industrials
# 7                 53.38      Germany              Healthcare
# 8                 49.87      Germany              Financials
# 9                  6.92      Germany  Consumer Discretionary
# 10                77.25      Germany  Consumer Discretionary
# 11                32.32      Germany              Financials
# 12                15.90      Germany              Healthcare
# 13                33.41      Germany  Consumer Discretionary
# 14                28.61      Germany        Consumer Staples
# 15                24.66      Germany              Financials
# 16                91.36      Germany              Financials
# 17                14.96      Germany              Financials
# 18                17.87      Germany  Consumer Discretionary
# 19                44.37      Germany         Basic Materials
# 20                14.65      Germany         Basic Materials
# 21                50.42      Germany              Technology
# 22                10.49  Netherlands              Healthcare
# 23                32.35      Germany               Utilities
# 24               113.90  Netherlands             Industrials
# 25                77.55      Germany  Consumer Discretionary
# 26                32.95      Germany               Utilities
# 27                84.94      Germany  Consumer Discretionary
# 28                30.65      Germany        Consumer Staples
# 29               131.00      Germany             Industrials
# 30               106.00      Germany  Communication Services
# 31               161.41      Germany              Technology
# 32                21.43      Germany              Healthcare
# 33                57.95      Germany             Industrials
# 34                70.69      Germany              Healthcare
# 35                15.69      Germany             Real Estate
# 36                11.76      Germany         Basic Materials
#
#                                   industry  st1_sentiment_continuous
# 0                  Industrial Distribution                  0.019156
# 1    Utilities—Independent Power Producers                  0.018045
# 2                      Specialty Chemicals                  0.018819
# 3                               Auto Parts                  0.017767
# 4                           Banks—Regional                  0.017723
# 5                      Specialty Chemicals                  0.018556
# 6                      Aerospace & Defense                  0.018378
# 7               Drug Manufacturers—General                  0.018680
# 8                    Insurance—Reinsurance                  0.018395
# 9                          Internet Retail                  0.015273
# 10                      Auto Manufacturers                  0.017979
# 11        Financial Data & Stock Exchanges                  0.015751
# 12                 Medical Care Facilities                  0.018011
# 13                  Footwear & Accessories                  0.018259
# 14           Household & Personal Products                  0.019817
# 15                   Insurance—Reinsurance                  0.018542
# 16                   Insurance—Diversified                  0.018116
# 17                          Banks—Regional                  0.017837
# 18                      Auto Manufacturers                  0.018476
# 19                               Chemicals                  0.018786
# 20                      Building Materials                  0.018709
# 21                          Semiconductors                  0.018381
# 22                  Diagnostics & Research                  0.019487
# 23                   Utilities—Diversified                  0.013654
# 24                     Aerospace & Defense                  0.017821
# 25                      Auto Manufacturers                  0.017304
# 26                   Utilities—Diversified                  0.017514
# 27                      Auto Manufacturers                  0.018746
# 28           Household & Personal Products                  0.018979
# 29          Specialty Industrial Machinery                  0.019526
# 30                        Telecom Services                  0.014531
# 31                    Software—Application                  0.018051
# 32          Medical Instruments & Supplies                  0.017118
# 33          Integrated Freight & Logistics                  0.018219
# 34  Drug Manufacturers—Specialty & Generic                  0.018736
# 35                    Real Estate Services                  0.017565
# 36                     Specialty Chemicals                  0.018195

# %%
del enriched_cleaned_data_new['content']

# %%
enriched_cleaned_data_new.head(37)
# Out:
#                 company               datatype  date  internal title  \
# 0           Rheinmetall  Sustainability Report  2021         1   the
# 1         SiemensEnergy  Sustainability Report  2021         1     ,
# 2               Symrise  Sustainability Report  2021         1   the
# 3           Continental  Sustainability Report  2021         1   the
# 4          DeutscheBank  Sustainability Report  2021         1   and
# 5              Covestro  Sustainability Report  2021         1   the
# 6                   MTU  Sustainability Report  2021         1   the
# 7                 Bayer  Sustainability Report  2021         1   the
# 8       MuenchenerRueck  Sustainability Report  2021         1     .
# 9               Zalando  Sustainability Report  2021         1     ,
# 10                  BMW  Sustainability Report  2021         1   the
# 11       DeutscheBoerse  Sustainability Report  2021         1   the
# 12            Fresenius  Sustainability Report  2021         1   the
# 13               Adidas  Sustainability Report  2021         1     ,
# 14           Beiersdorf  Sustainability Report  2021         1   our
# 15        HannoverRueck  Sustainability Report  2021         1   the
# 16              Allianz  Sustainability Report  2021         1   and
# 17          Commerzbank  Sustainability Report  2021         1   the
# 18              Porsche  Sustainability Report  2021         1   the
# 19                 BASF  Sustainability Report  2021         1   the
# 20  HeidelbergMaterials  Sustainability Report  2021         1   the
# 21             Infineon  Sustainability Report  2021         1   the
# 22               Qiagen  Sustainability Report  2021         1   and
# 23                  RWE  Sustainability Report  2021         1   the
# 24               Airbus  Sustainability Report  2021         1   the
# 25           Volkswagen  Sustainability Report  2021         1   the
# 26                  EON  Sustainability Report  2021         1     ,
# 27         MercedesBenz  Sustainability Report  2021         1   the
# 28               Henkel  Sustainability Report  2021         1   the
# 29              Siemens  Sustainability Report  2021         1   the
# 30              Telekom  Sustainability Report  2021         1     .
# 31                  SAP  Sustainability Report  2021         1     ,
# 32            Sartorius  Sustainability Report  2021         1   the
# 33                  DHL  Sustainability Report  2021         1   the
# 34                Merck  Sustainability Report  2021         1     ,
# 35              Vonovia  Sustainability Report  2021         1   the
# 36             Brenntag  Sustainability Report  2021         1   the
#
#                                       cleaned_content  \
# 0   basic information rheinmetall groupstructure r...
# 1   sustainability report creating transparency si...
# 2   gri sustainability record us international sta...
# 3   turn change opportunity embrace sustainability...
# 4   deutsche bank nonfinancial report letter chief...
# 5   combined management report combined management...
# 6   acting tomorrow today responsibility plan sust...
# 7   sustainability report editorial report crop pr...
# 8   sustainability report sustainability report an...
# 9   sustainability progress report progress glance...
# 10  2management reportcombined34 overview group34 ...
# 11  combined management report achieved report deu...
# 12  separate group nonfinancial report strategy ma...
# 13  group management report financial review conso...
# 14  sustainability highlight report care beyond sk...
# 15  sustainability report sustainability report gr...
# 16  group sustainability report building confidenc...
# 17  financial report directive stipulated commerzb...
# 18  sustainability management sustainability strat...
# 19  basf report report management overview nonfina...
# 20  portrait strategy management business complian...
# 21  sustainability supplementing annual report nav...
# 22  sustainy report sustainability report governan...
# 23  focus tomorrow sustainability report energy su...
# 24  overview sustainability prioritising sustainab...
# 25  sustainability report new auto reinvents world...
# 26  standwithukraine sustainability report search ...
# 27  sustainability report maximum image areaminimu...
# 28  sustainability report henkel sustainability re...
# 29  sustainability purpose technology transform ev...
# 30  corporate responsibility inhalt diesis pdfdoku...
# 31  integrated report stakeholder combined group m...
# 32  stedim biotech sa gri report stedim biotech gr...
# 33  combined management report nonfinancial statem...
# 34  sustainability report strategy management yees...
# 35  vonovia se sustainability report sustainable f...
# 36  brenntag se sustainability report brenntag wor...
#
#                                           word_tokens  \
# 0   ['basic', 'information', 'rheinmetall', 'group...
# 1   ['sustainability', 'report', 'creating', 'tran...
# 2   ['gri', 'sustainability', 'record', 'us', 'int...
# 3   ['turn', 'change', 'opportunity', 'embrace', '...
# 4   ['deutsche', 'bank', 'nonfinancial', 'report',...
# 5   ['combined', 'management', 'report', 'combined...
# 6   ['acting', 'tomorrow', 'today', 'responsibilit...
# 7   ['sustainability', 'report', 'editorial', 'rep...
# 8   ['sustainability', 'report', 'sustainability',...
# 9   ['sustainability', 'progress', 'report', 'prog...
# 10  ['2management', 'reportcombined34', 'overview'...
# 11  ['combined', 'management', 'report', 'achieved...
# 12  ['separate', 'group', 'nonfinancial', 'report'...
# 13  ['group', 'management', 'report', 'financial',...
# 14  ['sustainability', 'highlight', 'report', 'car...
# 15  ['sustainability', 'report', 'sustainability',...
# 16  ['group', 'sustainability', 'report', 'buildin...
# 17  ['financial', 'report', 'directive', 'stipulat...
# 18  ['sustainability', 'management', 'sustainabili...
# 19  ['basf', 'report', 'report', 'management', 'ov...
# 20  ['portrait', 'strategy', 'management', 'busine...
# 21  ['sustainability', 'supplementing', 'annual', ...
# 22  ['sustainy', 'report', 'sustainability', 'repo...
# 23  ['focus', 'tomorrow', 'sustainability', 'repor...
# 24  ['overview', 'sustainability', 'prioritising',...
# 25  ['sustainability', 'report', 'new', 'auto', 'r...
# 26  ['standwithukraine', 'sustainability', 'report...
# 27  ['sustainability', 'report', 'maximum', 'image...
# 28  ['sustainability', 'report', 'henkel', 'sustai...
# 29  ['sustainability', 'purpose', 'technology', 't...
# 30  ['corporate', 'responsibility', 'inhalt', 'die...
# 31  ['integrated', 'report', 'stakeholder', 'combi...
# 32  ['stedim', 'biotech', 'sa', 'gri', 'report', '...
# 33  ['combined', 'management', 'report', 'nonfinan...
# 34  ['sustainability', 'report', 'strategy', 'mana...
# 35  ['vonovia', 'se', 'sustainability', 'report', ...
# 36  ['brenntag', 'se', 'sustainability', 'report',...
#
#                                       sentence_tokens  \
# 0   ['basic information rheinmetall groupstructure...
# 1   ['sustainability report creating transparency ...
# 2   ['gri sustainability record uses international...
# 3   ['turn change opportunity embrace sustainabili...
# 4   ['deutsche bank nonfinancial report letter chi...
# 5   ['combined management report combined manageme...
# 6   ['acting tomorrow today responsibility plans s...
# 7   ['sustainability report editorial report crop ...
# 8   ['sustainability report sustainability report ...
# 9   ['sustainability progress report progress glan...
# 10  ['overview organisational business model group...
# 11  ['combined management report achieved report d...
# 12  ['separate group nonfinancial report strategy ...
# 13  ['group management report financial review con...
# 14  ['sustainability highlight report care beyond ...
# 15  ['sustainability report sustainability report ...
# 16  ['group sustainability report building confide...
# 17  ['financial report directives stipulated comme...
# 18  ['sustainability management sustainability str...
# 19  ['basf report report management overview nonfi...
# 20  ['portrait strategy management business compli...
# 21  ['sustainability supplementing annual report n...
# 22  ['', 'sustainy report sustainability report go...
# 23  ['focus tomorrow', 'sustainability report ener...
# 24  ['overview sustainability prioritising sustain...
# 25  ['sustainability report new auto reinvents wor...
# 26  ['standwithukraine sustainability report searc...
# 27  ['sustainability report maximum image areamini...
# 28  ['sustainability report henkel sustainability ...
# 29  ['sustainability purpose technology transform ...
# 30  ['corporate responsibility inhalt dieses pdfdo...
# 31  ['integrated report stakeholders combined grou...
# 32  ['stedim biotech gri report stedim biotech gri...
# 33  ['combined management report nonfinancial stat...
# 34  ['sustainability report strategy management ye...
# 35  ['vonovia se sustainability report sustainable...
# 36  ['brenntag se sustainability report brenntag w...
#
#                                pos_tagged_word_tokens  \
# 0   [('basic', 'JJ'), ('information', 'NN'), ('rhe...
# 1   [('sustainability', 'NN'), ('report', 'NN'), (...
# 2   [('gri', 'JJ'), ('sustainability', 'NN'), ('re...
# 3   [('turn', 'NN'), ('change', 'NN'), ('opportuni...
# 4   [('deutsche', 'NN'), ('bank', 'NN'), ('nonfina...
# 5   [('combined', 'JJ'), ('management', 'NN'), ('r...
# 6   [('acting', 'VBG'), ('tomorrow', 'NN'), ('toda...
# 7   [('sustainability', 'NN'), ('report', 'NN'), (...
# 8   [('sustainability', 'NN'), ('report', 'NN'), (...
# 9   [('sustainability', 'NN'), ('progress', 'NN'),...
# 10  [('2management', 'CD'), ('reportcombined34', '...
# 11  [('combined', 'JJ'), ('management', 'NN'), ('r...
# 12  [('separate', 'JJ'), ('group', 'NN'), ('nonfin...
# 13  [('group', 'NN'), ('management', 'NN'), ('repo...
# 14  [('sustainability', 'NN'), ('highlight', 'VBD'...
# 15  [('sustainability', 'NN'), ('report', 'NN'), (...
# 16  [('group', 'NN'), ('sustainability', 'NN'), ('...
# 17  [('financial', 'JJ'), ('report', 'NN'), ('dire...
# 18  [('sustainability', 'NN'), ('management', 'NN'...
# 19  [('basf', 'JJ'), ('report', 'NN'), ('report', ...
# 20  [('portrait', 'NN'), ('strategy', 'NN'), ('man...
# 21  [('sustainability', 'NN'), ('supplementing', '...
# 22  [('sustainy', 'JJ'), ('report', 'NN'), ('susta...
# 23  [('focus', 'NN'), ('tomorrow', 'NN'), ('sustai...
# 24  [('overview', 'NN'), ('sustainability', 'NN'),...
# 25  [('sustainability', 'NN'), ('report', 'NN'), (...
# 26  [('standwithukraine', 'JJ'), ('sustainability'...
# 27  [('sustainability', 'NN'), ('report', 'NN'), (...
# 28  [('sustainability', 'NN'), ('report', 'NN'), (...
# 29  [('sustainability', 'NN'), ('purpose', 'NN'), ...
# 30  [('corporate', 'JJ'), ('responsibility', 'NN')...
# 31  [('integrated', 'JJ'), ('report', 'NN'), ('sta...
# 32  [('stedim', 'NN'), ('biotech', 'NN'), ('sa', '...
# 33  [('combined', 'JJ'), ('management', 'NN'), ('r...
# 34  [('sustainability', 'NN'), ('report', 'NN'), (...
# 35  [('vonovia', 'NN'), ('se', 'JJ'), ('sustainabi...
# 36  [('brenntag', 'NN'), ('se', 'JJ'), ('sustainab...
#
#                            pos_tagged_sentence_tokens  \
# 0   [[('basic', 'JJ'), ('information', 'NN'), ('rh...
# 1   [[('sustainability', 'NN'), ('report', 'NN'), ...
# 2   [[('gri', 'NN'), ('sustainability', 'JJ'), ('r...
# 3   [[('turn', 'NN'), ('change', 'NN'), ('opportun...
# 4   [[('deutsche', 'NN'), ('bank', 'NN'), ('nonfin...
# 5   [[('combined', 'VBD'), ('management', 'NN'), (...
# 6   [[('acting', 'VBG'), ('tomorrow', 'NN'), ('tod...
# 7   [[('sustainability', 'NN'), ('report', 'NN'), ...
# 8   [[('sustainability', 'NN'), ('report', 'NN'), ...
# 9   [[('sustainability', 'NN'), ('progress', 'NN')...
# 10  [[('overview', 'NN'), ('organisational', 'JJ')...
# 11  [[('combined', 'VBD'), ('management', 'NN'), (...
# 12  [[('separate', 'JJ'), ('group', 'NN'), ('nonfi...
# 13  [[('group', 'NN'), ('management', 'NN'), ('rep...
# 14  [[('sustainability', 'NN'), ('highlight', 'VBD...
# 15  [[('sustainability', 'NN'), ('report', 'NN'), ...
# 16  [[('group', 'NN'), ('sustainability', 'NN'), (...
# 17  [[('financial', 'JJ'), ('report', 'NN'), ('sti...
# 18  [[('sustainability', 'NN'), ('management', 'NN...
# 19  [[('basf', 'VBD'), ('report', 'NN'), ('report'...
# 20  [[('portrait', 'NN'), ('strategy', 'NN'), ('ma...
# 21  [[('sustainability', 'NN'), ('supplementing', ...
# 22  [[], [('sustainy', 'JJ'), ('report', 'NN'), ('...
# 23  [[('focus', 'NN'), ('tomorrow', 'NN')], [('sus...
# 24  [[('overview', 'JJ'), ('sustainability', 'NN')...
# 25  [[('sustainability', 'NN'), ('report', 'VBP'),...
# 26  [[('standwithukraine', 'JJ'), ('sustainability...
# 27  [[('sustainability', 'NN'), ('report', 'NN'), ...
# 28  [[('sustainability', 'NN'), ('report', 'NN'), ...
# 29  [[('sustainability', 'NN'), ('purpose', 'JJ'),...
# 30  [[('corporate', 'JJ'), ('responsibility', 'NN'...
# 31  [[('integrated', 'VBN'), ('report', 'NN'), ('c...
# 32  [[('stedim', 'NN'), ('biotech', 'NN'), ('gri',...
# 33  [[('combined', 'VBN'), ('management', 'NN'), (...
# 34  [[('sustainability', 'NN'), ('report', 'NN'), ...
# 35  [[('vonovia', 'NN'), ('se', 'JJ'), ('sustainab...
# 36  [[('brenntag', 'NN'), ('se', 'NN'), ('sustaina...
#
#                                          company_name symbol  \
# 0                                      Rheinmetall AG    RHM
# 1                                   Siemens Energy AG    ENR
# 2                                          Symrise AG    SY1
# 3                                      Continental AG    CON
# 4                                    Deutsche Bank AG    DBK
# 5                                         Covestro AG   1COV
# 6                                 MTU Aero Engines AG    MTX
# 7                                            Bayer AG   BAYN
# 8   Münchener Rückversicherungs-Gesellschaft Aktie...   MUV2
# 9                                          Zalando SE    ZAL
# 10                        Bayerische Motoren Werke AG    BMW
# 11                                  Deutsche Börse AG    DB1
# 12                             Fresenius SE & Co KGaA    FRE
# 13                                          adidas AG    ADS
# 14                                      Beiersdorf AG    BEI
# 15                                   Hannover Rück SE   HNRB
# 16                                         Allianz SE    ALV
# 17                                     Commerzbank AG    CBK
# 18                       Porsche Automobil Holding SE   PAH3
# 19                                            BASF SE    BAS
# 20                            Heidelberg Materials AG    HEI
# 21                           Infineon Technologies AG    IFX
# 22                                        Qiagen N.V.    QIA
# 23                                             RWE AG    RWE
# 24                                          Airbus SE    AIR
# 25                                      Volkswagen AG    VOW
# 26                                            E.ON SE   EOAN
# 27                             Mercedes-Benz Group AG    DAI
# 28                                Henkel AG & Co KGaA    HEN
# 29                                         Siemens AG    SIE
# 30                                Deutsche Telekom AG    DTE
# 31                                             SAP SE    SAP
# 32                                       Sartorius AG    SRT
# 33                                   Deutsche Post AG    DHL
# 34             MERCK Kommanditgesellschaft auf Aktien    MRK
# 35                                         Vonovia SE    VNA
# 36                                        Brenntag AG    BNR
#
#     market_cap_in_usd_b      country                  sector  \
# 0                 11.96      Germany             Industrials
# 1                 13.82      Germany               Utilities
# 2                 14.81      Germany         Basic Materials
# 3                 15.16      Germany  Consumer Discretionary
# 4                 21.13      Germany              Financials
# 5                  9.87      Germany         Basic Materials
# 6                 13.21      Germany             Industrials
# 7                 53.38      Germany              Healthcare
# 8                 49.87      Germany              Financials
# 9                  6.92      Germany  Consumer Discretionary
# 10                77.25      Germany  Consumer Discretionary
# 11                32.32      Germany              Financials
# 12                15.90      Germany              Healthcare
# 13                33.41      Germany  Consumer Discretionary
# 14                28.61      Germany        Consumer Staples
# 15                24.66      Germany              Financials
# 16                91.36      Germany              Financials
# 17                14.96      Germany              Financials
# 18                17.87      Germany  Consumer Discretionary
# 19                44.37      Germany         Basic Materials
# 20                14.65      Germany         Basic Materials
# 21                50.42      Germany              Technology
# 22                10.49  Netherlands              Healthcare
# 23                32.35      Germany               Utilities
# 24               113.90  Netherlands             Industrials
# 25                77.55      Germany  Consumer Discretionary
# 26                32.95      Germany               Utilities
# 27                84.94      Germany  Consumer Discretionary
# 28                30.65      Germany        Consumer Staples
# 29               131.00      Germany             Industrials
# 30               106.00      Germany  Communication Services
# 31               161.41      Germany              Technology
# 32                21.43      Germany              Healthcare
# 33                57.95      Germany             Industrials
# 34                70.69      Germany              Healthcare
# 35                15.69      Germany             Real Estate
# 36                11.76      Germany         Basic Materials
#
#                                   industry  st1_sentiment_continuous
# 0                  Industrial Distribution                  0.019156
# 1    Utilities—Independent Power Producers                  0.018045
# 2                      Specialty Chemicals                  0.018819
# 3                               Auto Parts                  0.017767
# 4                           Banks—Regional                  0.017723
# 5                      Specialty Chemicals                  0.018556
# 6                      Aerospace & Defense                  0.018378
# 7               Drug Manufacturers—General                  0.018680
# 8                    Insurance—Reinsurance                  0.018395
# 9                          Internet Retail                  0.015273
# 10                      Auto Manufacturers                  0.017979
# 11        Financial Data & Stock Exchanges                  0.015751
# 12                 Medical Care Facilities                  0.018011
# 13                  Footwear & Accessories                  0.018259
# 14           Household & Personal Products                  0.019817
# 15                   Insurance—Reinsurance                  0.018542
# 16                   Insurance—Diversified                  0.018116
# 17                          Banks—Regional                  0.017837
# 18                      Auto Manufacturers                  0.018476
# 19                               Chemicals                  0.018786
# 20                      Building Materials                  0.018709
# 21                          Semiconductors                  0.018381
# 22                  Diagnostics & Research                  0.019487
# 23                   Utilities—Diversified                  0.013654
# 24                     Aerospace & Defense                  0.017821
# 25                      Auto Manufacturers                  0.017304
# 26                   Utilities—Diversified                  0.017514
# 27                      Auto Manufacturers                  0.018746
# 28           Household & Personal Products                  0.018979
# 29          Specialty Industrial Machinery                  0.019526
# 30                        Telecom Services                  0.014531
# 31                    Software—Application                  0.018051
# 32          Medical Instruments & Supplies                  0.017118
# 33          Integrated Freight & Logistics                  0.018219
# 34  Drug Manufacturers—Specialty & Generic                  0.018736
# 35                    Real Estate Services                  0.017565
# 36                     Specialty Chemicals                  0.018195

# %%
enriched_cleaned_data_new.shape
# Out:
# (37, 17)

# %%
enriched_cleaned_data_new.to_csv('../data/checkpoints/enriched_cleaned_data_new_2021.csv', index=False)

# %%
import matplotlib.pyplot as plt

# Sort the data by market cap in descending order
enriched_cleaned_data_new = enriched_cleaned_data_new.sort_values(by='market_cap_in_usd_b', ascending=False)

# Create a horizontal stacked bar chart
enriched_cleaned_data_new.plot(x='company', y=['market_cap_in_usd_b'], kind='barh', stacked=True, legend=False, figsize=(10, 8))

# Set the title and axis labels
plt.title('Market Cap by Company')
plt.xlabel('Market Cap (in billions)')
plt.ylabel('Company')

# Show the plot
plt.show()

# %% [markdown]
# ### Stage 1: Data Analysis
#
# # Setup & Data Loading

# %%
# %pip install seaborn
# %pip install scipy
# %pip install scikit-learn
# %pip install gensim
# Out:
# Requirement already satisfied: seaborn in /Users/seyyiduzun/opt/miniconda3/envs/bachelor/lib/python3.12/site-packages (0.13.0)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in /Users/seyyiduzun/opt/miniconda3/envs/bachelor/lib/python3.12/site-packages (from seaborn) (1.26.1)
# Requirement already satisfied: pandas>=1.2 in /Users/seyyiduzun/opt/miniconda3/envs/bachelor/lib/python3.12/site-packages (from seaborn) (2.1.2)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.3 in /Users/seyyiduzun/opt/miniconda3/envs/bachelor/lib/python3.12/site-packages (from seaborn) (3.8.1)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/seyyiduzun/opt/miniconda3/envs/bachelor/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in /Users/seyyiduzun/opt/miniconda3/envs/bachelor/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/seyyiduzun/opt/miniconda3/envs/bachelor/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (4.44.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/seyyiduzun/opt/miniconda3/envs/bachelor/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /Users/seyyiduzun/opt/miniconda3/envs/bachelor/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (23.2)
# Requirement already satisfied: pillow>=8 in /Users/seyyiduzun/opt/miniconda3/envs/bachelor/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (10.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/seyyiduzun/opt/miniconda3/envs/bachelor/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/seyyiduzun/opt/miniconda3/envs/bachelor/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/seyyiduzun/opt/miniconda3/envs/bachelor/lib/python3.12/site-packages (from pandas>=1.2->seaborn) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /Users/seyyiduzun/opt/miniconda3/envs/bachelor/lib/python3.12/site-packages (from pandas>=1.2->seaborn) (2023.3)
# Requirement already satisfied: six>=1.5 in /Users/seyyiduzun/opt/miniconda3/envs/bachelor/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.3->seaborn) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: scipy in /Users/seyyiduzun/opt/miniconda3/envs/bachelor/lib/python3.12/site-packages (1.11.3)
# Requirement already satisfied: numpy<1.28.0,>=1.21.6 in /Users/seyyiduzun/opt/miniconda3/envs/bachelor/lib/python3.12/site-packages (from scipy) (1.26.1)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: scikit-learn in /Users/seyyiduzun/opt/miniconda3/envs/bachelor/lib/python3.12/site-packages (1.3.2)
# Requirement already satisfied: numpy<2.0,>=1.17.3 in /Users/seyyiduzun/opt/miniconda3/envs/bachelor/lib/python3.12/site-packages (from scikit-learn) (1.26.1)
# Requirement already satisfied: scipy>=1.5.0 in /Users/seyyiduzun/opt/miniconda3/envs/bachelor/lib/python3.12/site-packages (from scikit-learn) (1.11.3)
# Requirement already satisfied: joblib>=1.1.1 in /Users/seyyiduzun/opt/miniconda3/envs/bachelor/lib/python3.12/site-packages (from scikit-learn) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/seyyiduzun/opt/miniconda3/envs/bachelor/lib/python3.12/site-packages (from scikit-learn) (3.2.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: gensim in /Users/seyyiduzun/opt/miniconda3/envs/bachelor/lib/python3.12/site-packages (4.3.2)
# Requirement already satisfied: numpy>=1.18.5 in /Users/seyyiduzun/opt/miniconda3/envs/bachelor/lib/python3.12/site-packages (from gensim) (1.26.1)
# Requirement already satisfied: scipy>=1.7.0 in /Users/seyyiduzun/opt/miniconda3/envs/bachelor/lib/python3.12/site-packages (from gensim) (1.11.3)
# Requirement already satisfied: smart-open>=1.8.1 in /Users/seyyiduzun/opt/miniconda3/envs/bachelor/lib/python3.12/site-packages (from gensim) (6.4.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Import needed packages
import ast
import pandas as pd
import numpy as np
import seaborn as sns
import scipy.stats as stats
import matplotlib.pyplot as plt
from sklearn.manifold import TSNE
from gensim.models import Word2Vec
from collections import Counter
from sklearn.feature_extraction.text import TfidfVectorizer
from scipy.stats import skew, kurtosis

# %%
file_path = '../data/checkpoints/enriched_cleaned_data_new_2021.csv'

with open(file_path, 'r') as f:
    for i, line in enumerate(f, start=1):
        fields = line.split('|')
        if len(fields) != 1:  # Adjust this condition based on the expected number of fields
            print(f'Error in line {i}: {line}')

# %%
# Load a few rows from the CSV file
df_check = pd.read_csv('../data/checkpoints/enriched_cleaned_data_new_2021.csv', delimiter=',', nrows=5)

# Print the loaded data
print(df_check)
# Out:
#          company               datatype  date  internal title  \
# 0    Rheinmetall  Sustainability Report  2021         1   the
# 1  SiemensEnergy  Sustainability Report  2021         1     ,
# 2        Symrise  Sustainability Report  2021         1   the
# 3    Continental  Sustainability Report  2021         1   the
# 4   DeutscheBank  Sustainability Report  2021         1   and
#
#                                      cleaned_content  \
# 0  basic information rheinmetall groupstructure r...
# 1  sustainability report creating transparency si...
# 2  gri sustainability record us international sta...
# 3  turn change opportunity embrace sustainability...
# 4  deutsche bank nonfinancial report letter chief...
#
#                                          word_tokens  \
# 0  ['basic', 'information', 'rheinmetall', 'group...
# 1  ['sustainability', 'report', 'creating', 'tran...
# 2  ['gri', 'sustainability', 'record', 'us', 'int...
# 3  ['turn', 'change', 'opportunity', 'embrace', '...
# 4  ['deutsche', 'bank', 'nonfinancial', 'report',...
#
#                                      sentence_tokens  \
# 0  ['basic information rheinmetall groupstructure...
# 1  ['sustainability report creating transparency ...
# 2  ['gri sustainability record uses international...
# 3  ['turn change opportunity embrace sustainabili...
# 4  ['deutsche bank nonfinancial report letter chi...
#
#                               pos_tagged_word_tokens  \
# 0  [('basic', 'JJ'), ('information', 'NN'), ('rhe...
# 1  [('sustainability', 'NN'), ('report', 'NN'), (...
# 2  [('gri', 'JJ'), ('sustainability', 'NN'), ('re...
# 3  [('turn', 'NN'), ('change', 'NN'), ('opportuni...
# 4  [('deutsche', 'NN'), ('bank', 'NN'), ('nonfina...
#
#                           pos_tagged_sentence_tokens       company_name  \
# 0  [[('basic', 'JJ'), ('information', 'NN'), ('rh...     Rheinmetall AG
# 1  [[('sustainability', 'NN'), ('report', 'NN'), ...  Siemens Energy AG
# 2  [[('gri', 'NN'), ('sustainability', 'JJ'), ('r...         Symrise AG
# 3  [[('turn', 'NN'), ('change', 'NN'), ('opportun...     Continental AG
# 4  [[('deutsche', 'NN'), ('bank', 'NN'), ('nonfin...   Deutsche Bank AG
#
#   symbol  market_cap_in_usd_b  country                  sector  \
# 0    RHM                11.96  Germany             Industrials
# 1    ENR                13.82  Germany               Utilities
# 2    SY1                14.81  Germany         Basic Materials
# 3    CON                15.16  Germany  Consumer Discretionary
# 4    DBK                21.13  Germany              Financials
#
#                                 industry  st1_sentiment_continuous
# 0                Industrial Distribution                  0.019156
# 1  Utilities—Independent Power Producers                  0.018045
# 2                    Specialty Chemicals                  0.018819
# 3                             Auto Parts                  0.017767
# 4                         Banks—Regional                  0.017723

# %%
# Load the data
cleaned_data_last = pd.read_csv('../data/checkpoints/enriched_cleaned_data_new_2021.csv', delimiter=',')

# %%
# Set the theme and figisze for a unique plot appearence
sns.set_theme(style='whitegrid')
plt.rcParams['figure.figsize'] = (10, 6)

# %%
# Print the first 37 rows of the loaded data
print(cleaned_data_last.head(37))
# Out:
#                 company               datatype  date  internal title  \
# 0           Rheinmetall  Sustainability Report  2021         1   the
# 1         SiemensEnergy  Sustainability Report  2021         1     ,
# 2               Symrise  Sustainability Report  2021         1   the
# 3           Continental  Sustainability Report  2021         1   the
# 4          DeutscheBank  Sustainability Report  2021         1   and
# 5              Covestro  Sustainability Report  2021         1   the
# 6                   MTU  Sustainability Report  2021         1   the
# 7                 Bayer  Sustainability Report  2021         1   the
# 8       MuenchenerRueck  Sustainability Report  2021         1     .
# 9               Zalando  Sustainability Report  2021         1     ,
# 10                  BMW  Sustainability Report  2021         1   the
# 11       DeutscheBoerse  Sustainability Report  2021         1   the
# 12            Fresenius  Sustainability Report  2021         1   the
# 13               Adidas  Sustainability Report  2021         1     ,
# 14           Beiersdorf  Sustainability Report  2021         1   our
# 15        HannoverRueck  Sustainability Report  2021         1   the
# 16              Allianz  Sustainability Report  2021         1   and
# 17          Commerzbank  Sustainability Report  2021         1   the
# 18              Porsche  Sustainability Report  2021         1   the
# 19                 BASF  Sustainability Report  2021         1   the
# 20  HeidelbergMaterials  Sustainability Report  2021         1   the
# 21             Infineon  Sustainability Report  2021         1   the
# 22               Qiagen  Sustainability Report  2021         1   and
# 23                  RWE  Sustainability Report  2021         1   the
# 24               Airbus  Sustainability Report  2021         1   the
# 25           Volkswagen  Sustainability Report  2021         1   the
# 26                  EON  Sustainability Report  2021         1     ,
# 27         MercedesBenz  Sustainability Report  2021         1   the
# 28               Henkel  Sustainability Report  2021         1   the
# 29              Siemens  Sustainability Report  2021         1   the
# 30              Telekom  Sustainability Report  2021         1     .
# 31                  SAP  Sustainability Report  2021         1     ,
# 32            Sartorius  Sustainability Report  2021         1   the
# 33                  DHL  Sustainability Report  2021         1   the
# 34                Merck  Sustainability Report  2021         1     ,
# 35              Vonovia  Sustainability Report  2021         1   the
# 36             Brenntag  Sustainability Report  2021         1   the
#
#                                       cleaned_content  \
# 0   basic information rheinmetall groupstructure r...
# 1   sustainability report creating transparency si...
# 2   gri sustainability record us international sta...
# 3   turn change opportunity embrace sustainability...
# 4   deutsche bank nonfinancial report letter chief...
# 5   combined management report combined management...
# 6   acting tomorrow today responsibility plan sust...
# 7   sustainability report editorial report crop pr...
# 8   sustainability report sustainability report an...
# 9   sustainability progress report progress glance...
# 10  2management reportcombined34 overview group34 ...
# 11  combined management report achieved report deu...
# 12  separate group nonfinancial report strategy ma...
# 13  group management report financial review conso...
# 14  sustainability highlight report care beyond sk...
# 15  sustainability report sustainability report gr...
# 16  group sustainability report building confidenc...
# 17  financial report directive stipulated commerzb...
# 18  sustainability management sustainability strat...
# 19  basf report report management overview nonfina...
# 20  portrait strategy management business complian...
# 21  sustainability supplementing annual report nav...
# 22  sustainy report sustainability report governan...
# 23  focus tomorrow sustainability report energy su...
# 24  overview sustainability prioritising sustainab...
# 25  sustainability report new auto reinvents world...
# 26  standwithukraine sustainability report search ...
# 27  sustainability report maximum image areaminimu...
# 28  sustainability report henkel sustainability re...
# 29  sustainability purpose technology transform ev...
# 30  corporate responsibility inhalt diesis pdfdoku...
# 31  integrated report stakeholder combined group m...
# 32  stedim biotech sa gri report stedim biotech gr...
# 33  combined management report nonfinancial statem...
# 34  sustainability report strategy management yees...
# 35  vonovia se sustainability report sustainable f...
# 36  brenntag se sustainability report brenntag wor...
#
#                                           word_tokens  \
# 0   ['basic', 'information', 'rheinmetall', 'group...
# 1   ['sustainability', 'report', 'creating', 'tran...
# 2   ['gri', 'sustainability', 'record', 'us', 'int...
# 3   ['turn', 'change', 'opportunity', 'embrace', '...
# 4   ['deutsche', 'bank', 'nonfinancial', 'report',...
# 5   ['combined', 'management', 'report', 'combined...
# 6   ['acting', 'tomorrow', 'today', 'responsibilit...
# 7   ['sustainability', 'report', 'editorial', 'rep...
# 8   ['sustainability', 'report', 'sustainability',...
# 9   ['sustainability', 'progress', 'report', 'prog...
# 10  ['2management', 'reportcombined34', 'overview'...
# 11  ['combined', 'management', 'report', 'achieved...
# 12  ['separate', 'group', 'nonfinancial', 'report'...
# 13  ['group', 'management', 'report', 'financial',...
# 14  ['sustainability', 'highlight', 'report', 'car...
# 15  ['sustainability', 'report', 'sustainability',...
# 16  ['group', 'sustainability', 'report', 'buildin...
# 17  ['financial', 'report', 'directive', 'stipulat...
# 18  ['sustainability', 'management', 'sustainabili...
# 19  ['basf', 'report', 'report', 'management', 'ov...
# 20  ['portrait', 'strategy', 'management', 'busine...
# 21  ['sustainability', 'supplementing', 'annual', ...
# 22  ['sustainy', 'report', 'sustainability', 'repo...
# 23  ['focus', 'tomorrow', 'sustainability', 'repor...
# 24  ['overview', 'sustainability', 'prioritising',...
# 25  ['sustainability', 'report', 'new', 'auto', 'r...
# 26  ['standwithukraine', 'sustainability', 'report...
# 27  ['sustainability', 'report', 'maximum', 'image...
# 28  ['sustainability', 'report', 'henkel', 'sustai...
# 29  ['sustainability', 'purpose', 'technology', 't...
# 30  ['corporate', 'responsibility', 'inhalt', 'die...
# 31  ['integrated', 'report', 'stakeholder', 'combi...
# 32  ['stedim', 'biotech', 'sa', 'gri', 'report', '...
# 33  ['combined', 'management', 'report', 'nonfinan...
# 34  ['sustainability', 'report', 'strategy', 'mana...
# 35  ['vonovia', 'se', 'sustainability', 'report', ...
# 36  ['brenntag', 'se', 'sustainability', 'report',...
#
#                                       sentence_tokens  \
# 0   ['basic information rheinmetall groupstructure...
# 1   ['sustainability report creating transparency ...
# 2   ['gri sustainability record uses international...
# 3   ['turn change opportunity embrace sustainabili...
# 4   ['deutsche bank nonfinancial report letter chi...
# 5   ['combined management report combined manageme...
# 6   ['acting tomorrow today responsibility plans s...
# 7   ['sustainability report editorial report crop ...
# 8   ['sustainability report sustainability report ...
# 9   ['sustainability progress report progress glan...
# 10  ['overview organisational business model group...
# 11  ['combined management report achieved report d...
# 12  ['separate group nonfinancial report strategy ...
# 13  ['group management report financial review con...
# 14  ['sustainability highlight report care beyond ...
# 15  ['sustainability report sustainability report ...
# 16  ['group sustainability report building confide...
# 17  ['financial report directives stipulated comme...
# 18  ['sustainability management sustainability str...
# 19  ['basf report report management overview nonfi...
# 20  ['portrait strategy management business compli...
# 21  ['sustainability supplementing annual report n...
# 22  ['', 'sustainy report sustainability report go...
# 23  ['focus tomorrow', 'sustainability report ener...
# 24  ['overview sustainability prioritising sustain...
# 25  ['sustainability report new auto reinvents wor...
# 26  ['standwithukraine sustainability report searc...
# 27  ['sustainability report maximum image areamini...
# 28  ['sustainability report henkel sustainability ...
# 29  ['sustainability purpose technology transform ...
# 30  ['corporate responsibility inhalt dieses pdfdo...
# 31  ['integrated report stakeholders combined grou...
# 32  ['stedim biotech gri report stedim biotech gri...
# 33  ['combined management report nonfinancial stat...
# 34  ['sustainability report strategy management ye...
# 35  ['vonovia se sustainability report sustainable...
# 36  ['brenntag se sustainability report brenntag w...
#
#                                pos_tagged_word_tokens  \
# 0   [('basic', 'JJ'), ('information', 'NN'), ('rhe...
# 1   [('sustainability', 'NN'), ('report', 'NN'), (...
# 2   [('gri', 'JJ'), ('sustainability', 'NN'), ('re...
# 3   [('turn', 'NN'), ('change', 'NN'), ('opportuni...
# 4   [('deutsche', 'NN'), ('bank', 'NN'), ('nonfina...
# 5   [('combined', 'JJ'), ('management', 'NN'), ('r...
# 6   [('acting', 'VBG'), ('tomorrow', 'NN'), ('toda...
# 7   [('sustainability', 'NN'), ('report', 'NN'), (...
# 8   [('sustainability', 'NN'), ('report', 'NN'), (...
# 9   [('sustainability', 'NN'), ('progress', 'NN'),...
# 10  [('2management', 'CD'), ('reportcombined34', '...
# 11  [('combined', 'JJ'), ('management', 'NN'), ('r...
# 12  [('separate', 'JJ'), ('group', 'NN'), ('nonfin...
# 13  [('group', 'NN'), ('management', 'NN'), ('repo...
# 14  [('sustainability', 'NN'), ('highlight', 'VBD'...
# 15  [('sustainability', 'NN'), ('report', 'NN'), (...
# 16  [('group', 'NN'), ('sustainability', 'NN'), ('...
# 17  [('financial', 'JJ'), ('report', 'NN'), ('dire...
# 18  [('sustainability', 'NN'), ('management', 'NN'...
# 19  [('basf', 'JJ'), ('report', 'NN'), ('report', ...
# 20  [('portrait', 'NN'), ('strategy', 'NN'), ('man...
# 21  [('sustainability', 'NN'), ('supplementing', '...
# 22  [('sustainy', 'JJ'), ('report', 'NN'), ('susta...
# 23  [('focus', 'NN'), ('tomorrow', 'NN'), ('sustai...
# 24  [('overview', 'NN'), ('sustainability', 'NN'),...
# 25  [('sustainability', 'NN'), ('report', 'NN'), (...
# 26  [('standwithukraine', 'JJ'), ('sustainability'...
# 27  [('sustainability', 'NN'), ('report', 'NN'), (...
# 28  [('sustainability', 'NN'), ('report', 'NN'), (...
# 29  [('sustainability', 'NN'), ('purpose', 'NN'), ...
# 30  [('corporate', 'JJ'), ('responsibility', 'NN')...
# 31  [('integrated', 'JJ'), ('report', 'NN'), ('sta...
# 32  [('stedim', 'NN'), ('biotech', 'NN'), ('sa', '...
# 33  [('combined', 'JJ'), ('management', 'NN'), ('r...
# 34  [('sustainability', 'NN'), ('report', 'NN'), (...
# 35  [('vonovia', 'NN'), ('se', 'JJ'), ('sustainabi...
# 36  [('brenntag', 'NN'), ('se', 'JJ'), ('sustainab...
#
#                            pos_tagged_sentence_tokens  \
# 0   [[('basic', 'JJ'), ('information', 'NN'), ('rh...
# 1   [[('sustainability', 'NN'), ('report', 'NN'), ...
# 2   [[('gri', 'NN'), ('sustainability', 'JJ'), ('r...
# 3   [[('turn', 'NN'), ('change', 'NN'), ('opportun...
# 4   [[('deutsche', 'NN'), ('bank', 'NN'), ('nonfin...
# 5   [[('combined', 'VBD'), ('management', 'NN'), (...
# 6   [[('acting', 'VBG'), ('tomorrow', 'NN'), ('tod...
# 7   [[('sustainability', 'NN'), ('report', 'NN'), ...
# 8   [[('sustainability', 'NN'), ('report', 'NN'), ...
# 9   [[('sustainability', 'NN'), ('progress', 'NN')...
# 10  [[('overview', 'NN'), ('organisational', 'JJ')...
# 11  [[('combined', 'VBD'), ('management', 'NN'), (...
# 12  [[('separate', 'JJ'), ('group', 'NN'), ('nonfi...
# 13  [[('group', 'NN'), ('management', 'NN'), ('rep...
# 14  [[('sustainability', 'NN'), ('highlight', 'VBD...
# 15  [[('sustainability', 'NN'), ('report', 'NN'), ...
# 16  [[('group', 'NN'), ('sustainability', 'NN'), (...
# 17  [[('financial', 'JJ'), ('report', 'NN'), ('sti...
# 18  [[('sustainability', 'NN'), ('management', 'NN...
# 19  [[('basf', 'VBD'), ('report', 'NN'), ('report'...
# 20  [[('portrait', 'NN'), ('strategy', 'NN'), ('ma...
# 21  [[('sustainability', 'NN'), ('supplementing', ...
# 22  [[], [('sustainy', 'JJ'), ('report', 'NN'), ('...
# 23  [[('focus', 'NN'), ('tomorrow', 'NN')], [('sus...
# 24  [[('overview', 'JJ'), ('sustainability', 'NN')...
# 25  [[('sustainability', 'NN'), ('report', 'VBP'),...
# 26  [[('standwithukraine', 'JJ'), ('sustainability...
# 27  [[('sustainability', 'NN'), ('report', 'NN'), ...
# 28  [[('sustainability', 'NN'), ('report', 'NN'), ...
# 29  [[('sustainability', 'NN'), ('purpose', 'JJ'),...
# 30  [[('corporate', 'JJ'), ('responsibility', 'NN'...
# 31  [[('integrated', 'VBN'), ('report', 'NN'), ('c...
# 32  [[('stedim', 'NN'), ('biotech', 'NN'), ('gri',...
# 33  [[('combined', 'VBN'), ('management', 'NN'), (...
# 34  [[('sustainability', 'NN'), ('report', 'NN'), ...
# 35  [[('vonovia', 'NN'), ('se', 'JJ'), ('sustainab...
# 36  [[('brenntag', 'NN'), ('se', 'NN'), ('sustaina...
#
#                                          company_name symbol  \
# 0                                      Rheinmetall AG    RHM
# 1                                   Siemens Energy AG    ENR
# 2                                          Symrise AG    SY1
# 3                                      Continental AG    CON
# 4                                    Deutsche Bank AG    DBK
# 5                                         Covestro AG   1COV
# 6                                 MTU Aero Engines AG    MTX
# 7                                            Bayer AG   BAYN
# 8   Münchener Rückversicherungs-Gesellschaft Aktie...   MUV2
# 9                                          Zalando SE    ZAL
# 10                        Bayerische Motoren Werke AG    BMW
# 11                                  Deutsche Börse AG    DB1
# 12                             Fresenius SE & Co KGaA    FRE
# 13                                          adidas AG    ADS
# 14                                      Beiersdorf AG    BEI
# 15                                   Hannover Rück SE   HNRB
# 16                                         Allianz SE    ALV
# 17                                     Commerzbank AG    CBK
# 18                       Porsche Automobil Holding SE   PAH3
# 19                                            BASF SE    BAS
# 20                            Heidelberg Materials AG    HEI
# 21                           Infineon Technologies AG    IFX
# 22                                        Qiagen N.V.    QIA
# 23                                             RWE AG    RWE
# 24                                          Airbus SE    AIR
# 25                                      Volkswagen AG    VOW
# 26                                            E.ON SE   EOAN
# 27                             Mercedes-Benz Group AG    DAI
# 28                                Henkel AG & Co KGaA    HEN
# 29                                         Siemens AG    SIE
# 30                                Deutsche Telekom AG    DTE
# 31                                             SAP SE    SAP
# 32                                       Sartorius AG    SRT
# 33                                   Deutsche Post AG    DHL
# 34             MERCK Kommanditgesellschaft auf Aktien    MRK
# 35                                         Vonovia SE    VNA
# 36                                        Brenntag AG    BNR
#
#     market_cap_in_usd_b      country                  sector  \
# 0                 11.96      Germany             Industrials
# 1                 13.82      Germany               Utilities
# 2                 14.81      Germany         Basic Materials
# 3                 15.16      Germany  Consumer Discretionary
# 4                 21.13      Germany              Financials
# 5                  9.87      Germany         Basic Materials
# 6                 13.21      Germany             Industrials
# 7                 53.38      Germany              Healthcare
# 8                 49.87      Germany              Financials
# 9                  6.92      Germany  Consumer Discretionary
# 10                77.25      Germany  Consumer Discretionary
# 11                32.32      Germany              Financials
# 12                15.90      Germany              Healthcare
# 13                33.41      Germany  Consumer Discretionary
# 14                28.61      Germany        Consumer Staples
# 15                24.66      Germany              Financials
# 16                91.36      Germany              Financials
# 17                14.96      Germany              Financials
# 18                17.87      Germany  Consumer Discretionary
# 19                44.37      Germany         Basic Materials
# 20                14.65      Germany         Basic Materials
# 21                50.42      Germany              Technology
# 22                10.49  Netherlands              Healthcare
# 23                32.35      Germany               Utilities
# 24               113.90  Netherlands             Industrials
# 25                77.55      Germany  Consumer Discretionary
# 26                32.95      Germany               Utilities
# 27                84.94      Germany  Consumer Discretionary
# 28                30.65      Germany        Consumer Staples
# 29               131.00      Germany             Industrials
# 30               106.00      Germany  Communication Services
# 31               161.41      Germany              Technology
# 32                21.43      Germany              Healthcare
# 33                57.95      Germany             Industrials
# 34                70.69      Germany              Healthcare
# 35                15.69      Germany             Real Estate
# 36                11.76      Germany         Basic Materials
#
#                                   industry  st1_sentiment_continuous
# 0                  Industrial Distribution                  0.019156
# 1    Utilities—Independent Power Producers                  0.018045
# 2                      Specialty Chemicals                  0.018819
# 3                               Auto Parts                  0.017767
# 4                           Banks—Regional                  0.017723
# 5                      Specialty Chemicals                  0.018556
# 6                      Aerospace & Defense                  0.018378
# 7               Drug Manufacturers—General                  0.018680
# 8                    Insurance—Reinsurance                  0.018395
# 9                          Internet Retail                  0.015273
# 10                      Auto Manufacturers                  0.017979
# 11        Financial Data & Stock Exchanges                  0.015751
# 12                 Medical Care Facilities                  0.018011
# 13                  Footwear & Accessories                  0.018259
# 14           Household & Personal Products                  0.019817
# 15                   Insurance—Reinsurance                  0.018542
# 16                   Insurance—Diversified                  0.018116
# 17                          Banks—Regional                  0.017837
# 18                      Auto Manufacturers                  0.018476
# 19                               Chemicals                  0.018786
# 20                      Building Materials                  0.018709
# 21                          Semiconductors                  0.018381
# 22                  Diagnostics & Research                  0.019487
# 23                   Utilities—Diversified                  0.013654
# 24                     Aerospace & Defense                  0.017821
# 25                      Auto Manufacturers                  0.017304
# 26                   Utilities—Diversified                  0.017514
# 27                      Auto Manufacturers                  0.018746
# 28           Household & Personal Products                  0.018979
# 29          Specialty Industrial Machinery                  0.019526
# 30                        Telecom Services                  0.014531
# 31                    Software—Application                  0.018051
# 32          Medical Instruments & Supplies                  0.017118
# 33          Integrated Freight & Logistics                  0.018219
# 34  Drug Manufacturers—Specialty & Generic                  0.018736
# 35                    Real Estate Services                  0.017565
# 36                     Specialty Chemicals                  0.018195

# %% [markdown]
# # Data Preparation & simple Feature Engineering
#
# As a preperation step, the tokenzied words are converted to lists so later operations work as expected. The word counts for the tokenized words and sentences are introduced as simple features for later analysis.

# %%
# Define a function to convert a string representation of a list to a list datatype
def string_to_list(string):
    try:
        return ast.literal_eval(string)
    except (ValueError, SyntaxError):
        print('List conversion failed')
        return []

# Convert the string representations of the lists to the correct 'list' datatype
cleaned_data_last['word_tokens'] = cleaned_data_last['word_tokens'].apply(string_to_list)
cleaned_data_last['sentence_tokens'] = cleaned_data_last['sentence_tokens'].apply(string_to_list)
cleaned_data_last['pos_tagged_word_tokens'] = cleaned_data_last['pos_tagged_word_tokens'].apply(string_to_list)
cleaned_data_last['pos_tagged_sentence_tokens'] = cleaned_data_last['pos_tagged_sentence_tokens'].apply(string_to_list)

# %%
# Add some count features for the analysis
cleaned_data_last['cnt_word'] = cleaned_data_last['word_tokens'].apply(len)
cleaned_data_last['cnt_sentence'] = cleaned_data_last['sentence_tokens'].apply(len)

# Calculate ratio between words/sentences
cleaned_data_last['ratio_word_sentence'] = cleaned_data_last['cnt_word'] / cleaned_data_last['cnt_sentence']

# %%
# Check the data with a few samples
cleaned_data_last.sample(5)
# Out:
#             company               datatype  date  internal title  \
# 22           Qiagen  Sustainability Report  2021         1   and
# 6               MTU  Sustainability Report  2021         1   the
# 33              DHL  Sustainability Report  2021         1   the
# 8   MuenchenerRueck  Sustainability Report  2021         1     .
# 23              RWE  Sustainability Report  2021         1   the
#
#                                       cleaned_content  \
# 22  sustainy report sustainability report governan...
# 6   acting tomorrow today responsibility plan sust...
# 33  combined management report nonfinancial statem...
# 8   sustainability report sustainability report an...
# 23  focus tomorrow sustainability report energy su...
#
#                                           word_tokens  \
# 22  [sustainy, report, sustainability, report, gov...
# 6   [acting, tomorrow, today, responsibility, plan...
# 33  [combined, management, report, nonfinancial, s...
# 8   [sustainability, report, sustainability, repor...
# 23  [focus, tomorrow, sustainability, report, ener...
#
#                                       sentence_tokens  \
# 22  [, sustainy report sustainability report gover...
# 6   [acting tomorrow today responsibility plans su...
# 33  [combined management report nonfinancial state...
# 8   [sustainability report sustainability report a...
# 23  [focus tomorrow, sustainability report energy ...
#
#                                pos_tagged_word_tokens  \
# 22  [(sustainy, JJ), (report, NN), (sustainability...
# 6   [(acting, VBG), (tomorrow, NN), (today, NN), (...
# 33  [(combined, JJ), (management, NN), (report, NN...
# 8   [(sustainability, NN), (report, NN), (sustaina...
# 23  [(focus, NN), (tomorrow, NN), (sustainability,...
#
#                            pos_tagged_sentence_tokens  \
# 22  [[], [(sustainy, JJ), (report, NN), (sustainab...
# 6   [[(acting, VBG), (tomorrow, NN), (today, NN), ...
# 33  [[(combined, VBN), (management, NN), (report, ...
# 8   [[(sustainability, NN), (report, NN), (sustain...
# 23  [[(focus, NN), (tomorrow, NN)], [(sustainabili...
#
#                                          company_name symbol  \
# 22                                        Qiagen N.V.    QIA
# 6                                 MTU Aero Engines AG    MTX
# 33                                   Deutsche Post AG    DHL
# 8   Münchener Rückversicherungs-Gesellschaft Aktie...   MUV2
# 23                                             RWE AG    RWE
#
#     market_cap_in_usd_b      country       sector  \
# 22                10.49  Netherlands   Healthcare
# 6                 13.21      Germany  Industrials
# 33                57.95      Germany  Industrials
# 8                 49.87      Germany   Financials
# 23                32.35      Germany    Utilities
#
#                           industry  st1_sentiment_continuous  cnt_word  \
# 22          Diagnostics & Research                  0.019487      8702
# 6              Aerospace & Defense                  0.018378     24901
# 33  Integrated Freight & Logistics                  0.018219      3350
# 8            Insurance—Reinsurance                  0.018395     32801
# 23           Utilities—Diversified                  0.013654     32319
#
#     cnt_sentence  ratio_word_sentence
# 22           493            17.651116
# 6           1676            14.857399
# 33           212            15.801887
# 8           2745            11.949362
# 23          2142            15.088235

# %% [markdown]
# # General Descriptive Analysis
#
# To get a fast overview in terms of the statistial key metrics, several functions are defined. These ensure quick insights into the data.

# %%
def plot_basic_hist_and_box(column, data):
    """
    Plots a histogram and boxplot of a specified column in a pandas DataFrame.

    Args:
    - column (str): The name of the column to plot.
    - data (pandas DataFrame): The DataFrame containing the column.

    Returns:
    - None
    """
    plt.figure(figsize=(12, 5))
    plt.subplot(1, 2, 1)
    sns.histplot(data[column], kde=True)
    plt.title(f'Histogram of {column}')
    plt.subplot(1, 2, 2)
    sns.boxplot(x=data[column])
    plt.title(f'Boxplot of {column}')
    plt.show()

def calculate_basic_statistical_properties(column, data):
    """
    Calculates basic statistical properties of a specified column in a pandas DataFrame.

    Args:
    - column (str): The name of the column to analyze.
    - data (pandas DataFrame): The DataFrame containing the column.

    Returns:
    - None
    """
    mean = data[column].mean()
    median = data[column].median()
    mode = data[column].mode().values[0]
    skewness = skew(data[column].dropna())
    kurt = kurtosis(data[column].dropna())
    
    print(f'Mean: {round(mean,2)}\nMedian: {round(median,2)}\nMode: {round(mode,2)}\nSkewness: {round(skewness,2)}\nKurtosis: {round(kurt,2)}')

def calulate_dispersion_measures(column, data):
    """
    Calculates measures of dispersion of a specified column in a pandas DataFrame.

    Args:
    - column (str): The name of the column to analyze.
    - data (pandas DataFrame): The DataFrame containing the column.

    Returns:
    - None
    """
    min_value = data[column].min()
    max_value = data[column].max()
    range_value = max_value - min_value
    q1 = data[column].quantile(0.25)
    q3 = data[column].quantile(0.75)
    iqr = q3 - q1
    variance = data[column].var()
    std_dev = data[column].std()
    
    print(f'Range: {round(range_value,2)}\nInterquartile Range: {round(iqr,2)}\nVariance: {round(variance,2)}\nStandard Deviation: {round(std_dev,2)}')

# %% [markdown]
# ### Basic Statistical Metrics of documents by Words

# %%
calculate_basic_statistical_properties('cnt_word', cleaned_data_last)
calulate_dispersion_measures('cnt_word', cleaned_data_last)
plot_basic_hist_and_box('cnt_word', cleaned_data_last)
# Out:
# Mean: 31577.08
# Median: 32801.0
# Mode: 3350
# Skewness: 0.21
# Kurtosis: 0.06
# Range: 71034
# Interquartile Range: 21159.0
# Variance: 241924869.97
# Standard Deviation: 15553.93

# %%
average_sentiment = cleaned_data_last.groupby('company')['st1_sentiment_continuous'].mean()
print(average_sentiment)
# Out:
# company
# Adidas                 0.018259
# Airbus                 0.017821
# Allianz                0.018116
# BASF                   0.018786
# BMW                    0.017979
# Bayer                  0.018680
# Beiersdorf             0.019817
# Brenntag               0.018195
# Commerzbank            0.017837
# Continental            0.017767
# Covestro               0.018556
# DHL                    0.018219
# DeutscheBank           0.017723
# DeutscheBoerse         0.015751
# EON                    0.017514
# Fresenius              0.018011
# HannoverRueck          0.018542
# HeidelbergMaterials    0.018709
# Henkel                 0.018979
# Infineon               0.018381
# MTU                    0.018378
# MercedesBenz           0.018746
# Merck                  0.018736
# MuenchenerRueck        0.018395
# Porsche                0.018476
# Qiagen                 0.019487
# RWE                    0.013654
# Rheinmetall            0.019156
# SAP                    0.018051
# Sartorius              0.017118
# Siemens                0.019526
# SiemensEnergy          0.018045
# Symrise                0.018819
# Telekom                0.014531
# Volkswagen             0.017304
# Vonovia                0.017565
# Zalando                0.015273
# Name: st1_sentiment_continuous, dtype: float64

# %%
import matplotlib.pyplot as plt

plt.hist(cleaned_data_last['st1_sentiment_continuous'], bins=20)
plt.xlabel('Sentiment')
plt.ylabel('Frequency')
plt.title('Distribution of Sentiment Values')
plt.show()

# %%
plt.scatter(cleaned_data_last['cnt_word'], cleaned_data_last['st1_sentiment_continuous'])
plt.xlabel('Word Count')
plt.ylabel('Sentiment')
plt.title('Word Count vs Sentiment')
plt.show()

# %%
average_sentiment_by_country = cleaned_data_last.groupby('country')['st1_sentiment_continuous'].mean()
print(average_sentiment_by_country)
# Out:
# country
# Germany        0.017931
# Netherlands    0.018654
# Name: st1_sentiment_continuous, dtype: float64

# %%
average_sentiment_by_country.plot(kind='bar')
plt.xlabel('Country')
plt.ylabel('Average Sentiment')
plt.title('Average Sentiment by Country')
plt.show()

# %%
average_sentiment_by_industry = cleaned_data_last.groupby('industry')['st1_sentiment_continuous'].mean()
print(average_sentiment_by_industry)
# Out:
# industry
# Aerospace & Defense                       0.018100
# Auto Manufacturers                        0.018126
# Auto Parts                                0.017767
# Banks—Regional                            0.017780
# Building Materials                        0.018709
# Chemicals                                 0.018786
# Diagnostics & Research                    0.019487
# Drug Manufacturers—General                0.018680
# Drug Manufacturers—Specialty & Generic    0.018736
# Financial Data & Stock Exchanges          0.015751
# Footwear & Accessories                    0.018259
# Household & Personal Products             0.019398
# Industrial Distribution                   0.019156
# Insurance—Diversified                     0.018116
# Insurance—Reinsurance                     0.018468
# Integrated Freight & Logistics            0.018219
# Internet Retail                           0.015273
# Medical Care Facilities                   0.018011
# Medical Instruments & Supplies            0.017118
# Real Estate Services                      0.017565
# Semiconductors                            0.018381
# Software—Application                      0.018051
# Specialty Chemicals                       0.018523
# Specialty Industrial Machinery            0.019526
# Telecom Services                          0.014531
# Utilities—Diversified                     0.015584
# Utilities—Independent Power Producers     0.018045
# Name: st1_sentiment_continuous, dtype: float64

# %%
average_sentiment_by_industry.plot(kind='barh', figsize=(10, 8))
plt.xlabel('Average Sentiment')
plt.ylabel('Industry')
plt.title('Average Sentiment by Industry')
plt.show()

# %%
average_sentiment_by_company = cleaned_data_last.groupby('company')['st1_sentiment_continuous'].mean()
top_10_companies = average_sentiment_by_company.sort_values(ascending=False).head(10)

top_10_companies.plot(kind='bar')
plt.xlabel('Company')
plt.ylabel('Average Sentiment')
plt.title('Top 10 Companies by Average Sentiment')
plt.show()

# %%
correlation_matrix = cleaned_data_last[['st1_sentiment_continuous', 'cnt_word', 'cnt_sentence', 'ratio_word_sentence']].corr()

import seaborn as sns

sns.heatmap(correlation_matrix, annot=True)
plt.title('Correlation Matrix')
plt.show()

# %%
# Convert market cap to numeric
cleaned_data_last['market_cap_in_usd_b'] = pd.to_numeric(cleaned_data_last['market_cap_in_usd_b'], errors='coerce')

plt.scatter(cleaned_data_last['market_cap_in_usd_b'], cleaned_data_last['st1_sentiment_continuous'])
plt.xlabel('Market Cap (in billion USD)')
plt.ylabel('Sentiment')
plt.title('Market Cap vs Sentiment')
plt.show()

# %%
# Define bins for market cap
bins = [0, 10, 50, 100, np.inf]
labels = ['Small', 'Medium', 'Large', 'Very Large']
cleaned_data_last['market_cap_group'] = pd.cut(cleaned_data_last['market_cap_in_usd_b'], bins=bins, labels=labels)

# Calculate average sentiment by market cap group
average_sentiment_by_market_cap_group = cleaned_data_last.groupby('market_cap_group')['st1_sentiment_continuous'].mean()
print(average_sentiment_by_market_cap_group)
# Out:
# market_cap_group
# Small         0.016914
# Medium        0.018043
# Large         0.018270
# Very Large    0.017482
# Name: st1_sentiment_continuous, dtype: float64
# /var/folders/ln/8_743tps409d2_3d_6px3_nc0000gn/T/ipykernel_3667/2022677677.py:7: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   average_sentiment_by_market_cap_group = cleaned_data_last.groupby('market_cap_group')['st1_sentiment_continuous'].mean()

# %%
average_sentiment_by_market_cap_group.plot(kind='bar')
plt.xlabel('Market Cap Group')
plt.ylabel('Average Sentiment')
plt.title('Average Sentiment by Market Cap Group')
plt.show()

# %%
average_sentiment_by_market_cap_group.plot(kind='line')
plt.xlabel('Market Cap Group')
plt.ylabel('Average Sentiment')
plt.title('Average Sentiment by Market Cap Group')
plt.show()

# %%
cleaned_data_last.to_csv('/Users/seyyiduzun/Documents/Bachelorarbeit/Bachelorarbeit/comparison/cleaned_data_last_2021.csv', index=False)
